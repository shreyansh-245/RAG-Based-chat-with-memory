# %%
import os
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from secret_key import my_openapi_key

os.environ["OPENAI_API_KEY"] = "my_openapi_key"

def get_pdf_text(pdf_paths):
    text = ""
    for pdf_path in pdf_paths:
        pdf_reader = PdfReader(pdf_path)
        for page in pdf_reader.pages:
            text += page.extract_text()
    return text

def get_text_chunks(text):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=300, chunk_overlap=100
    )
    chunks = text_splitter.split_text(text)
    return chunks

def get_vectorstore(text_chunks):
    embeddings = OpenAIEmbeddings()
    vectorstore = FAISS.from_texts(texts=text_chunks, embedding=embeddings)
    return vectorstore

def get_conversation_chain(vectorstore):
    llm = ChatOpenAI()
    memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)
    conversation_chain = ConversationalRetrievalChain.from_llm(
        llm=llm, retriever=vectorstore.as_retriever(), memory=memory
    )
    return conversation_chain

def handle_userinput(conversation_chain, user_question, prompt_template):
    response = conversation_chain({"question": prompt_template.format(user_question)})
    return response

# Specify the path to your PDF file
pdf_paths = ["Doc/policy-booklet-0923.pdf"]

# Extract text from the PDF
raw_text = get_pdf_text(pdf_paths)

# Split the text into chunks
text_chunks = get_text_chunks(raw_text)

# Create a vector store from the text chunks
vectorstore = get_vectorstore(text_chunks)

# Create a conversation chain with the vector store
conversation_chain = get_conversation_chain(vectorstore)

prompt_template = "Please provide information about {} from within the policy document. If there are any other question request the user to stick to the context only."

# Example user input
user_question = "What is the policy on coverage for other people?"

# Handle the user input and get a response
response = handle_userinput(conversation_chain, user_question, prompt_template)

# Display the response
for message in response["chat_history"]:
    if message.type == "user":
        print(f"User: {message.content}")
    else:
        print(f"Bot: {message.content}")
# Out:
# /Users/ritikaverma/anaconda3/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# /Users/ritikaverma/anaconda3/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# /Users/ritikaverma/anaconda3/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Bot: Please provide information about Provide me the number to call, if I need to claim from within the policy document. If there are any other question request the user to stick to the context only.
# Bot: If you need to make a claim according to the policy document, you can call 0345 878 6261 for general claims or 0800 328 9150 for windscreen claims. Stick to the context provided for any other questions.

# %% [markdown]
# ### Evaluation of RAG - Accuracy

# %%
EVAL_PROMPT = """
Expected Response: {expected_response}
Actual Response: {actual_response}
---
(Answer with 'true' or 'false') Does the actual response match the expected response? 
"""

# Function to evaluate the RAG system using Ollama model
def evaluate_rag_system_from_csv(conversation_chain, csv_path):
    df = pd.read_csv(csv_path)
    correct = 0
    total = len(df)
    eval_model = Ollama(model="mistral")  # Initialize the Ollama model

    for index, row in df.iterrows():
        question = row['Question']
        expected_answer = row['Answer']

        response = handle_userinput(conversation_chain, question)
        bot_answer = response["chat_history"][-1].content  # Last message is the bot's response

        eval_prompt = EVAL_PROMPT.format(expected_response=expected_answer, actual_response=bot_answer)
        
        # Invoke the Ollama model with the evaluation prompt
        evaluation_results_str = eval_model.invoke(eval_prompt)
        evaluation_results_str_cleaned = evaluation_results_str.strip().lower()

        print(eval_prompt)

        if "true" in evaluation_results_str_cleaned:
            # Print response in Green if it is correct.
            print("\033[92m" + f"Response: {evaluation_results_str_cleaned}" + "\033[0m")
            correct += 1
        elif "false" in evaluation_results_str_cleaned:
            # Print response in Red if it is incorrect.
            print("\033[91m" + f"Response: {evaluation_results_str_cleaned}" + "\033[0m")
        #else:
            #raise ValueError(
                #f"Invalid evaluation result. Cannot determine if 'true' or 'false'."
            #)

    accuracy = correct / total
    print(f"Accuracy: {accuracy * 100:.2f}%")

# Path to your CSV file
csv_path = "Updated_Testcase_Dataset_v2.csv"

# Run the evaluation
evaluate_rag_system_from_csv(conversation_chain, csv_path)
# Out:
# Expected Response: To make a claim for windscreen damage, you need to contact the windscreen claims number provided, and the policy will cover the cost of replacing or repairing broken glass in the windscreen, sunroof, or windows.
# Actual Response: To make a claim for windscreen damage, you would need to contact Churchill at 0800 328 9150 if you have Essentials, Comprehensive, or Comprehensive Plus cover. They will guide you through the process of having your windscreen repaired or replaced. Additionally, if you have Motor Legal Cover, you can contact the Motor Legal Helpline at 0345 246 2408 for assistance with your claim. Remember that there may be excess amounts to pay for each incident you claim for, as outlined in your policy.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true, but the actual response provides more detailed information about the process and contact numbers for making a windscreen damage claim with churchill insurance.
#
# Expected Response: No, the policy does not cover theft or attempted theft if the car is left unlocked.
# Actual Response: No, the policy does not cover theft if the car is left unlocked. If your car is left unlocked, with the keys or key fobs inside, the insurance won't pay a claim for theft or attempted theft.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. both responses convey that if a car is left unlocked and stolen, the insurance policy does not cover the loss. however, the actual response adds some clarity by also mentioning key fobs in addition to keys.
#
# Expected Response: Yes, the home charger and charging cables are considered an accessory to the car and are covered under 'Section 2: Fire and theft' or 'Section 4: Accidental damage.'
# Actual Response: Yes, your electric car's charging cables are covered under the policy as they are considered an accessory to your car. They are covered under 'Section 2: Fire and theft' and you are also covered for any accidents involving your charging cables when they are attached to your car under 'Section 1: Liability.'
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. both responses indicate that the charging cables are covered under the insurance policy. the actual response adds additional information about which sections of the policy cover the charging cables, but it still aligns with the expected response.
#
# Expected Response: The policy covers up to £10,000 for personal accident under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car.
# Actual Response: Under the policy, the coverage for personal accident includes covering medical expenses for injuries sustained in a car accident, up to the amounts specified in the policy document. The insurance will only pay out once in any period of insurance and will cover accidents to both you and your partner up to the specified limits. If you have personal accident coverage under another policy with the same insurer, they will only pay out on one of your policies.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: false, the actual response goes into more detail about the medical expenses coverage aspect of personal accident under the policy, but it does mention the £10,000 limit for personal accident cover in a car accident involving your car.
#
# Expected Response: DriveSure is a telematics insurance product designed to capture how, when, and where your car is driven, based on driver-monitoring technology. This information is used to understand your driving style and give feedback, which in turn bases your premium on your driving record.
# Actual Response: DriveSure works by capturing how, when, and where your car is driven through driver-monitoring technology. This data helps understand your driving style and provides feedback. Your premium is then based on your driving record. If you have a Comprehensive with DriveSure policy, your cover is the same as a regular Comprehensive policy, but your premium is influenced by your driving behavior as monitored by DriveSure.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. the actual response elaborates on the same concept as the expected response and provides additional details.
#
# Expected Response: The policy covers up to £1,000 for the theft of car keys.
# Actual Response: The coverage amount for the theft of car keys under the policy is £1,000.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. both responses convey that the coverage amount for the theft of car keys under the policy is £1,000.
#
# Expected Response: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court.
# Actual Response: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court. This cover includes fines, penalties, compensation or damages you may be ordered to pay by a court, as well as disputes with the insurance provider under Motor Legal Cover. It also covers the appointed representative's fees and responsibilities to report to the insurance company.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. the actual response expands upon the expected response by providing additional details about what is covered under motor legal cover.
#
# Expected Response: Courtesy cars are available if you have Essentials or Comprehensive cover and your car is being repaired by an approved repairer.
# Actual Response: Courtesy cars are not available for all types of cover. They are included with Third Party, Fire and Theft, Essentials, and Comprehensive policies if you haven't chosen Guaranteed Hire Car Plus. It's important to check your specific policy to see if a courtesy car is included.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true, but with some additional details. the actual response correctly states that courtesy cars are not available for all types of cover and provides more information about which policies include them. the expected response is also correct but does not provide this level of detail.
#
# Expected Response: The territorial limits include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# Actual Response: The territorial limits for coverage under the policy include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man. It also covers journeys between these places.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. both responses describe the same territorial coverage for the policy. the only difference is that the actual response adds "it also covers journeys between these places." however, this additional detail does not change the essential meaning of the response.
#
# Expected Response: You should provide your personal details, policy number, car registration number, and a description of the loss or damage.
# Actual Response: If you are involved in an accident, here are some steps you should follow:
#
# 1. Safety first: Stop at the scene of the accident and call the police and emergency services if there are any injuries or if any driver involved hasn’t stopped.
# 2. Take photos of the accident if it’s safe to do so, including any vehicles involved. Dash cam footage could be useful as well.
# 3. Obtain the other driver/vehicle details: Ask the other party for their contact details, including their vehicle registration, name, address, and telephone number. Give your information to the other party but do not accept blame for the accident.
# 4. Seek out witnesses: If there are any witnesses who have stopped, ask for their contact information.
#
# Remember to notify your insurance company about the accident as soon as possible to initiate the claims process.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: false. the actual response provides steps to follow in case of an accident, but it does not specifically ask for personal details, policy number, car registration number, and a description of the loss or damage as stated in the expected response.
# Expected Response: Section 1: Liability covers you if you're found to be legally responsible for an accident involving your car that injures or kills someone or damages their property.
# Actual Response: Section 1: Liability covers the payment of reasonable legal costs or expenses to defend or represent you or any driver covered by the policy if you have to go to court due to an accident covered by the policy.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: false. the actual response is about legal costs related to an accident, not liability coverage for injuries or property damages.
#
# Expected Response: If your new car is stolen and not recovered, or written off, Comprehensive Plus will replace it with one of the same make and model if your car is less than 2 years old.
# Actual Response: Under Comprehensive Plus cover, your car will be replaced with a new one of the same make and model if it is less than 2 years old when it’s stolen or damaged.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. both responses convey that comprehensive plus will replace a car (stolen or damaged) with a new one of the same make and model if it is less than 2 years old.
#
# Expected Response: Yes, personal belongings are covered if they are lost or damaged by fire, theft, attempted theft, or accident while they’re in or on your car, up to £500 under Comprehensive Plus.
# Actual Response: Personal belongings are covered under the policy if they are damaged in your car and you are legally responsible for them. However, the policy does not cover damage to personal belongings that are owned or responsible for by someone else, or if the damage is due to an act of terrorism. It's important to check your policy carefully for specific details on coverage for personal belongings.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: false. the expected response states that personal belongings are covered up to £500 under comprehensive plus if they are lost or damaged by certain perils, while the actual response states that they are covered only if the policyholder is legally responsible for them and the damage is not caused by an act of terrorism. the expected response does not mention any specific limit for coverage.
#
# Expected Response: The maximum number of claims allowed under Protected No Claim Discount is 2 claims in 3 years.
# Actual Response: The maximum number of claims allowed under Protected No Claim Discount in the policy is 2 claims in 3 years.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. both responses state that the maximum number of claims allowed under protected no claim discount is 2 claims in 3 years.
#
# Expected Response: You should call the claims number provided, have your personal details, policy number, car registration number, and a description of the loss or damage ready.
# Actual Response: If you need to make a claim, follow these steps:
#
# 1. Contact the insurance company as soon as possible after the accident.
# 2. Provide your personal details and policy number.
# 3. Cooperate with the insurance company to provide any necessary information or documentation.
# 4. Follow any instructions provided by the insurance company to process your claim efficiently.
# 5. Keep all relevant information handy, such as the details of the accident and any other parties involved.
#
# For specific instructions or guidance on making a claim, you can contact the insurance company at the provided number: 0345 878 6261.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. the actual response includes all the elements of the expected response, but it also provides some additional steps and information to help guide the claimant through the process.
#
# Expected Response: No, the policy does not cover mechanical or electrical failure.
# Actual Response: No, the policy does not cover mechanical or electrical failure.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. both expected and actual responses are "no" and indicate that the policy does not cover mechanical or electrical failure.
#
# Expected Response: Yes, you can use your car abroad, but you may need a Green Card and should take a European Accident Statement with you.
# Actual Response: If you have Comprehensive cover and you've added Foreign Use Extension to your policy before traveling abroad, your car will be covered while driving abroad. This means that if your car keys are stolen, they will be covered. If your automated car is involved in an accident while lawfully driving itself outside of Great Britain, your policy will still apply. If you do not have Foreign Use Extension or if it has been used up, your car insurance will only provide the minimum required coverage by law in European Union countries.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true, but the actual response provides more detailed information about the requirements for using a car abroad with car insurance coverage.
#
# Expected Response: If your car is written off, the insurance will pay the market value of the car, and the car will become the property of the insurance company.
# Actual Response: If your car is written off under the policy and the insurance company agrees to settle your claim on that basis, they will have met their responsibilities to you under the policy. Depending on the type of coverage you have, such as Comprehensive or Comprehensive Plus, you may be entitled to a hire car for a certain period of time after your car is written off or stolen and not recovered. Additionally, if your car needs to be put into safe storage at any time, the insurance company will cover the reasonable cost of storage. However, if your car is written off or stolen and not recovered, you won't receive a courtesy car.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: false. the actual response goes beyond the expected response by providing additional information about potential entitlements for hire cars and storage costs under certain types of coverage, as well as clarifying that the car won't be returned if written off or stolen and not recovered.
#
# Expected Response: The Vandalism Promise covers damage to your car that is a result of vandalism, and this won’t affect the No Claim Discount on your policy.
# Actual Response: The Vandalism Promise covers damage to your car that is a result of vandalism. It states that if you claim for such damage, it won't affect the No Claim Discount on your policy. However, it does not cover damage caused by another vehicle.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true, but with an additional detail that the actual response specifies that the vandalism promise does not cover damage caused by another vehicle.
#
# Expected Response: The Uninsured Driver Promise ensures that if you are hit by an uninsured driver, your No Claim Discount will not be affected and you will not need to pay an excess.
# Actual Response: The Uninsured Driver Promise is a feature included with Essential Comp and Comp+ insurance policies. If you have this promise and you're involved in an accident that isn't your fault and the other driver is uninsured, your No Claim Discount on the policy will not be affected, and you will not need to pay an excess. You will need to provide details about the uninsured driver's vehicle and the driver if possible. This promise provides coverage in case of accidents with uninsured drivers.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. the actual response elaborates on the details of the uninsured driver promise as stated in the expected response.
#
# Expected Response: You must report the theft to the police, obtain a crime reference number, and pay the theft excess.
# Actual Response: If your car keys are stolen, you should report the theft to the police and obtain a crime reference number. Then, contact your insurance provider to report the theft of your car keys. They will provide cover to reprogram immobilisers, infrared handsets, and alarms. Additionally, they can choose to either repair or replace your lost or damaged car keys and the locks they fit, including any locksmith charges. Just remember that you may need to pay a theft excess in this situation.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true, but the actual response provides more detailed information. the expected response only mentions reporting the theft to the police and paying a theft excess. the actual response adds contacting the insurance provider to report the stolen car keys, obtaining coverage for reprogramming immobilisers, infrared handsets, and alarms, and possibly repairing or replacing lost or damaged car keys and locks.
# Expected Response: Yes, the policy covers vandalism damage, and it won’t affect your No Claim Discount if you have Comprehensive or Comprehensive Plus cover.
# Actual Response: Yes, the policy covers vandalism damage. If you claim for damage to your car that's a result of vandalism, it won't affect the No Claim Discount on this policy. Just make sure to follow the necessary steps provided in the policy if you need to make a claim for vandalism damage.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. both responses convey that there is no impact on no claim discount when making a claim for vandalism damage under comprehensive or comprehensive plus car insurance policies. the second response provides some additional instructions to follow the necessary steps if making a claim, but it does not change the core message of the expected response.
#
# Expected Response: The policy does not cover any claims if the car is driven by someone who is not insured on the policy.
# Actual Response: If someone drives your car without being named or listed as a driver on your insurance policy, there could be serious consequences. In such a situation, your insurance may not cover any loss, damage, liability, or injury that occurs while your car is being driven by an unauthorized person. This means that you may be personally liable for any damages or injuries caused by the uninsured driver. Additionally, driving without insurance is illegal in most places and can result in fines, license suspension, or other legal penalties. It is important to ensure that only authorized drivers are using your car to avoid these consequences.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true, but the actual response provides additional information and context beyond just stating that the policy does not cover claims for unauthorized drivers.
#
# Expected Response: You can claim for personal belongings if they are lost or damaged by fire, theft, attempted theft, or accident while they are in or on your car, up to the specified amount.
# Actual Response: Personal belongings can be claimed under the policy if they are damaged in your car and you are legally responsible for them. You can claim for any other financial losses that happened as a direct result of the accident. To use this cover, your car must be involved in a road traffic accident within the territorial limits or when driving abroad. The insurance will provide cover up to certain amounts depending on the type of claim and the level of cover you have. After settling the claim, your car will become the insurance company's property, and you must send them the registration document, unless otherwise agreed.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: false, the actual response goes into more detail about the conditions under which personal belongings can be claimed, as well as other financial losses, and mentions that the car must be involved in a road traffic accident for this coverage to apply. the expected response only mentioned personal belongings being covered if they are lost or damaged by certain causes while in or on the car.
#
# Expected Response: Yes, medical expenses are covered up to the specified amount if you are injured in a car accident.
# Actual Response: Yes, medical expenses are covered if you are injured in a car accident under the policy, as long as no other car insurance policy covers the cost. The policy will cover up to the amounts specified in 'What your cover includes.'
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true, both responses indicate that medical expenses are covered up to a specified amount if you are injured in a car accident. however, the actual response adds an extra condition that no other car insurance policy covers the cost.
#
# Expected Response: The DriveSure policy includes telematics insurance that captures driving data to understand your driving style and adjust your premium accordingly.
# Actual Response: The DriveSure policy is a telematics insurance product designed to monitor how, when, and where your car is driven. It uses driver-monitoring technology to understand your driving style and provide feedback. The policy includes capturing data on your driving habits to base your premium on your driving record. Additionally, if you have a policy that includes DriveSure, it will also include the DriveSure terms and conditions provided by the insurance company.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. the actual response expands upon the information provided in the expected response while maintaining its essential meaning.
#
# Expected Response: Yes, the policy covers damage caused by misfuelling, but it does not cover the cost of draining, flushing, or replacing the fuel.
# Actual Response: Yes, damage caused by misfuelling is covered under the policy. The policy will cover any damage to your car caused by misfuelling. However, it won't cover the cost of draining, flushing, or replacing the fuel if the wrong fuel is put in your car.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true. the expected and actual responses both indicate that damage caused by misfuelling is covered under the policy, but the cost of draining, flushing, or replacing the fuel is not.
#
# Expected Response: The policy covers up to £300 for hotel expenses if you cannot drive your car after an accident or loss covered under sections 2 or 4.
# Actual Response: The policy covers hotel expenses if you are unable to drive your car after an accident that is covered under sections 2 or 4 of the policy. The coverage includes compensation up to the amounts specified in the policy document. Additionally, if the insurance company cannot provide you with a hire car due to certain reasons, they will reimburse your travel costs up to £50 per day, with a total limit of £500 per claim, under specific conditions like being injured in a way that prevents you from driving.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true, but the actual response provides more detailed information. the expected response only mentions the coverage for hotel expenses up to £300 after an accident, while the actual response includes compensation up to the amounts specified in the policy document and the option of travel costs reimbursement under certain conditions if a hire car cannot be provided.
#
# Expected Response: You can use the courtesy car for the duration of the repair if it is being repaired by an approved repairer.
# Actual Response: If your car can be repaired and is driveable, you can use the courtesy car:
# - If you use our approved repairer, until they have repaired your car.
# - If you use your own repairer, for up to 21 days in a row while they’re repairing your car.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true, but with some additional details. the actual response is more specific and includes the condition that if the person uses their own repairer, they can only use the courtesy car for up to 21 days in a row.
#
# Expected Response: Guaranteed Hire Car Plus provides a hire car of a similar size to your own if your car is damaged in an incident, written off, or stolen.
# Actual Response: The Guaranteed Hire Car Plus cover provides a hire car of a similar size to your own if your car is damaged in an incident, written off, or stolen. The hire car is provided to keep you mobile while your car is being repaired. The duration you can have the hire car for may vary depending on whether you use an approved repairer or a different repairer. The excess for accidental damage claims related to the courtesy car is £250.
# ---
# (Answer with 'true' or 'false') Does the actual response match the expected response?
#
# Response: true, but the actual response provides additional details that were not included in the expected response. specifically, it mentions that the hire car is provided to keep you mobile while your car is being repaired and notes that the duration you can have the hire car for may vary depending on whether you use an approved repairer or a different repairer. it also specifies the excess for accidental damage claims related to the courtesy car.
# Accuracy: 80.00%

# %% [markdown]
# Accuracy with this approach(local LLM & prompt engineering) provides 80% accuracy.

# %% [markdown]
# ### RAG Evaluation - Relevancy, precision & Recall (Using SentenceTransformer)

# %%
import os
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from secret_key import my_openapi_key

os.environ["OPENAI_API_KEY"] = "my_openapi_key"


conversation_chain = conversation_chain

# Load the sentence transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Function to handle user input and get response
def handle_userinput(conversation_chain, user_question):
    response = conversation_chain({"question": user_question})
    return response

# Function to evaluate precision, recall, and relevancy using sentence-transformers
def evaluate_rag_system(conversation_chain, csv_path):
    df = pd.read_csv(csv_path)
    precision_scores = []
    recall_scores = []
    relevancy_scores = []

    for index, row in df.iterrows():
        question = row['Question']
        expected_answer = row['Answer']

        response = handle_userinput(conversation_chain, question)
        bot_answer = response["chat_history"][-1].content  # Last message is the bot's response

        # Compute embeddings
        expected_embedding = model.encode(expected_answer, convert_to_tensor=True)
        bot_embedding = model.encode(bot_answer, convert_to_tensor=True)

        # Compute cosine similarity
        relevancy_score = util.pytorch_cos_sim(expected_embedding, bot_embedding).item()

        # Precision and Recall are a bit more abstract, let's consider them based on token overlap for simplicity
        expected_tokens = set(expected_answer.split())
        bot_tokens = set(bot_answer.split())
        true_positive = len(expected_tokens & bot_tokens)
        precision = true_positive / len(bot_tokens) if len(bot_tokens) > 0 else 0
        recall = true_positive / len(expected_tokens) if len(expected_tokens) > 0 else 0

        precision_scores.append(precision)
        recall_scores.append(recall)
        relevancy_scores.append(relevancy_score)

        print(f"Question: {question}")
        print(f"Expected: {expected_answer}")
        print(f"Bot: {bot_answer}")
        print(f"Precision: {precision:.2f}, Recall: {recall:.2f}, Relevancy: {relevancy_score:.2f}\n")

    avg_precision = np.mean(precision_scores)
    avg_recall = np.mean(recall_scores)
    avg_relevancy = np.mean(relevancy_scores)

    print(f"Average Precision: {avg_precision:.2f}")
    print(f"Average Recall: {avg_recall:.2f}")
    print(f"Average Relevancy: {avg_relevancy:.2f}")

csv_path = "Updated_Testcase_Dataset_v2.csv"

# Run the evaluation
evaluate_rag_system(conversation_chain, csv_path)
# Out:
# /Users/ritikaverma/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Question: What is the procedure to make a claim for windscreen damage?
# Expected: To make a claim for windscreen damage, you need to contact the windscreen claims number provided, and the policy will cover the cost of replacing or repairing broken glass in the windscreen, sunroof, or windows.
# Bot: To make a claim for windscreen damage, you can call the Windscreen Claims number at 0800 328 9150 if you have Essentials, Comprehensive, or Comprehensive Plus cover with Churchill insurance. They will guide you through the claims process. Remember to refer to 'Section 5: Windscreen damage' on page 20 for details on the excess amounts for windscreen repairs and replacement.
# Precision: 0.32, Recall: 0.53, Relevancy: 0.87
#
# Question: Does the policy cover theft if the car is left unlocked?
# Expected: No, the policy does not cover theft or attempted theft if the car is left unlocked.
# Bot: No, the policy does not cover theft if the car is left unlocked. If the car is left unlocked, the policy will not pay a claim for theft or attempted theft.
# Precision: 0.64, Recall: 1.00, Relevancy: 0.95
#
# Question: Are electric car charging cables covered under the policy?
# Expected: Yes, the home charger and charging cables are considered an accessory to the car and are covered under 'Section 2: Fire and theft' or 'Section 4: Accidental damage.'
# Bot: Yes, your electric car's charging cables are covered under the policy. They are considered an accessory to your car and are covered under 'Section 2: Fire and theft'. Additionally, you are covered for any accidents involving your charging cables when they are attached to your car, such as someone tripping over the cable, as long as you have taken due care to prevent such accidents.
# Precision: 0.36, Recall: 0.70, Relevancy: 0.70
#
# Question: What is the coverage for personal accident?
# Expected: The policy covers up to £10,000 for personal accident under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car.
# Bot: Under the policy, personal accident coverage includes covering medical expenses for injuries resulting from a car accident, as long as no other car insurance policy covers the cost. The coverage will pay out up to the amounts specified in the policy document. Additionally, if you are insured for personal accident under multiple policies with the same insurance provider, they will only pay out on one policy. The coverage is limited to a maximum amount for both individuals involved in the accident.
# Precision: 0.25, Recall: 0.56, Relevancy: 0.73
#
# Question: What is DriveSure and how does it affect my premium?
# Expected: DriveSure is a telematics insurance product designed to capture how, when, and where your car is driven, based on driver-monitoring technology. This information is used to understand your driving style and give feedback, which in turn bases your premium on your driving record.
# Bot: DriveSure is a telematics insurance product that captures how, when, and where your car is driven to understand your driving style. This information is used to provide feedback and tailor your premium based on your driving record. So, DriveSure can affect your premium by potentially lowering it if you demonstrate safe driving habits.
# Precision: 0.54, Recall: 0.65, Relevancy: 0.95
#
# Question: How much will be covered for the theft of car keys?
# Expected: The policy covers up to £1,000 for the theft of car keys.
# Bot: Up to £1,000 will be covered for the theft of car keys, including the cost of replacing the stolen keys and the locks they fit, as well as any locksmith charges. This cover is included with Essentials, Comprehensive, and Comprehensive Plus policies.
# Precision: 0.19, Recall: 0.58, Relevancy: 0.75
#
# Question: What does Motor Legal Cover include?
# Expected: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court.
# Bot: Motor Legal Cover includes covering costs for legal action or defending yourself in court if your claim has a reasonable chance of succeeding. It covers fines, penalties, compensation, or damages ordered by a court, disputes with the insurance company under Motor Legal Cover, and certain limits for all claims related to the same incident. It also includes coverage for the appointed representative's fees and responsibilities to report to the insurance company.
# Precision: 0.23, Recall: 0.72, Relevancy: 0.88
#
# Question: Are courtesy cars available for all types of cover?
# Expected: Courtesy cars are available if you have Essentials or Comprehensive cover and your car is being repaired by an approved repairer.
# Bot: Courtesy cars are available for the following types of cover:
# - Third Party, Fire and Theft
# - Essentials
# - Comprehensive (if Guaranteed Hire Car Plus has not been selected)
#
# Courtesy cars are not included with all types of cover, so it depends on the specific type of policy you have.
# Precision: 0.20, Recall: 0.38, Relevancy: 0.77
#
# Question: What are the territorial limits for coverage?
# Expected: The territorial limits include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# Bot: The territorial limits for coverage under your car insurance policy include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man. Journeys between these places are also covered.
# Precision: 0.52, Recall: 1.00, Relevancy: 0.63
#
# Question: What should you do if you are involved in an accident?
# Expected: You should provide your personal details, policy number, car registration number, and a description of the loss or damage.
# Bot: If you are involved in an accident, here are some steps you should follow:
# 1. Safety first: Stop at the scene of the accident and call the police and emergency services if there are any injuries.
# 2. Take photos of the accident and vehicles involved if it's safe to do so.
# 3. Exchange contact details with the other party involved in the accident, including their vehicle registration, name, address, and telephone number.
# 4. If there are any witnesses, ask for their contact information.
# 5. Notify your insurance company as soon as possible with your personal details and policy number to start the claims process.
# Precision: 0.10, Recall: 0.39, Relevancy: 0.63
#
# Question: What is covered under Section 1: Liability?
# Expected: Section 1: Liability covers you if you're found to be legally responsible for an accident involving your car that injures or kills someone or damages their property.
# Bot: Under Section 1: Liability of the car insurance policy, the coverage includes legal costs or expenses to defend or represent you or any driver covered by the policy if you have to go to court due to an accident covered by the policy. It also covers liability to other people (third parties) if you are found to be legally responsible for an accident. The extent of the cover depends on the type of insurance you have, whether it's Third Party, Fire and Theft, Essentials, Comprehensive, or Comprehensive Plus.
# Precision: 0.25, Recall: 0.62, Relevancy: 0.78
#
# Question: What is the coverage for new car replacement under Comprehensive Plus?
# Expected: If your new car is stolen and not recovered, or written off, Comprehensive Plus will replace it with one of the same make and model if your car is less than 2 years old.
# Bot: The coverage for new car replacement under Comprehensive Plus includes the replacement of your car with one of the same make and model if it is less than 2 years old when it's stolen or damaged.
# Precision: 0.69, Recall: 0.73, Relevancy: 0.87
#
# Question: Are personal belongings covered under the policy?
# Expected: Yes, personal belongings are covered if they are lost or damaged by fire, theft, attempted theft, or accident while they’re in or on your car, up to £500 under Comprehensive Plus.
# Bot: Personal belongings are covered under the policy if they are damaged in your car and you are legally responsible for them.
# Precision: 0.47, Recall: 0.33, Relevancy: 0.79
#
# Question: What is the maximum number of claims allowed under Protected No Claim Discount?
# Expected: The maximum number of claims allowed under Protected No Claim Discount is 2 claims in 3 years.
# Bot: The maximum number of claims allowed under Protected No Claim Discount is 2 claims in 3 years.
# Precision: 1.00, Recall: 1.00, Relevancy: 1.00
# Question: What should you do if you need to make a claim?
# Expected: You should call the claims number provided, have your personal details, policy number, car registration number, and a description of the loss or damage ready.
# Bot: If you need to make a claim, you should contact the insurance company at 0345 878 6261. Make sure the incident happened within the territorial limits, you were covered on the date of the incident, and the legal proceedings will happen within the territorial limits. Additionally, take all reasonable precautions to minimize the cost of claims and prevent a claim from happening. If you do not follow the terms of the policy, the insurance company may refuse or withdraw from the claim.
# Precision: 0.12, Recall: 0.30, Relevancy: 0.59
#
# Question: Does the policy cover mechanical or electrical failure?
# Expected: No, the policy does not cover mechanical or electrical failure.
# Bot: No, the policy does not cover mechanical or electrical failure.
# Precision: 1.00, Recall: 1.00, Relevancy: 1.00
#
# Question: Can you use your car abroad under this policy?
# Expected: Yes, you can use your car abroad, but you may need a Green Card and should take a European Accident Statement with you.
# Bot: Yes, you can use your car abroad under this policy if you have Comprehensive cover and have added the Foreign Use Extension to your policy before you travel. If you do not have the Foreign Use Extension, your car insurance will only provide the minimum cover required by law in countries that are members of the European Union.
# Precision: 0.19, Recall: 0.38, Relevancy: 0.75
#
# Question: What happens if your car is written off?
# Expected: If your car is written off, the insurance will pay the market value of the car, and the car will become the property of the insurance company.
# Bot: If your car is written off, the insurance company will settle your claim based on that assessment. Depending on your policy, you may not be eligible for a courtesy car if your car is written off or stolen and not recovered. However, in some cases, the insurance company may provide you with a hire car for a specific period of time after the settlement.
# Precision: 0.24, Recall: 0.61, Relevancy: 0.64
#
# Question: What does the Vandalism Promise cover?
# Expected: The Vandalism Promise covers damage to your car that is a result of vandalism, and this won’t affect the No Claim Discount on your policy.
# Bot: The Vandalism Promise covers damage to your car that is a result of vandalism. If you claim for vandalism damage, it won't affect your No Claim Discount on the policy. However, it's important to note that damage caused by another vehicle is not covered under the Vandalism Promise.
# Precision: 0.49, Recall: 0.83, Relevancy: 0.94
#
# Question: What is the Uninsured Driver Promise?
# Expected: The Uninsured Driver Promise ensures that if you are hit by an uninsured driver, your No Claim Discount will not be affected and you will not need to pay an excess.
# Bot: The Uninsured Driver Promise is a feature included in car insurance policies such as Essential Comp, Comprehensive, and Comprehensive Plus. If you are in an accident that is not your fault and the other driver is uninsured, this promise ensures that your No Claim Discount will not be affected, and you will not have to pay an excess. If the accident is confirmed to be the fault of the uninsured driver, your excess will be repaid, your No Claim Discount will be restored, and any extra premium you've paid due to the claim will be refunded. You will need to provide details of the other vehicle and driver in such situations.
# Precision: 0.34, Recall: 0.85, Relevancy: 0.92
#
# Question: What should you do if your car keys are stolen?
# Expected: You must report the theft to the police, obtain a crime reference number, and pay the theft excess.
# Bot: If your car keys are stolen, you should report the theft to the police and obtain a crime reference number. Then, you should contact your insurance provider to inform them of the theft. They may provide cover to reprogram immobilisers, infrared handsets, alarms, and replace the stolen car keys and the locks they fit, including any locksmith charges. You may also need to pay the theft excess as per your insurance policy. Remember to take all reasonable steps to protect your car keys from theft.
# Precision: 0.18, Recall: 0.73, Relevancy: 0.55
#
# Question: Does the policy cover vandalism damage?
# Expected: Yes, the policy covers vandalism damage, and it won’t affect your No Claim Discount if you have Comprehensive or Comprehensive Plus cover.
# Bot: The Vandalism Promise covers damage to your car that is a result of vandalism. This coverage will not affect the No Claim Discount on your policy. However, it's important to note that the Vandalism Promise does not cover damage caused by another vehicle.
# Precision: 0.20, Recall: 0.33, Relevancy: 0.75
#
# Question: What happens if someone drives your car without being insured?
# Expected: The policy does not cover any claims if the car is driven by someone who is not insured on the policy.
# Bot: If someone drives your car without being named or listed as an excluded driver on your certificate of motor insurance or car insurance details, you may not be covered for any loss, damage, liability, or injury that happens while your car is being driven by that person. It's important to ensure that only authorized and insured drivers operate your vehicle to avoid potential coverage issues.
# Precision: 0.17, Recall: 0.50, Relevancy: 0.69
#
# Question: How can you claim for personal belongings under the policy?
# Expected: You can claim for personal belongings if they are lost or damaged by fire, theft, attempted theft, or accident while they are in or on your car, up to the specified amount.
# Bot: You can claim for personal belongings under the policy if they were damaged in a road traffic accident where you are legally responsible. You would need to report the vandalism to the police and follow the necessary steps outlined in the policy booklet for making a claim.
# Precision: 0.38, Recall: 0.52, Relevancy: 0.75
#
# Question: Are medical expenses covered if you are injured in a car accident?
# Expected: Yes, medical expenses are covered up to the specified amount if you are injured in a car accident.
# Bot: Yes, medical expenses are covered if you are injured in a car accident under the Personal Accident coverage provided by the Essential Comp and Comp+ policies. This coverage applies if no other car insurance policy covers the cost, and it will cover up to the amounts specified in the policy details.
# Precision: 0.38, Recall: 0.88, Relevancy: 0.87
#
# Question: What is included in the DriveSure policy?
# Expected: The DriveSure policy includes telematics insurance that captures driving data to understand your driving style and adjust your premium accordingly.
# Bot: The DriveSure policy is a telematics insurance product designed to capture how, when, and where your car is driven based on driver-monitoring technology. It helps understand your driving style, provide feedback, and base your premium on your driving record. When you have a policy that includes DriveSure, it also includes the DriveSure terms and conditions provided to you.
# Precision: 0.29, Recall: 0.72, Relevancy: 0.94
#
# Question: Does the policy cover damage caused by misfuelling?
# Expected: Yes, the policy covers damage caused by misfuelling, but it does not cover the cost of draining, flushing, or replacing the fuel.
# Bot: Yes, the policy covers any damage to your car caused by misfuelling. However, it does not cover the cost of draining, flushing, or replacing the fuel if the wrong fuel is put in your car.
# Precision: 0.57, Recall: 0.85, Relevancy: 0.92
#
# Question: What is the coverage for hotel expenses if you cannot drive your car after an accident?
# Expected: The policy covers up to £300 for hotel expenses if you cannot drive your car after an accident or loss covered under sections 2 or 4.
# Bot: The policy provides coverage for hotel expenses if you cannot drive your car after an accident that's covered under sections 2 or 4 of the policy. Specifically, it includes reimbursement for hotel expenses up to the amounts specified in the policy document.
# Precision: 0.58, Recall: 0.84, Relevancy: 0.83
# Question: How long can you use the courtesy car if your car is being repaired?
# Expected: You can use the courtesy car for the duration of the repair if it is being repaired by an approved repairer.
# Bot: If your car can be repaired and is driveable, you can use a courtesy car:
# - From the point your car goes in for repair until it is repaired if you use the approved repairer.
# - For up to 21 days in a row while your car is being repaired if you use your own repairer.
#
# If your car is not driveable, once you confirm the repair can start, you'll receive a courtesy car until the repair is completed if you use the approved repairer. The same 21-day limit applies if you choose your own repairer.
#
# It's important to note that your cover to drive the courtesy car is limited to the terms and exclusions in your certificate of motor insurance and policy. Additionally, a courtesy car may not always be available on the same day.
# Precision: 0.22, Recall: 0.79, Relevancy: 0.80
#
# Question: What does the Guaranteed Hire Car Plus cover provide?
# Expected: Guaranteed Hire Car Plus provides a hire car of a similar size to your own if your car is damaged in an incident, written off, or stolen.
# Bot: The Guaranteed Hire Car Plus cover provides a hire car of a similar size to your own if your car is damaged in an incident, written off, or stolen. It is designed to keep you mobile while your car is being repaired. The cover includes a specified amount of time you can have the hire car for, depending on whether you use an approved repairer or a different repairer.
# Precision: 0.48, Recall: 1.00, Relevancy: 0.85
#
# Average Precision: 0.39
# Average Recall: 0.68
# Average Relevancy: 0.80

# %% [markdown]
# ### Results:

# %% [markdown]
# - Average Precision: 0.39
# - Average Recall: 0.68
# - Average Relevancy: 0.80
