# %% [markdown]
# The following changed have been made:
# 1. PDF cleanup
# 2. MultiQueryRetriever

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import re
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.retrievers import MultiQueryRetriever
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.schema import HumanMessage, AIMessage
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from secret_key import my_openapi_key

os.environ["OPENAI_API_KEY"] = "my_openapi_key"

def get_pdf_text(pdf_paths):
    text = ""
    for pdf_path in pdf_paths:
        pdf_reader = PdfReader(pdf_path)
        for page in pdf_reader.pages:
            text += page.extract_text()

    # Clean the text: remove newlines, extra spaces, and other noise
    cleaned_text = re.sub(r'\s+', ' ', text)  # Replace multiple whitespace with a single space
    return cleaned_text

def get_text_chunks(text):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=300, chunk_overlap=100
    )
    chunks = text_splitter.split_text(text)
    return chunks

def get_vectorstore(text_chunks):
    embeddings = OpenAIEmbeddings()
    vectorstore = FAISS.from_texts(texts=text_chunks, embedding=embeddings)
    return vectorstore

def get_conversation_chain(vectorstore):
    llm = ChatOpenAI()
    memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

    # Define the prompt template for the LLMChain
    QUERY_PROMPT = PromptTemplate(template="You are a Churchill car insurance agent. Your task is to generate five\
    different versions of the given user {question} to retrieve relevant documents from\
    a vector database.Please provide variations of the query: {question} \
    to retrieve relevant documents from a vector database. By generating multiple perspectives on \
    the user question, your goal is to help the user overcome some of the limitations of the distance-based \
    similarity search.", input_variables=["question"])

    # Create the LLMChain for MultiQueryRetriever
    llm_chain = LLMChain(llm=llm, prompt=QUERY_PROMPT)

    retriever = MultiQueryRetriever.from_llm(
        vectorstore.as_retriever(),
        llm,
        prompt=QUERY_PROMPT
    )

    conversation_chain = ConversationalRetrievalChain.from_llm(
        llm=llm, retriever=retriever, memory=memory
    )
    return conversation_chain

def handle_userinput(conversation_chain, user_question, citation):
    response = conversation_chain({"question": user_question})
    response["citation"] = citation
    return response

# Specify the path to PDF file
pdf_paths = ["Doc/policy-booklet-0923.pdf"]

# Extract text from the PDF
raw_text = get_pdf_text(pdf_paths)

# Split the text into chunks
text_chunks = get_text_chunks(raw_text)

# Create a vector store from the text chunks
vectorstore = get_vectorstore(text_chunks)

# Create a conversation chain with the vector store
conversation_chain = get_conversation_chain(vectorstore)

# Example user input
user_question = "What is covered in case of theft?"

# Specify the citation (will be improved to extract from the document)
citation = "Source: Policy document"

# Handle the user input and get a response
response = handle_userinput(conversation_chain, user_question, citation)

# Display the response
for message in response["chat_history"]:
    if isinstance(message, HumanMessage):
        print(f"User: {message.content}")
    elif isinstance(message, AIMessage):
        print(f"Bot: {message.content}")

# Print the citation
print(response["citation"])
# Out:
# User: What is covered in case of theft?
# Bot: If your car is stolen, damaged as a result of theft, or damaged by fire, lightning, or an explosion, your insurance may cover the costs. The cover for theft typically includes repairing the damage, replacing stolen items, or settling the claim with a payment. However, specific details may vary based on the type of insurance you have, such as TPFT Essential Comp or Comp+. It's best to refer to your car insurance policy details for precise information on what is covered in case of theft.
# Source: Policy document

# %% [markdown]
# ### Using synthetic dataset for training
# (Few-shots prompting)

# %%
import os
import re
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.retrievers import MultiQueryRetriever
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.schema import HumanMessage, AIMessage
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

os.environ["OPENAI_API_KEY"] = "my_openapi_key"

def get_pdf_text(pdf_paths):
    text = ""
    for pdf_path in pdf_paths:
        pdf_reader = PdfReader(pdf_path)
        for page in pdf_reader.pages:
            text += page.extract_text()

    # Clean the text: remove newlines, extra spaces, and other noise
    cleaned_text = re.sub(r'\s+', ' ', text)  # Replace multiple whitespace with a single space
    return cleaned_text

def get_text_chunks(text):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=300, chunk_overlap=100
    )
    chunks = text_splitter.split_text(text)
    return chunks

def get_vectorstore(text_chunks):
    embeddings = OpenAIEmbeddings()
    vectorstore = FAISS.from_texts(texts=text_chunks, embedding=embeddings)
    return vectorstore

def get_conversation_chain(vectorstore):
    llm = ChatOpenAI()
    memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

    # Define the prompt template for the LLMChain
    QUERY_PROMPT = PromptTemplate(template="You are a Churchill car insurance agent. Your task is to generate five\
    different versions of the given user {question} to retrieve relevant documents from\
    a vector database.Please provide variations of the query: {question} \
    to retrieve relevant documents from a vector database. By generating multiple perspectives on \
    the user question, your goal is to help the user overcome some of the limitations of the distance-based \
    similarity search.", input_variables=["question"])

    # Create the LLMChain for MultiQueryRetriever
    llm_chain = LLMChain(llm=llm, prompt=QUERY_PROMPT)

    retriever = MultiQueryRetriever.from_llm(
        vectorstore.as_retriever(),
        llm,
        prompt=QUERY_PROMPT
    )

    conversation_chain = ConversationalRetrievalChain.from_llm(
        llm=llm, retriever=retriever, memory=memory
    )
    return conversation_chain

def handle_userinput(conversation_chain, user_question, citation):
    response = conversation_chain({"question": user_question})
    response["citation"] = citation
    return response

# Specify the path to your PDF file
pdf_paths = ["Doc/policy-booklet-0923.pdf"]

# Extract text from the PDF
raw_text = get_pdf_text(pdf_paths)

# Split the text into chunks
text_chunks = get_text_chunks(raw_text)

# Create a vector store from the text chunks
vectorstore = get_vectorstore(text_chunks)

# Load additional dataset
dataset_path = "Updated_Testcase_Dataset_v2.csv"
df = pd.read_csv(dataset_path)

# Prepare additional dataset text chunks
additional_text_chunks = []
for index, row in df.iterrows():
    question_excerpt_answer = f"Question: {row['Question']} Excerpt: {row['Excerpt']} Answer: {row['Answer']}"
    additional_text_chunks.extend(get_text_chunks(question_excerpt_answer))

# Combine text chunks from PDF and additional dataset
all_text_chunks = text_chunks + additional_text_chunks

# Create a new vector store with combined text chunks
vectorstore = get_vectorstore(all_text_chunks)

# Create a new conversation chain with the updated vector store
conversation_chain = get_conversation_chain(vectorstore)

# Example user input
user_question = "Give me the numebr to call If I need to make a claim"

# Specify the citation
citation = "Source: Policy document and additional dataset"

# Handle the user input and get a response
response = handle_userinput(conversation_chain, user_question, citation)

# Display the response
for message in response["chat_history"]:
    if isinstance(message, HumanMessage):
        print(f"User: {message.content}")
    elif isinstance(message, AIMessage):
        print(f"Bot: {message.content}")

# Print the citation
print(response["citation"])
# Out:
# User: Give me the numebr to call If I need to make a claim
# Bot: If you need to make a claim, you should call 0345 878 6261.
# Source: Policy document and additional dataset

# %% [markdown]
# ### Adding metadata
# Trying to add more context

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1

# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.2.4-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.2.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.2.5)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (0.1.77)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.8 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (0.2.1)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (2.7.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain_community) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2024.6.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (2.18.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain_community
# Successfully installed dataclasses-json-0.6.7 langchain_community-0.2.4 marshmallow-3.21.3 mypy-extensions-1.0.0 typing-inspect-0.9.0

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-0.2.3-py3-none-any.whl (974 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.0/974.0 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_core-0.2.5-py3-none-any.whl (314 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 8.1 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.1-py3-none-any.whl (23 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.77-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.7.3)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.2 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: packaging, orjson, jsonpointer, jsonpatch, langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
# Successfully installed jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.3 langchain-core-0.2.5 langchain-text-splitters-0.2.1 langsmith-0.1.77 orjson-3.10.4 packaging-23.2

# %%
# !pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 50.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from faiss-cpu) (1.25.2)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.8.0

# %%
# !pip -q install tiktoken
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.4 MB/s eta 0:00:00

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.33.0-py3-none-any.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.6.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.2 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.4)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.33.0

# %% [markdown]
# ### Final RAG code

# %%
import os
import re
import pandas as pd
from PyPDF2 import PdfReader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.chains import ConversationalRetrievalChain
from langchain.retrievers import MultiQueryRetriever
from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate
from langchain.schema import HumanMessage, AIMessage
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# %%
os.environ["OPENAI_API_KEY"] = "my_openapi_key"

def get_pdf_text(pdf_paths):
    text = ""
    for pdf_path in pdf_paths:
        pdf_reader = PdfReader(pdf_path)
        for page in pdf_reader.pages:
            text += page.extract_text()

    # Clean the text: remove newlines, extra spaces, and other noise
    cleaned_text = re.sub(r'\s+', ' ', text)  # Replace multiple whitespace with a single space
    return cleaned_text

def get_text_chunks_with_metadata(text, source, page_number=None):
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=300, chunk_overlap=100)
    chunks = text_splitter.split_text(text)

    chunk_metadata = []

    for i, chunk in enumerate(chunks):
        metadata = {
            "source": source,
            "page_number": page_number,
            "chunk_index": i
        }
        chunk_metadata.append((chunk, metadata))

    return chunk_metadata

def get_vectorstore(text_chunks_with_metadata):
    embeddings = OpenAIEmbeddings()
    texts = [text for text, metadata in text_chunks_with_metadata]
    metadatas = [metadata for text, metadata in text_chunks_with_metadata]
    vectorstore = FAISS.from_texts(texts=texts, embedding=embeddings, metadatas=metadatas)
    return vectorstore

def get_conversation_chain(vectorstore):
    llm = ChatOpenAI(temperature=0)
    memory = ConversationBufferMemory(memory_key="chat_history", return_messages=True)

    # Define the prompt template for the LLMChain
    QUERY_PROMPT = PromptTemplate(template="You are a Churchill car insurance agent. Your task is to generate five\
    different versions of the given user {question} to retrieve relevant documents from\
    a vector database.Please provide variations of the query: {question} \
    to retrieve relevant documents from a vector database. By generating multiple perspectives on \
    the user question, your goal is to help the user overcome some of the limitations of the distance-based \
    similarity search.", input_variables=["question"])

    # Create the LLMChain for MultiQueryRetriever
    llm_chain = LLMChain(llm=llm, prompt=QUERY_PROMPT)

    retriever = MultiQueryRetriever.from_llm(
        vectorstore.as_retriever(),
        llm,
        prompt=QUERY_PROMPT
    )

    conversation_chain = ConversationalRetrievalChain.from_llm(
        llm=llm, retriever=retriever, memory=memory
    )
    return conversation_chain

def handle_userinput(conversation_chain, user_question, citation):
    response = conversation_chain({"question": user_question})
    response["citation"] = citation
    return response

# Specify the path to your PDF file
pdf_paths = ["/content/sample_data/policy-booklet-0923.pdf"]

# Extract text from the PDF and add metadata
text_chunks_with_metadata = []
for pdf_path in pdf_paths:
    raw_text = get_pdf_text([pdf_path])
    text_chunks_with_metadata.extend(get_text_chunks_with_metadata(raw_text, pdf_path))

# Create a vector store from the text chunks with metadata
vectorstore = get_vectorstore(text_chunks_with_metadata)

# Load additional dataset
dataset_path = "/content/sample_data/TrainingSet_10.csv"
df = pd.read_csv(dataset_path)

# Prepare additional dataset text chunks with metadata
additional_text_chunks_with_metadata = []
for index, row in df.iterrows():
    question_excerpt_answer = f"Question: {row['Question']} Excerpt: {row['Excerpt']} Answer: {row['Answer']}"
    additional_text_chunks_with_metadata.extend(get_text_chunks_with_metadata(question_excerpt_answer, "dataset"))

# Combine text chunks from PDF and additional dataset
all_text_chunks_with_metadata = text_chunks_with_metadata + additional_text_chunks_with_metadata

# Create a new vector store with combined text chunks with metadata
vectorstore = get_vectorstore(all_text_chunks_with_metadata)

# Create a new conversation chain with the updated vector store
conversation_chain = get_conversation_chain(vectorstore)

# Example user input
user_question = "What is covered in case of theft?"

# Specify the citation
citation = "Source: Policy document and additional dataset"

# Handle the user input and get a response
response = handle_userinput(conversation_chain, user_question, citation)

# Display the response
for message in response["chat_history"]:
    if isinstance(message, HumanMessage):
        print(f"User: {message.content}")
    elif isinstance(message, AIMessage):
        print(f"Bot: {message.content}")

# Print the citation
print(response["citation"])
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 0.3.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# User: What is covered in case of theft?
# Bot: In case of theft, the policy covers situations where your car is stolen, damaged by an attempted theft, or damaged by fire.
# Source: Policy document and additional dataset

# %% [markdown]
# ### Evaluation
# Using local LLM and prompt engineering, using the same old dataset.

# %%
from langchain_community.llms.ollama import Ollama

# %%
# !ollama list
# Out:
# NAME                   	ID          	SIZE  	MODIFIED
# llama3:latest          	a6990ed6be41	4.7 GB	6 weeks ago
# mistral:latest         	61e88e884507	4.1 GB	6 weeks ago
# nomic-embed-text:latest	0a109f422b47	274 MB	6 weeks ago
# phi3:latest            	a2c89ceaed85	2.3 GB	5 weeks ago

# %%
EVAL_PROMPT = """
Expected Response: {expected_response}
Actual Response: {actual_response}
---
(Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
"""


# Function to evaluate the RAG system using Ollama model
def evaluate_rag_system_from_csv(conversation_chain, csv_path):
    df = pd.read_csv(csv_path)
    correct = 0
    total = len(df)
    eval_model = Ollama(model="mistral")  # Initialize the Ollama model

    for index, row in df.iterrows():
        question = row['Question']
        expected_answer = row['Answer']

        response = handle_userinput(conversation_chain, question, "Source: Policy document and additional dataset")
        bot_answer = response["chat_history"][-1].content  # Last message is the bot's response

        eval_prompt = EVAL_PROMPT.format(expected_response=expected_answer, actual_response=bot_answer)

        # Invoke the Ollama model with the evaluation prompt
        evaluation_results_str = eval_model.invoke(eval_prompt)
        evaluation_results_str_cleaned = evaluation_results_str.strip().lower()

        print(eval_prompt)

        if "true" in evaluation_results_str_cleaned:
            print("\033[92m" + f"Response: {evaluation_results_str_cleaned}" + "\033[0m")
            correct += 1
        elif "false" in evaluation_results_str_cleaned:
            print("\033[91m" + f"Response: {evaluation_results_str_cleaned}" + "\033[0m")
        else:
            print("\033[93m" + f"Unexpected Response: {evaluation_results_str_cleaned}" + "\033[0m")

    accuracy = correct / total
    print(f"Accuracy: {accuracy * 100:.2f}%")


# Path to your CSV file
csv_path = "Updated_Testcase_Dataset_v2.csv"

# Run the evaluation
evaluate_rag_system_from_csv(conversation_chain, csv_path)
# Out:
# Expected Response: To make a claim for windscreen damage, you need to contact the windscreen claims number provided, and the policy will cover the cost of replacing or repairing broken glass in the windscreen, sunroof, or windows.
# Actual Response: To make a claim for windscreen damage, you need to contact the windscreen claims number provided, which is 0800 328 9150. This will enable you to report the damage and initiate the process for the replacement or repair of the broken glass in the windscreen, sunroof, or windows of your car.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response provides the specific claims number for reporting windscreen damage and confirms that the policy covers the cost of replacement or repair of broken glass in the windscreen, sunroof, or windows.
#
# Expected Response: No, the policy does not cover theft or attempted theft if the car is left unlocked.
# Actual Response: No, the policy does not cover theft or attempted theft if the car is left unlocked.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Unexpected Response: yes, the expected and actual responses match. both state that the policy does not cover theft or attempted theft if the car is left unlocked.
#
# Expected Response: Yes, the home charger and charging cables are considered an accessory to the car and are covered under 'Section 2: Fire and theft' or 'Section 4: Accidental damage.'
# Actual Response: Yes, electric car charging cables are considered an accessory to the car and are covered under 'Section 2: Fire and theft' or 'Section 4: Accidental damage' of the policy.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response correctly states that electric car charging cables are considered an accessory to the car and are covered under 'section 2: fire and theft' or 'section 4: accidental damage' of the policy.
#
# Expected Response: The policy covers up to £10,000 for personal accident under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car.
# Actual Response: The policy covers up to £10,000 for personal accident under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately states that the policy covers up to £10,000 for personal accident under comprehensive plus cover in the event of injury or death caused by a car accident involving the insured's car.
#
# Expected Response: DriveSure is a telematics insurance product designed to capture how, when, and where your car is driven, based on driver-monitoring technology. This information is used to understand your driving style and give feedback, which in turn bases your premium on your driving record.
# Actual Response: DriveSure is a telematics insurance product designed to capture how, when, and where your car is driven, based on driver-monitoring technology. This information is used to understand your driving style and give feedback, which in turn bases your premium on your driving record.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately describes drivesure as a telematics insurance product that uses driver-monitoring technology to capture driving data, provide feedback based on driving style, and determine premiums based on driving record.
#
# Expected Response: The policy covers up to £1,000 for the theft of car keys.
# Actual Response: The policy covers up to £1,000 for the theft of car keys.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response and expected response are identical in this case. they both state that the policy covers up to £1,000 for the theft of car keys.
#
# Expected Response: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court.
# Actual Response: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court. It can only help with problems related to laws that apply in the UK.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response adds more specificity to the expected response by specifying that motor legal cover applies only to problems related to uk laws.
#
# Expected Response: Courtesy cars are available if you have Essentials or Comprehensive cover and your car is being repaired by an approved repairer.
# Actual Response: Courtesy cars are available if you have Essentials or Comprehensive cover and your car is being repaired by an approved repairer.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the expected and actual responses are identical, meaning they convey the same information.
#
# Expected Response: The territorial limits include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# Actual Response: The territorial limits for coverage include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response correctly states that the territorial limits for coverage include great britain, northern ireland, the channel islands, and the isle of man.
#
# Expected Response: You should provide your personal details, policy number, car registration number, and a description of the loss or damage.
# Actual Response: If you are involved in an accident, you should follow these steps:
# 1. Stop at the scene of the accident and ensure safety.
# 2. Call the police and emergency services if there are any injuries or if any driver involved hasn’t stopped.
# 3. Take photos of the accident if it’s safe to do so, including any vehicles involved.
# 4. Exchange personal details, policy number, car registration number, and a description of the loss or damage with the other party.
# 5. Collect other driver/vehicle details such as their contact information, vehicle registration, name, address, and telephone number.
# 6. Do not accept blame for the accident.
# 7. If there are any witnesses, ask for their contact information.
# 8. If you receive any communication related to the accident, keep it handy and inform your insurance company.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response provides accurate steps to follow in case of a car accident. however, it's important to note that step 4 is an essential part of the process and should be done even if the other party refuses to exchange information or tries to leave the scene without providing their details.
#
# Expected Response: Section 1: Liability covers you if you're found to be legally responsible for an accident involving your car that injures or kills someone or damages their property.
# Actual Response: Section 1: Liability in the car insurance policy covers injury to third parties or damage caused to their property, not to the car being driven. It also includes liability for automated cars in Great Britain. This section provides cover for accidents caused by your automated car when it is lawfully driving.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response clarifies that section 1 of a car insurance policy covers injury to third parties and damage caused to their property, not to the insured vehicle itself. additionally, it includes coverage for automated cars in great britain and accidents caused by these vehicles when they are lawfully driving.
# Expected Response: If your new car is stolen and not recovered, or written off, Comprehensive Plus will replace it with one of the same make and model if your car is less than 2 years old.
# Actual Response: If your new car is stolen and not recovered, or written off, Comprehensive Plus will replace it with one of the same make and model.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately states that if a new car is stolen and not recovered, or written off, comprehensive plus will replace it with one of the same make and model. however, the expected response adds the condition that the car must be less than 2 years old. this additional detail is not mentioned in the actual response but does not affect the overall accuracy of the statement.
#
# Expected Response: Yes, personal belongings are covered if they are lost or damaged by fire, theft, attempted theft, or accident while they’re in or on your car, up to £500 under Comprehensive Plus.
# Actual Response: The coverage for personal belongings under the policy includes payment for personal belongings if they are lost or damaged by fire, theft, attempted theft, or accident while they are in or on your car. The policy provides coverage for personal portable electronic or entertainment equipment that is not specifically designed to be used in your car as well.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response expands upon the expected response by providing additional details about the coverage of personal belongings, including portable electronic or entertainment equipment, under the car insurance policy.
#
# Expected Response: The maximum number of claims allowed under Protected No Claim Discount is 2 claims in 3 years.
# Actual Response: The maximum number of claims allowed under Protected No Claim Discount is 2 claims in 3 years of insurance in a row.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response is an accurate reflection of the statement made in the expected response. the key difference between the two responses is the inclusion of the phrase "in a row" in the actual response, which specifies that the two claims must occur consecutively within the 3-year period to be eligible for the protected no claim discount.
#
# Expected Response: You should call the claims number provided 0345 878 6261
# Windscreen claims 0800 328 9150 , have your personal details, policy number, car registration number, and a description of the loss or damage ready.
# Actual Response: If you need to make a claim, you should follow these steps: provide your personal details, policy number, car registration number, and a description of the loss or damage.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response instructs the reader to provide their personal details, policy number, car registration number, and a description of the loss or damage when making a claim. this aligns with the expected response which also includes these steps. however, the actual response does not include specific phone numbers as in the expected response. therefore, the instructions for calling the claims number are missing in the actual response.
#
# Expected Response: No, the policy does not cover mechanical or electrical failure.
# Actual Response: No, the policy does not cover mechanical or electrical failure.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the expected and actual responses are identical, both stating that the policy does not cover mechanical or electrical failure.
#
# Expected Response: Yes, you can use your car abroad, but you may need a Green Card and should take a European Accident Statement with you.
# Actual Response: Yes, you can use your car abroad under this policy. The cover depends on the type of policy you have and where you are driving. The policy provides details on where you can drive and the conditions for driving abroad.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response acknowledges that using a car abroad is covered under the policy but mentions that the coverage depends on the type of policy and where you are driving. it also correctly states that the policy provides details on these conditions. however, it does not explicitly mention the requirement for a green card or the european accident statement, but it's common knowledge among travelers that these documents might be needed when driving abroad, so it's important to check with the insurance provider for specific requirements.
#
# Expected Response: If your car is written off, the insurance will pay the market value of the car, and the car will become the property of the insurance company.
# Actual Response: If your car is written off, typically the insurance company will pay you the actual cash value of your car at the time of the accident, minus any deductible you may have. This amount can be used towards purchasing a new vehicle. It's important to check your policy for specific details on how your insurance company handles write-offs.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response correctly states that the insurance company pays the actual cash value of the car to the policyholder, and that this amount can be used towards purchasing a new vehicle. however, it is important to note that there may be a deductible that needs to be paid out of pocket by the policyholder before receiving the payment from the insurance company.
#
# Expected Response: The Vandalism Promise covers damage to your car that is a result of vandalism, and this won’t affect the No Claim Discount on your policy.
# Actual Response: The Vandalism Promise covers damage to your car that is a result of vandalism. If you claim for such damage, it won't affect the No Claim Discount on your policy. However, it's important to note that the Vandalism Promise doesn't cover damage caused by another vehicle.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response correctly states that making a claim under the vandalism promise won't affect the no claim discount, but it also clarifies that this coverage doesn't extend to damage caused by another vehicle.
#
# Expected Response: The Uninsured Driver Promise ensures that if you are hit by an uninsured driver, your No Claim Discount will not be affected and you will not need to pay an excess.
# Actual Response: The Uninsured Driver Promise is a feature included in certain types of car insurance policies. It provides coverage if you are involved in an accident that is not your fault and the other driver is uninsured. The promise helps you claim your uninsured losses from the person who was to blame for the accident. This can include compensation for bodily injury or other losses.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response correctly describes the uninsured driver promise as a feature of car insurance policies that provides coverage for uninsured losses if you are involved in an accident caused by an uninsured driver. it also mentions that this can include compensation for bodily injury and other losses.
#
# Expected Response: You must report the theft to the police, obtain a crime reference number, and pay the theft excess.
# Actual Response: If your car keys are stolen, you should report the theft to the police and obtain a crime reference number. After that, you should contact your insurance provider to inform them of the theft and provide them with the necessary information. They will then assist you in replacing your stolen car keys and the locks they fit, including any locksmith charges, as per the policy coverage.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response advises reporting the theft to the police and obtaining a crime reference number, which aligns with the expected response. additionally, it suggests contacting the insurance provider to replace the stolen keys and locks, which is an appropriate next step after the theft report.
# Expected Response: Yes, the policy covers vandalism damage, and it won’t affect your No Claim Discount if you have Comprehensive or Comprehensive Plus cover.
# Actual Response: Yes, the policy covers vandalism damage. If you claim for damage to your car that’s a result of vandalism, it won’t affect the No Claim Discount on the policy.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response correctly states that vandalism damage is covered under the insurance policy and that it will not affect the no claim discount if comprehensive or comprehensive plus cover is in place.
#
# Expected Response: The policy does not cover any claims if the car is driven by someone who is not insured on the policy.
# Actual Response: If someone drives your car without being insured and gets into an accident, the insurance policy may not cover the damages or losses. This could result in you being personally liable for any costs related to the accident. Additionally, if the person driving your car without insurance gets into an accident, it could lead to legal consequences for both the driver and the owner of the vehicle.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response expands on the expected response by adding potential legal consequences for both the driver and the owner of the vehicle if someone drives an uninsured person's car and gets into an accident. however, the core message remains consistent with the expected response - that an insurance policy may not cover damages or losses resulting from an accident caused by an uninsured driver.
#
# Expected Response: You can claim for personal belongings if they are lost or damaged by fire, theft, attempted theft, or accident while they are in or on your car, up to the specified amount.
# Actual Response: To claim personal belongings under your car insurance policy, you should ensure that they meet the criteria mentioned in your policy booklet. This includes having the belongings in your car or on your car, in your locked private garage, or plugged into your car. Additionally, you should follow the steps outlined in the policy booklet to make a claim, which may involve providing your personal details, policy number, car registration number, and a description of the loss or damage. If you need further assistance, you can contact the provided important numbers for help with the claims process.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response provides more detailed information on how to claim for personal belongings under car insurance, emphasizing the need to follow the policy booklet and providing some examples of where the belongings can be located. it also includes steps to make a claim and contact details for assistance.
#
# Expected Response: Yes, medical expenses are covered up to the specified amount if you are injured in a car accident.
# Actual Response: If you are injured in a car accident, medical expenses such as hospital bills, doctor's fees, and other necessary medical treatments are covered under the policy. The coverage includes expenses related to injuries sustained in the accident, as long as no other car insurance policy covers the cost. The policy will cover up to the specified amounts mentioned in the policy booklet.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately states that medical expenses are covered under the car insurance policy up to the specified amount if the policyholder is injured in a car accident, and that this coverage applies only when no other car insurance policy covers the cost.
#
# Expected Response: The DriveSure policy includes telematics insurance that captures driving data to understand your driving style and adjust your premium accordingly.
# Actual Response: The DriveSure policy includes capturing data on how, when, and where your car is driven using driver-monitoring technology. This information is used to understand your driving style and provide feedback. Additionally, the DriveSure policy may have terms and conditions that need to be read and understood.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response expands upon the expected response by providing more detail about the driver-monitoring technology used in the drivesure policy and emphasizing that the information collected is used to understand driving style and provide feedback. additionally, it reminds readers that there may be terms and conditions to be read and understood.
#
# Expected Response: Yes, the policy covers damage caused by misfuelling, but it does not cover the cost of draining, flushing, or replacing the fuel.
# Actual Response: Yes, the policy covers any damage to your car caused by misfuelling. However, it does not cover the cost of draining, flushing, or replacing the fuel if the wrong fuel is put in your car.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately conveys that the policy covers damage caused by misfuelling, but does not cover the cost of draining, flushing, or replacing the fuel in case of wrong fuel being put into the car.
#
# Expected Response: The policy covers up to £300 for hotel expenses if you cannot drive your car after an accident or loss covered under sections 2 or 4.
# Actual Response: The coverage for hotel expenses if you cannot drive your car after an accident is up to £250 with the Comp policy and up to £300 with the Comp+ policy.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, but with some clarifications:
#
# 1. the actual response correctly mentions that there is a difference in coverage limits between comp and comp+ policies regarding hotel expenses when you cannot drive your car after an accident.
# 2. however, the expected response incorrectly states that the policy covers up to £300 for hotel expenses without specifying which policy (comp or comp+).
# 3. both responses indicate that this coverage applies only if the accident is covered under sections 2 or 4.
#
# Expected Response: You can use the courtesy car for the duration of the repair if it is being repaired by an approved repairer.
# Actual Response: The duration of use for the courtesy car while your car is being repaired depends on the type of cover you have and whether you are using an approved repairer or your own repairer. If your car is being repaired by an approved repairer, you will get a courtesy car to keep you mobile while your car is being repaired, subject to availability. If you have Essentials or Comprehensive cover, you will receive a courtesy car for the duration of the repair.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response provides more detailed information than the expected response, but it still matches in that if you use an approved repairer, you will receive a courtesy car during the repair process, subject to availability.
#
# Expected Response: Guaranteed Hire Car Plus provides a hire car of a similar size to your own if your car is damaged in an incident, written off, or stolen.
# Actual Response: The Guaranteed Hire Car Plus cover provides a hire car for a specified amount of time if your car is being repaired by an approved repairer. If the insurance company cannot provide you with a hire car for certain reasons, they will repay your travel costs. Additionally, this cover may be extended if you are unable to use your car for a specific reason.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately describes the guaranteed hire car plus cover, stating that it provides a hire car while the insured vehicle is being repaired by an approved repairer, and if certain conditions are met, the insurance company will repay travel costs instead. it also mentions that this cover may be extended in specific circumstances where the insured is unable to use their car.
# Accuracy: 96.67%

# %% [markdown]
# Accuracy improved from 80% to 96%.

# %% [markdown]
# ### Testing with mixed Dataset(50): 30 generated, 20 added manually
# Questions are added post researching the top car insurance policy questions.

# %%
EVAL_PROMPT = """
Expected Response: {expected_response}
Actual Response: {actual_response}
---
(Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
"""


# Function to evaluate the RAG system using Ollama model
def evaluate_rag_system_from_csv(conversation_chain, csv_path):
    df = pd.read_csv(csv_path)
    correct = 0
    total = len(df)
    eval_model = Ollama(model="mistral")  # Initialize the Ollama model

    for index, row in df.iterrows():
        question = row['Question']
        expected_answer = row['Answer']

        response = handle_userinput(conversation_chain, question, "Source: Policy document and additional dataset")
        bot_answer = response["chat_history"][-1].content  # Last message is the bot's response

        eval_prompt = EVAL_PROMPT.format(expected_response=expected_answer, actual_response=bot_answer)

        # Invoke the Ollama model with the evaluation prompt
        evaluation_results_str = eval_model.invoke(eval_prompt)
        evaluation_results_str_cleaned = evaluation_results_str.strip().lower()

        print(eval_prompt)

        if "true" in evaluation_results_str_cleaned:
            print("\033[92m" + f"Response: {evaluation_results_str_cleaned}" + "\033[0m")
            correct += 1
        elif "false" in evaluation_results_str_cleaned:
            print("\033[91m" + f"Response: {evaluation_results_str_cleaned}" + "\033[0m")
        else:
            print("\033[93m" + f"Unexpected Response: {evaluation_results_str_cleaned}" + "\033[0m")

    accuracy = correct / total
    print(f"Accuracy: {accuracy * 100:.2f}%")


# Path to evaluation CSV file
csv_path = "Cleaned_Testcase_Dataset.csv"

# Run the evaluation
evaluate_rag_system_from_csv(conversation_chain, csv_path)
# Out:
# Expected Response: To make a claim for windscreen damage, you need to contact the windscreen claims number provided, and the policy will cover the cost of replacing or repairing broken glass in the windscreen, sunroof, or windows.
# Actual Response: To make a claim for windscreen damage, you need to contact the windscreen claims number provided in your policy documents. The insurance company will guide you through the process and cover the cost of replacing or repairing the broken glass in the windscreen, sunroof, or windows.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response is similar to the expected response, but it provides more detail about the process and who will guide the policyholder through it. both responses indicate that contacting the windscreen claims number in the policy documents is necessary to make a claim and that the insurance company will cover the cost of repair or replacement.
#
# Expected Response: No, the policy does not cover theft or attempted theft if the car is left unlocked.
# Actual Response: No, the policy does not cover theft or attempted theft if the car is left unlocked.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the expected and actual responses are identical, both stating that the policy does not cover theft or attempted theft if the car is left unlocked.
#
# Expected Response: Yes, the home charger and charging cables are considered an accessory to the car and are covered under 'Section 2: Fire and theft' or 'Section 4: Accidental damage.'
# Actual Response: Yes, the home charger and charging cables are considered an accessory to the car and are covered under 'Section 2: Fire and theft' or 'Section 4: Accidental damage.'
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response is correct according to the information provided in the expected response. the home charger and charging cables are considered accessories to the car, and they fall under 'section 2: fire and theft' or 'section 4: accidental damage.' these sections typically cover damages or losses related to the vehicle and its accessories.
#
# Expected Response: The policy covers up to Â£10,000 for personal accident under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car.
# Actual Response: The policy covers up to £10,000 for personal accident under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response accurately states that the policy covers up to £10,000 for personal accident under comprehensive plus cover if the insured or their partner are accidentally injured or killed in a car accident involving their car.
#
# Expected Response: DriveSure is a telematics insurance product designed to capture how, when, and where your car is driven, based on driver-monitoring technology. This information is used to understand your driving style and give feedback, which in turn bases your premium on your driving record.
# Actual Response: DriveSure is a telematics insurance product designed to capture how, when, and where your car is driven, based on driver-monitoring technology. This information is used to understand your driving style and provide feedback. The impact on your premium would depend on how you drive based on the data collected by DriveSure. Safe and responsible driving habits could potentially lead to lower premiums, while risky driving behavior may result in higher premiums.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response provides additional information about how the data collected by drivesure is used to determine premiums, which was not explicitly stated in the expected response but is an accurate and relevant detail.
#
# Expected Response: The policy covers up to Â£1,000 for the theft of car keys.
# Actual Response: The policy covers up to £1,000 for the theft of car keys.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the expected and actual responses are identical in this case. both state that the policy covers up to £1,000 for the theft of car keys.
#
# Expected Response: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court.
# Actual Response: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response accurately describes what motor legal cover is. this type of insurance coverage helps pay for the costs associated with taking legal action or defending oneself in court related to a motor vehicle incident.
#
# Expected Response: Courtesy cars are available if you have Essentials or Comprehensive cover and your car is being repaired by an approved repairer.
# Actual Response: Courtesy cars are available if you have Essentials or Comprehensive cover and your car is being repaired by an approved repairer.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response matches the expected response in meaning and content. both responses state that courtesy cars are available only when one has essentials or comprehensive cover and their car is being repaired by an approved repairer.
#
# Expected Response: The territorial limits include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# Actual Response: The territorial limits for coverage include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response correctly identifies the territorial limits for coverage as including great britain, northern ireland, the channel islands, and the isle of man.
#
# Expected Response: You should provide your personal details, policy number, car registration number, and a description of the loss or damage.
# Actual Response: If you are involved in an accident, you should first stop at the scene of the accident and ensure safety. If there are any injuries or if any driver involved hasn’t stopped, call the police and emergency services. Take photos of the accident if it’s safe to do so, including any vehicles involved. Exchange personal details, policy numbers, car registration numbers, and a description of the loss or damage with the other party involved.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response provides additional steps beyond just exchanging personal details, policy numbers, car registration numbers, and a description of the loss or damage, which is what was asked for in the expected response. however, these steps are important to follow after an accident to ensure safety and gather necessary information.
#
# Expected Response: Section 1: Liability covers you if you're found to be legally responsible for an accident involving your car that injures or kills someone or damages their property.
# Actual Response: Under Section 1: Liability, your car insurance policy provides cover for liability to other people (third parties) within the territorial limits in the countries listed in the 'Countries where you have minimum cover'. This includes injury to anyone working with or for the driver of the car, except as set out in the Road Traffic Act. Additionally, there is coverage for accidents caused by your automated car when it is lawfully driving. If you need more details or have specific questions about the level of cover, it's recommended to refer to the specific details provided under each section in your policy booklet.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately reflects the content of section 1: liability as outlined in most car insurance policies. it specifies that the policy provides coverage for third-party liability within the specified territorial limits, including injuries to those working with or for the driver and coverage for accidents caused by an automated car while lawfully driving.
# Expected Response: If your new car is stolen and not recovered, or written off, Comprehensive Plus will replace it with one of the same make and model if your car is less than 2 years old.
# Actual Response: If your new car is stolen and not recovered, or written off, Comprehensive Plus will replace it with one of the same make and model. This cover is provided as long as you are the first and only registered keeper of the car.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response correctly states that comprehensive plus will replace a new car (that is stolen and not recovered or written off) with one of the same make and model as long as the person making the claim is the first and only registered keeper of the car.
#
# Expected Response: Yes, personal belongings are covered if they are lost or damaged by fire, theft, attempted theft, or accident while theyâre in or on your car, up to Â£500 under Comprehensive Plus.
# Actual Response: Yes, personal belongings are covered under the policy if they are lost or damaged by fire, theft, attempted theft, or accident while they’re in or on your car.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response correctly states that personal belongings are covered under the policy if they are lost or damaged by specified perils (fire, theft, attempted theft, or accident) while in or on the car.
#
# Expected Response: The maximum number of claims allowed under Protected No Claim Discount is 2 claims in 3 years.
# Actual Response: The maximum number of claims allowed under Protected No Claim Discount is 2 claims in 3 years of insurance in a row.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response specifies that the maximum number of claims allowed under protected no claim discount is 2 claims in 3 consecutive years. this matches the statement in the expected response that the maximum number of claims allowed is 2 claims in 3 years.
#
# Expected Response: You should call the claims number provided 0345 878 6261
# Windscreen claims 0800 328 9150 , have your personal details, policy number, car registration number, and a description of the loss or damage ready.
# Actual Response: If you need to make a claim, you should provide your personal details, policy number, car registration number, and a description of the loss or damage. Additionally, you should stay up to date with any developments related to the claim and provide any information, evidence, or documents you have to your appointed representative.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response provides similar instructions as the expected response regarding what information is needed to make a claim and the importance of staying updated on any developments related to the claim. however, the actual response does not provide specific phone numbers for making a windscreen claim or general claims, but instead encourages the person to provide their information to their appointed representative.
#
# Expected Response: No, the policy does not cover mechanical or electrical failure.
# Actual Response: No, the policy does not cover mechanical or electrical failure.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Unexpected Response: yes, the expected and actual responses match. the policy being discussed in both statements does not cover mechanical or electrical failure.
#
# Expected Response: Yes, you can use your car abroad, but you may need a Green Card and should take a European Accident Statement with you.
# Actual Response: Yes, you can use your car abroad under this policy if you have Comprehensive cover and you've added the Foreign Use Extension to your cover before you travel. This will be shown on your car insurance details.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response is providing accurate information about using a car abroad with comprehensive cover and the addition of the foreign use extension.
#
# Expected Response: If your car is written off, the insurance will pay the market value of the car, and the car will become the property of the insurance company.
# Actual Response: If your car is written off and the insurance company agrees to settle your claim on that basis, they will have met their responsibilities to you under the policy. They will not refund any of your premium if you pay annually. If you pay by instalments under a credit agreement, you must resolve the entire claim, giving you the best service and keeping the costs down.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response correctly states that if a car is written off and the insurance company settles the claim, they have fulfilled their obligations under the policy. it also clarifies that there will be no refund of premiums, whether paid annually or through installments under a credit agreement. the explanation for keeping costs down by resolving the entire claim in one go is additional but not contradictory to the main statement.
#
# Expected Response: The Vandalism Promise covers damage to your car that is a result of vandalism, and this wonât affect the No Claim Discount on your policy.
# Actual Response: The Vandalism Promise covers damage to your car that is a result of vandalism. If you claim for vandalism damage, it won't affect the No Claim Discount on your policy. However, it's important to note that the Vandalism Promise doesn't cover damage caused by another vehicle.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response adds additional information to the expected response, stating that the vandalism promise does not cover damage caused by another vehicle and therefore will not affect the no claim discount on the policy only if the damage was caused by vandalism.
#
# Expected Response: The Uninsured Driver Promise ensures that if you are hit by an uninsured driver, your No Claim Discount will not be affected and you will not need to pay an excess.
# Actual Response: The Uninsured Driver Promise covers the scenario where you are involved in an accident that isn't your fault, and the driver of the other vehicle is uninsured. In this case, the promise ensures that your No Claim Discount is protected. Additionally, it helps you claim your uninsured losses from the person who was at fault for the accident. This could include compensation for bodily injury or death.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response goes into more detail than the expected response, but it still accurately conveys that the uninsured driver promise protects the no claim discount and helps claim uninsured losses in case of an accident caused by an uninsured driver.
#
# Expected Response: You must report the theft to the police, obtain a crime reference number, and pay the theft excess.
# Actual Response: If your car keys are stolen, you should report the theft to the police and obtain a crime reference number. After that, you should contact your insurance provider and follow their instructions for making a claim. They will provide cover to replace your stolen car keys and the locks they fit, including any locksmith charges.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response adds additional information to the expected response by advising to contact the insurance provider and follow their instructions for making a claim after reporting the theft to the police and obtaining a crime reference number. this information is important as it ensures that the cost of replacing the stolen car keys and locks will be covered by the insurance provider.
# Expected Response: Yes, the policy covers vandalism damage, and it wonât affect your No Claim Discount if you have Comprehensive or Comprehensive Plus cover.
# Actual Response: Yes, the policy covers vandalism damage. If you claim for damage to your car that’s a result of vandalism, it won’t affect the No Claim Discount on the policy.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response accurately states that vandalism damage is covered under the policy and will not affect the no claim discount if comprehensive or comprehensive plus cover is in place.
#
# Expected Response: The policy does not cover any claims if the car is driven by someone who is not insured on the policy.
# Actual Response: If someone drives your car without being insured, the insurance policy may not cover any loss, damage, liability, or injury that occurs while the car is being driven by someone who isn't named or listed as an excluded driver on your certificate of motor insurance. In such a case, you may not be able to claim for any damages or losses resulting from the uninsured driver using your car.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response provides a clear explanation that if someone drives the insured car without being listed on the policy, the insurance may not cover any damages, losses, liabilities, or injuries resulting from their use of the car.
#
# Expected Response: You can claim for personal belongings if they are lost or damaged by fire, theft, attempted theft, or accident while they are in or on your car, up to the specified amount.
# Actual Response: To claim personal belongings under your car insurance policy, you should follow these steps:
#
# 1. Ensure that your personal belongings are covered under your policy, typically when they are in your car, in your locked private garage, or plugged into your car.
# 2. Contact your insurance provider and inform them about the loss or damage to your personal belongings.
# 3. Provide your personal details, policy number, car registration number, and a description of the loss or damage.
# 4. Follow any additional instructions provided by your insurance provider to process your claim efficiently.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response provides steps on how to claim for personal belongings under car insurance, and it also mentions that coverage is typically when they are in the car or locked private garage, or plugged into the car. however, it's important to note that the coverage and limits vary depending on the specific insurance policy.
#
# Expected Response: Yes, medical expenses are covered up to the specified amount if you are injured in a car accident.
# Actual Response: Yes, medical expenses are covered if you are injured in a car accident, as long as no other car insurance policy covers the cost. The policy will cover up to the amounts specified in the 'What your cover includes' section of the policy booklet.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, but with some clarification. the actual response correctly states that medical expenses are covered in case of a car accident, but it adds an extra condition that no other car insurance policy covers the cost first. this is an important detail to consider when interpreting the statement.
#
# Expected Response: The DriveSure policy includes telematics insurance that captures driving data to understand your driving style and adjust your premium accordingly.
# Actual Response: The DriveSure policy is a telematics insurance product designed to capture how, when, and where your car is driven using driver-monitoring technology. It helps the insurance company understand your driving style and provide feedback based on that information.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately describes the drivesure policy as a telematics insurance product that uses driver-monitoring technology to capture driving data and provides feedback based on that information. the expected response also mentions adjusting premiums accordingly, which is an additional feature of many telematics policies but not explicitly stated in the actual response.
#
# Expected Response: Yes, the policy covers damage caused by misfuelling, but it does not cover the cost of draining, flushing, or replacing the fuel.
# Actual Response: Yes, the policy covers any damage to your car caused by misfuelling. However, it does not cover the cost of draining, flushing, or replacing the fuel if the wrong fuel is put in your car.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately reflects the information provided in the expected response and adds some clarity by specifying that the policy covers any damage caused by misfuelling but does not cover the cost of draining, flushing, or replacing the fuel if the wrong fuel is put in the car.
#
# Expected Response: The policy covers up to Â£300 for hotel expenses if you cannot drive your car after an accident or loss covered under sections 2 or 4.
# Actual Response: The coverage for hotel expenses if you cannot drive your car after an accident is up to £250 under the Comp policy and up to £300 under the Comp+ policy.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, with the following clarifications:
#
# 1. the actual response specifies that there are two different policies (comp and comp+), each with different coverage limits for hotel expenses if you cannot drive your car after an accident.
# 2. both policies cover up to £300 for hotel expenses under certain conditions, but they refer to different policies.
#
# the expected response only mentions one policy (the comp+ policy) covering up to £300 for hotel expenses, which is not entirely incorrect but incomplete. therefore, the actual response provides more accurate and complete information about the coverage for hotel expenses after an accident.
#
# Expected Response: You can use the courtesy car for the duration of the repair if it is being repaired by an approved repairer.
# Actual Response: If your car is being repaired and you have Comprehensive cover, you can use the courtesy car provided by the approved repairer until your car is repaired, subject to availability.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response clarifies that the use of the courtesy car is dependent on having comprehensive cover and the availability of the courtesy car from the approved repairer.
#
# Expected Response: Guaranteed Hire Car Plus provides a hire car of a similar size to your own if your car is damaged in an incident, written off, or stolen.
# Actual Response: The Guaranteed Hire Car Plus cover provides a hire car for a specified amount of time if your car is being repaired by an approved repairer. It extends cover while you are unable to use your car and includes repayment of travel costs if a hire car cannot be provided under certain circumstances. It does not provide cover for driving outside the territorial limits, so it's important to check with the hire car company for any additional coverage.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, but with some additional details. the actual response correctly states that guaranteed hire car plus provides a hire car while your own car is being repaired by an approved repairer. however, it also extends to cover travel costs if a hire car cannot be provided under certain circumstances. it's important to note that the coverage does not provide a hire car of a similar size to your own car as stated in the expected response, but rather provides a hire car for a specified amount of time. additionally, there are territorial limits to consider when using the hired car.
# Expected Response: We can base your premium on the basis of your driving record. If you change your car insurance and thereÕs an extra premium to pay, you can pay this at thetime of the change, or add it to your monthly payments.
# Actual Response: Your premium can be impacted by various factors, including your driving record, the type of coverage you choose, the make and model of your car, where you live, your age, and any additional optional extras you add to your policy. Additionally, if you choose DriveSure, our telematics insurance product, your premium may be affected based on your driving style and behavior as monitored by the technology.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response provides a more comprehensive answer than the expected response, mentioning several factors that can impact a car insurance premium beyond just the driving record.
#
# Expected Response: We will not refund any car insurance premium if you have made a car insurance claim or if one has been made against you during the period of cover (regardless of whether you pay annually or by monthly instalments under a credit agreement). We wonÕt refund any premium if youÕve made a claim, or if youÕve had a claim against you if you have chosen to pay by lump-sum.
# Actual Response: The premium will not be refunded if you have made a claim, or if a claim has been made against you during the period of cover. Additionally, the premium will not be refunded if there has been any fraudulent activity, if you have used threatening or abusive behavior, or if you have intimidated or bullied staff or suppliers.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response adds some additional conditions to the expected response but still maintains the core message that the premium will not be refunded if there is a claim made during the period of cover. the added conditions about fraudulent activity, abusive behavior, intimidation, and bullying are additional reasons for no refund.
#
# Expected Response: Your certificate of motor insurance will show who has cover to drive other cars.
# Generally, the insurance will only cover injury to third parties or damage caused to their property, not damage to the car being driven. If your friend is not listed on your insurance certificate or the policy does not explicitly allow it, then they would not be covered under your insurance.
# Actual Response: Yes, you can lend your car to a friend, and your insurance may cover them under certain conditions. Your friend would typically be covered if they have your permission to use the car, but not to drive it, or if they are getting into or out of your car. It's important to check your specific policy details to ensure coverage.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: false. the actual response is not an accurate reflection of the typical conditions of motor insurance policies regarding coverage for friends driving a borrowed car. while it is true that some policies may cover passengers getting in or out, or permissive users with specific permissions, the scope and conditions of such coverage can vary widely from one policy to another. it's essential to consult your specific policy details to determine the extent of third-party liability coverage and permissive driver coverage for friends driving your car.
#
# Expected Response: Your car insurance policy covers liability for injuries and property damage to others, as well as accidental damage to your car. It also includes personal benefits such as medical expenses, personal accident coverage, and the replacement of child car seats and in-car entertainment equipment. Additionally, you can receive a courtesy car during repairs and have protections like the Uninsured Driver Promise and Vandalism Promise, which safeguard your No Claim Discount under certain conditions. For complete details, refer to sections on liability, accidental damage, and personal benefits in your policy booklet.
# Actual Response: Your policy covers personal accident up to £10,000 under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car. Additionally, the policy may cover legal costs or expenses for defending or representing you in certain situations related to the accident. It's important to refer to the specific details outlined in your car insurance policy booklet for a comprehensive understanding of what is covered in case of an accident.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, but it's important to note that the actual response only mentions a portion of what a typical car insurance policy covers under personal benefits. the expected response provides a more comprehensive overview of what is usually covered in a car insurance policy, including medical expenses and replacement of child car seats and in-car entertainment equipment.
#
# Expected Response: the minimum liability coverage requirements include:
# Injuries to Other People: Unlimited coverage for injuries or death caused to other people.
# Property Damage: Coverage up to £20,000,000 per accident, including all costs and expenses .
# Actual Response: The minimum liability coverage requirements for your car insurance policy are based on the countries listed in the 'Countries where you have minimum cover' section. Once your cover has been used up, your insurance will provide you with the minimum car insurance required by law for countries that are members of the European Union or approved by the Commission of the European Community. If you want to add additional coverage beyond the minimum required, you will need to pay extra.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: false. the actual response does not specify the minimum liability coverage requirements for injuries to other people and property damage. it only mentions that the insurance will provide the minimum required by law in eu countries after the coverage has been used up.
#
# Expected Response: Your policy does not cover: use by unauthorized drivers, unauthorized taking by family without reporting to police, loss of value due to wear and tear, mechanical or electrical failures, deliberate damage, indirect losses like travel costs, actions by government or authorities, cyber events, automated car use when unlawful, and incidents involving drink or drug driving.
# Actual Response: Losses that are not covered under the policy include things like repair, replacement, or restoration of electronic data, cyber events, and any losses that are not specifically outlined in the policy terms. Additionally, if you fail to cooperate with the insurance company, provide necessary information, or if your circumstances change in a way that no longer meets the criteria for motor insurance, your claim may not be accepted. Threatening or abusive behavior towards staff or suspected fraud can also result in a claim not being covered.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, with the following explanations:
#
# 1. repair, replacement, or restoration of electronic data is not covered - the actual response correctly mentions that cyber events and related losses are not included in the policy coverage. this includes damages to electronic data.
# 2. any losses not specifically outlined in the policy terms are not covered - this statement matches the expected response as it highlights that only those losses explicitly mentioned in the policy will be covered, whereas others will not be.
# 3. cooperation with insurance company and providing necessary information is required - the actual response states that failure to cooperate or provide essential information might lead to a claim denial, which aligns with the expected response's statement about claims related to unauthorized drivers and family members taking the car without reporting to the police not being covered.
# 4. changes in circumstances affecting eligibility for motor insurance may result in non-coverage - this is accurate since the policy terms might include specific conditions that could invalidate coverage if they are no longer met, as mentioned in the expected response.
# 5. threatening or abusive behavior and suspected fraud can lead to denied claims - the actual response correctly states that such behavior can result in a claim being rejected; this is not explicitly stated in the expected response but generally holds true for insurance policies.
# Expected Response: Your NCD is protected if you make no more than 2 claims in 3 years. Protected NCD doesnât guarantee your premium wonât increase if a claim is made.
# Actual Response: Your No Claim Discount (NCD) is protected if you make up to 2 claims in 3 years of insurance in a row. This means that your NCD won't be affected by these claims on your policy. However, if you make more than 2 claims in 3 years, your NCD may not be protected.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately states that making up to 2 claims in 3 years won't affect the no claim discount (ncd), but making more than 2 claims may result in the ncd not being protected.
#
# Expected Response: If your car is written off, payments will be made to the lease or hire purchase company. Any remaining balance will be paid to you if you have the option to become the full owner at the end of the agreement.
# Actual Response: If your car is written off and you have a lease or hire purchase agreement, the insurance company will typically pay any claims directly to the lease company or the legal owners of the car. This is because they have ownership rights over the vehicle. You may need to provide documentation or information about the lease or hire purchase agreement to facilitate this process. It's important to contact your insurance provider and discuss the specific details of your situation to understand how the claim will be handled in your case.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response correctly explains that if a car is written off and there is an existing lease or hire purchase agreement, the insurance company will pay the claims directly to the lease or hire purchase company as they are the legal owners of the vehicle. it also advises that the person may need to provide documentation or information about the lease or hire purchase agreement to facilitate the process.
#
# Expected Response: Reasonable and necessary repairs can be carried out at a repairer of your choice, but these repairs will not be guaranteed by the insurer even if they pay for them directly.
# Actual Response: If you choose your own repairer instead of an approved one under the policy, the repairs will not be guaranteed by the insurance company, even if they pay for them directly. In this case, the repairs will not be treated as being carried out by an approved repairer. If there is a problem with any aspect of the repair, your first point of contact should be the repairer who did the original work.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response clearly states that if the policyholder chooses their own repairer instead of one approved by the insurance company, the repairs will not be guaranteed by the insurer. it also suggests that any issues with the repair should be taken up with the chosen repairer.
#
# Expected Response: Your policy doesnât cover damage, fire, or theft of the car youâre driving, nor does it provide Motor Legal cover when driving another car.
# Actual Response: The exclusions related to driving another car under your policy include not covering damage caused by any driver insured on the policy to any property they own or are responsible for.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, but incomplete. the actual response correctly states one of the exclusions related to driving another car under the policy. however, it doesn't mention that the policy also does not cover damage or theft to the borrowed car itself and does not provide motor legal cover. therefore, while the actual response is technically correct regarding the exclusion stated, it is incomplete as it does not cover all the relevant points.
#
# Expected Response: The Uninsured Driver Promise applies if you are in an accident that isnât your fault, and the driver of the other vehicle is uninsured. You need to provide the registration number, make and model of the vehicle that hit you, the driverâs details, and any witness information.
# Actual Response: The Uninsured Driver Promise typically applies when you are involved in a road traffic accident that isn't your fault, and the driver of the other vehicle that hits your car is uninsured.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately describes when the uninsured driver promise applies based on common understanding and usage of the term in insurance contexts.
#
# Expected Response: Motor Legal Cover includes costs for pursuing or defending claims related to road traffic accidents, motor contract disputes, and motoring offences, provided there is a reasonable chance of success.
# Actual Response: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response accurately summarizes the essence of motor legal cover, which is to cover the costs involved in legal action arising from motor-related issues. however, it's important to note that the actual response could be expanded upon by specifying the types of motor-related issues covered (e.g., road traffic accidents, contract disputes, and motoring offenses), as suggested in the expected response.
#
# Expected Response: If your car is not driveable and you use an approved repairer, you will be provided with a hire car until your car is repaired. If you use your own repairer, youâll get a hire car for up to 21 days.
# Actual Response: If your car is not driveable and you have the Guaranteed Hire Car Plus cover, the insurance will extend this cover while you're unable to use your car. This means that if you cannot drive your car due to lost or damaged car keys, for example, the Guaranteed Hire Car Plus cover will provide you with a hire car for the duration of the repair. If the insurance company cannot provide you with a hire car for any reason specified in the policy, they will repay your travel costs up to a certain limit per day.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response explains that if the car is not driveable and the guaranteed hire car plus cover is in effect, the insurance will provide a hire car during the repair period. it also mentions that if a hire car cannot be provided, the insurer will reimburse travel costs up to a certain limit per day. this additional detail expands upon the initial statement but does not contradict it.
#
# Expected Response: The policy doesnât cover other losses caused by the same incident that arenât related to windscreen damage, such as dents to the bodywork or damage caused by vandalism.
# Actual Response: Exclusions for windscreen damage coverage typically include damages that are not accidental, intentional damage, wear and tear, pre-existing damage, and damages caused by a lack of maintenance or negligence. It's important to refer to the specific policy details for a comprehensive list of exclusions.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response provides a more detailed and accurate description of the typical exclusions for windscreen damage coverage compared to the expected response, which is incomplete and not specific enough. both responses indicate that there are limitations to what is covered under windscreen damage insurance, but the actual response provides a more comprehensive list and clarification.
# Expected Response: You must not do or refrain from doing anything that would increase the amount of the claim without written permission, such as admitting liability or negotiating to settle any claim.
# Actual Response: You must not do, or refrain from doing, anything that would increase the amount of the claim without the written permission of the insurance provider. For example, admitting liability for, or negotiating to settle, any claim could potentially increase the amount claimed.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response reaffirms and provides an example of what actions should not be taken without written permission from the insurance provider to avoid increasing the amount of a claim.
#
# Expected Response: While driving abroad, car keys are covered if stolen when you have Comprehensive cover with a Foreign Use Extension or Comprehensive Plus cover. You must replace the keys and send receipts for reimbursement.
# Actual Response: To replace car keys if they are stolen or lost abroad, the conditions are as follows:
# 1. You must have Comprehensive cover and have added Foreign Use Extension to your policy before traveling.
# 2. If you have Comprehensive Plus cover, which includes 90 days of Foreign Use Extension for each insured period.
# 3. You need to report the theft to the police and provide the crime reference number.
# 4. You must replace the car keys and send the receipts to the insurance provider for reimbursement, up to the specified amounts.
# 5. The cover for replacing stolen or lost car keys is not included in Third Party, Fire and Theft policies.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately outlines the conditions under which car key replacement is covered when traveling abroad, as per comprehensive and comprehensive plus policies. it also specifies that this coverage is not included in third party, fire and theft policies.
#
# Expected Response: Yes, you are protected if you seriously injure someone in an accident. The liability coverage under your policy includes protection for injuries to other people caused by an accident involving your car. This includes unlimited coverage for injuries or death caused to other people.
# Actual Response: Yes, you are protected if you seriously injure someone in an accident. The policy covers injuries to other people for an accident involving your car that injures or kills someone.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true, the actual response is consistent with the expected response. both responses confirm that the policy covers injuries to other people caused by an accident involving the insured's car. the difference in wording is minimal and does not affect the accuracy of the response.
#
# Expected Response: Your Right to Cancel the Policy or Remove Any Optional Cover:
# Before Cover Starts: Full refund.
# During 14-Day Cooling-Off Period: Charge for the time you had cover, refund the rest.
# After the 14-Day Cooling-Off Period: Charge for the time you had cover plus an administration fee, refund any remaining premium.
# Actual Response: The cancellation policy states that if you decide to cancel your policy before it starts, you will receive a full refund. If you cancel during the 14-day cooling-off period, you will be charged for the time you had cover and refunded the rest of the premium paid. If you cancel after the cooling-off period, you will be charged for the time you had cover. The policy can also be canceled by the insurance company for valid reasons such as failure to cooperate, changes in circumstances, threatening behavior, or suspected fraud.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately outlines the different scenarios and their corresponding refund policies for cancelling an insurance policy, as well as noting that the insurer also has the right to cancel the policy under certain circumstances.
#
# Expected Response: If you have an accident, ensure everyone's safety and call emergency services if needed. Exchange details with the other driver(s) and gather information about the accident, including witness details. Report the accident to the police if there are injuries or the other driver leaves the scene. Notify your insurer as soon as possible by calling the claims number
# Actual Response: If you are involved in an accident, you should first ensure safety by stopping at the scene and calling the police and emergency services if there are any injuries or if any driver involved hasn’t stopped. Take photos of the accident if it’s safe to do so, including any vehicles involved. Exchange personal details, policy numbers, car registration numbers, and a description of the loss or damage with the other party. Do not accept blame for the accident. Collect contact details from any witnesses. Finally, contact your insurance provider as soon as possible with all the details.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response provides similar steps to those in the expected response, but it also includes taking photos of the accident scene and collecting witness contact details. these are additional steps that can be taken at an accident scene to help with the insurance claim process or potential legal proceedings.
#
# Expected Response: our car insurance covers the following areas:
# Great Britain
# Northern Ireland
# The Channel Islands
# The Isle of Man
# Actual Response: The territorial limits for coverage under the policy include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# ---
# (Answer with 'true' or 'false' for all entries) Does the actual response match? Provide a brief explanation for your assessment.
#
# Response: true. the actual response accurately describes the territorial limits for coverage under the car insurance policy.
# Accuracy: 96.00%

# %% [markdown]
# **Accuracy: 96%**

# %% [markdown]
# ### Evaluation - Relevancy, Recall & Precision
# Using sentence Transformer

# %%
import os
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer, util

# Set OpenAI API key
os.environ["OPENAI_API_KEY"] = "sk-proj-mXhbQjykLmNST2DJN7ldT3BlbkFJwLdQzBNgfTroC2qfhG82"

# Import the RAG chain from utils
conversation_chain = conversation_chain

# Load the sentence transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Function to evaluate precision, recall, and relevancy using sentence-transformers
def evaluate_rag_system(conversation_chain, csv_path):
    df = pd.read_csv(csv_path)
    precision_scores = []
    recall_scores = []
    relevancy_scores = []

    for index, row in df.iterrows():
        question = row['Question']
        expected_answer = row['Answer']

        citation = "Source: Policy document and additional dataset"
        response = handle_userinput(conversation_chain, question, citation)
        bot_answer = response["chat_history"][-1].content  # Last message is the bot's response

        # Compute embeddings
        expected_embedding = model.encode(expected_answer, convert_to_tensor=True)
        bot_embedding = model.encode(bot_answer, convert_to_tensor=True)

        # Compute cosine similarity
        relevancy_score = util.pytorch_cos_sim(expected_embedding, bot_embedding).item()

        # Precision and Recall are a bit more abstract, let's consider them based on token overlap for simplicity
        expected_tokens = set(expected_answer.split())
        bot_tokens = set(bot_answer.split())
        true_positive = len(expected_tokens & bot_tokens)
        precision = true_positive / len(bot_tokens) if len(bot_tokens) > 0 else 0
        recall = true_positive / len(expected_tokens) if len(expected_tokens) > 0 else 0

        precision_scores.append(precision)
        recall_scores.append(recall)
        relevancy_scores.append(relevancy_score)

        print(f"Question: {question}")
        print(f"Expected: {expected_answer}")
        print(f"Bot: {bot_answer}")
        print(f"Precision: {precision:.2f}, Recall: {recall:.2f}, Relevancy: {relevancy_score:.2f}")
        print(f"Citation: {response['citation']}\n")

    avg_precision = np.mean(precision_scores)
    avg_recall = np.mean(recall_scores)
    avg_relevancy = np.mean(relevancy_scores)

    print(f"Average Precision: {avg_precision:.2f}")
    print(f"Average Recall: {avg_recall:.2f}")
    print(f"Average Relevancy: {avg_relevancy:.2f}")

# Specify the path to your testcase CSV file
csv_path = "Cleaned_Testcase_Dataset.csv"

# Run the evaluation
evaluate_rag_system(conversation_chain, csv_path)
# Out:
# /Users/ritikaverma/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /Users/ritikaverma/anaconda3/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Question: What is the procedure to make a claim for windscreen damage?
# Expected: To make a claim for windscreen damage, you need to contact the windscreen claims number provided, and the policy will cover the cost of replacing or repairing broken glass in the windscreen, sunroof, or windows.
# Bot: To make a claim for windscreen damage, you need to contact the windscreen claims number provided, and the policy will cover the cost of replacing or repairing broken glass in the windscreen, sunroof, or windows.
# Precision: 1.00, Recall: 1.00, Relevancy: 1.00
# Citation: Source: Policy document and additional dataset
#
# Question: Does the policy cover theft if the car is left unlocked?
# Expected: No, the policy does not cover theft or attempted theft if the car is left unlocked.
# Bot: No, the policy does not cover theft or attempted theft if the car is left unlocked.
# Precision: 1.00, Recall: 1.00, Relevancy: 1.00
# Citation: Source: Policy document and additional dataset
#
# Question: Are electric car charging cables covered under the policy?
# Expected: Yes, the home charger and charging cables are considered an accessory to the car and are covered under 'Section 2: Fire and theft' or 'Section 4: Accidental damage.'
# Bot: Yes, the home charger and charging cables are considered an accessory to the car and are covered under 'Section 2: Fire and theft' or 'Section 4: Accidental damage.'
# Precision: 1.00, Recall: 1.00, Relevancy: 1.00
# Citation: Source: Policy document and additional dataset
#
# Question: What is the coverage for personal accident?
# Expected: The policy covers up to Â£10,000 for personal accident under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car.
# Bot: The policy covers up to £10,000 for personal accident under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car.
# Precision: 0.96, Recall: 0.96, Relevancy: 0.97
# Citation: Source: Policy document and additional dataset
#
# Question: What is DriveSure and how does it affect my premium?
# Expected: DriveSure is a telematics insurance product designed to capture how, when, and where your car is driven, based on driver-monitoring technology. This information is used to understand your driving style and give feedback, which in turn bases your premium on your driving record.
# Bot: DriveSure is a telematics insurance product designed to capture how, when, and where your car is driven, based on driver-monitoring technology. This information is used to understand your driving style and give you feedback. Your premium may be affected based on your driving record and behavior as monitored by DriveSure.
# Precision: 0.70, Recall: 0.82, Relevancy: 0.99
# Citation: Source: Policy document and additional dataset
#
# Question: How much will be covered for the theft of car keys?
# Expected: The policy covers up to Â£1,000 for the theft of car keys.
# Bot: The policy covers up to £1,000 for the theft of car keys.
# Precision: 0.92, Recall: 0.92, Relevancy: 0.97
# Citation: Source: Policy document and additional dataset
#
# Question: What does Motor Legal Cover include?
# Expected: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court.
# Bot: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court.
# Precision: 1.00, Recall: 1.00, Relevancy: 1.00
# Citation: Source: Policy document and additional dataset
#
# Question: Are courtesy cars available for all types of cover?
# Expected: Courtesy cars are available if you have Essentials or Comprehensive cover and your car is being repaired by an approved repairer.
# Bot: Courtesy cars are available if you have Essentials or Comprehensive cover and your car is being repaired by an approved repairer.
# Precision: 1.00, Recall: 1.00, Relevancy: 1.00
# Citation: Source: Policy document and additional dataset
#
# Question: What are the territorial limits for coverage?
# Expected: The territorial limits include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# Bot: The territorial limits include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# Precision: 1.00, Recall: 1.00, Relevancy: 1.00
# Citation: Source: Policy document and additional dataset
#
# Question: What should you do if you are involved in an accident?
# Expected: You should provide your personal details, policy number, car registration number, and a description of the loss or damage.
# Bot: If you are involved in an accident, you should first stop at the scene and ensure safety. If there are any injuries or if any driver involved hasn’t stopped, call the police and emergency services. Take photos of the accident if it’s safe to do so, including any vehicles involved. Collect the other driver's details and provide your personal details, policy number, car registration number, and a description of the loss or damage.
# Precision: 0.30, Recall: 0.94, Relevancy: 0.62
# Citation: Source: Policy document and additional dataset
#
# Question: What is covered under Section 1: Liability?
# Expected: Section 1: Liability covers you if you're found to be legally responsible for an accident involving your car that injures or kills someone or damages their property.
# Bot: Under Section 1: Liability, your car insurance policy covers liability to other people (third parties) if you are found to be legally responsible for an accident. The level of cover provided depends on the type of insurance you have, whether it's Third Party, Fire and Theft Essentials, Comprehensive, or Comprehensive Plus. Additionally, the policy also includes liability for accidents caused by your automated car when it is lawfully driving in Great Britain.
# Precision: 0.24, Recall: 0.58, Relevancy: 0.78
# Citation: Source: Policy document and additional dataset
#
# Question: What is the coverage for new car replacement under Comprehensive Plus?
# Expected: If your new car is stolen and not recovered, or written off, Comprehensive Plus will replace it with one of the same make and model if your car is less than 2 years old.
# Bot: If your new car is stolen and not recovered, or written off, Comprehensive Plus will replace it with one of the same make and model.
# Precision: 0.96, Recall: 0.77, Relevancy: 0.98
# Citation: Source: Policy document and additional dataset
#
# Question: Are personal belongings covered under the policy?
# Expected: Yes, personal belongings are covered if they are lost or damaged by fire, theft, attempted theft, or accident while theyâre in or on your car, up to Â£500 under Comprehensive Plus.
# Bot: Yes, personal belongings are covered under the policy if they are lost or damaged by fire, theft, attempted theft, or accident while they’re in or on your car.
# Precision: 0.83, Recall: 0.74, Relevancy: 0.86
# Citation: Source: Policy document and additional dataset
#
# Question: What is the maximum number of claims allowed under Protected No Claim Discount?
# Expected: The maximum number of claims allowed under Protected No Claim Discount is 2 claims in 3 years.
# Bot: The maximum number of claims allowed under Protected No Claim Discount is 2 claims in 3 years.
# Precision: 1.00, Recall: 1.00, Relevancy: 1.00
# Citation: Source: Policy document and additional dataset
#
# Question: What should you do if you need to make a claim?
# Expected: You should call the claims number provided 0345 878 6261
# Windscreen claims 0800 328 9150 , have your personal details, policy number, car registration number, and a description of the loss or damage ready.
# Bot: To make a claim, you should provide your personal details, policy number, car registration number, and a description of the loss or damage. Additionally, you should keep up to date with any developments related to the claim and provide any information, evidence, or documents you have to support your claim. Make sure that the incident happened within the territorial limits, you were covered on the date of the incident, and legal proceedings will happen in a court within the territorial limits.
# Precision: 0.29, Recall: 0.52, Relevancy: 0.52
# Citation: Source: Policy document and additional dataset
#
# Question: Does the policy cover mechanical or electrical failure?
# Expected: No, the policy does not cover mechanical or electrical failure.
# Bot: No, the policy does not cover mechanical or electrical failure.
# Precision: 1.00, Recall: 1.00, Relevancy: 1.00
# Citation: Source: Policy document and additional dataset
# Question: Can you use your car abroad under this policy?
# Expected: Yes, you can use your car abroad, but you may need a Green Card and should take a European Accident Statement with you.
# Bot: Yes, you can use your car abroad under this policy if you have Comprehensive cover and you've added the Foreign Use Extension to your cover before you travel. This information will be shown on your car insurance details.
# Precision: 0.22, Recall: 0.33, Relevancy: 0.72
# Citation: Source: Policy document and additional dataset
#
# Question: What happens if your car is written off?
# Expected: If your car is written off, the insurance will pay the market value of the car, and the car will become the property of the insurance company.
# Bot: If your car is written off, typically the insurance company will pay you the actual cash value of your car at the time of the accident, minus any deductible you may have. This amount can be used towards purchasing a new vehicle. It's important to check your policy for specific details on how your insurance company handles write-offs.
# Precision: 0.26, Recall: 0.67, Relevancy: 0.79
# Citation: Source: Policy document and additional dataset
#
# Question: What does the Vandalism Promise cover?
# Expected: The Vandalism Promise covers damage to your car that is a result of vandalism, and this wonât affect the No Claim Discount on your policy.
# Bot: The Vandalism Promise covers damage to your car that is a result of vandalism. If you claim for such damage, it won't affect the No Claim Discount on your policy. However, it's important to note that the Vandalism Promise doesn't cover damage caused by another vehicle.
# Precision: 0.51, Recall: 0.83, Relevancy: 0.96
# Citation: Source: Policy document and additional dataset
#
# Question: What is the Uninsured Driver Promise?
# Expected: The Uninsured Driver Promise ensures that if you are hit by an uninsured driver, your No Claim Discount will not be affected and you will not need to pay an excess.
# Bot: The Uninsured Driver Promise is a feature included in certain types of car insurance policies, such as Essential Comp and Comp+. It provides coverage if you are involved in an accident that isn't your fault and the driver of the other vehicle is uninsured. The promise helps you claim your uninsured losses from the person who was to blame for the accident. This can include compensation for bodily injury or death.
# Precision: 0.22, Recall: 0.48, Relevancy: 0.86
# Citation: Source: Policy document and additional dataset
#
# Question: What should you do if your car keys are stolen?
# Expected: You must report the theft to the police, obtain a crime reference number, and pay the theft excess.
# Bot: If your car keys are stolen, you should take the following steps:
#
# 1. Report the theft to the police and obtain a crime reference number.
# 2. Inform your insurance provider about the theft.
# 3. Take all reasonable steps to protect your car keys from theft.
# 4. Be prepared to pay the theft excess as per your insurance policy.
# 5. If you have Guaranteed Hire Car Plus cover and can't drive your car due to lost or damaged keys, inform your insurance provider to extend the cover for a hire car while you're unable to use your car.
# Precision: 0.13, Recall: 0.60, Relevancy: 0.51
# Citation: Source: Policy document and additional dataset
#
# Question: Does the policy cover vandalism damage?
# Expected: Yes, the policy covers vandalism damage, and it wonât affect your No Claim Discount if you have Comprehensive or Comprehensive Plus cover.
# Bot: Yes, the policy covers vandalism damage. If you claim for damage to your car that’s a result of vandalism, it won’t affect the No Claim Discount on the policy.
# Precision: 0.44, Recall: 0.57, Relevancy: 0.90
# Citation: Source: Policy document and additional dataset
#
# Question: What happens if someone drives your car without being insured?
# Expected: The policy does not cover any claims if the car is driven by someone who is not insured on the policy.
# Bot: If someone drives your car without being insured and they get into an accident, the insurance policy may not cover the damages or losses resulting from that accident. It's important to ensure that anyone driving your car is listed as a driver on your insurance policy to avoid potential issues in case of an accident.
# Precision: 0.20, Recall: 0.50, Relevancy: 0.75
# Citation: Source: Policy document and additional dataset
#
# Question: How can you claim for personal belongings under the policy?
# Expected: You can claim for personal belongings if they are lost or damaged by fire, theft, attempted theft, or accident while they are in or on your car, up to the specified amount.
# Bot: To claim personal belongings under your car insurance policy, you should ensure that they meet the criteria mentioned in your policy booklet. This includes having the belongings in your car or on it, in your locked private garage, or plugged into your car. When making a claim, provide your personal details, policy number, car registration number, and a description of the loss or damage to enable the process to be completed efficiently.
# Precision: 0.19, Recall: 0.37, Relevancy: 0.77
# Citation: Source: Policy document and additional dataset
#
# Question: Are medical expenses covered if you are injured in a car accident?
# Expected: Yes, medical expenses are covered up to the specified amount if you are injured in a car accident.
# Bot: Yes, medical expenses are covered if you are injured in a car accident, as long as no other car insurance policy covers the cost. The policy will cover up to the amounts specified in the 'What your cover includes' section of the policy booklet.
# Precision: 0.44, Recall: 0.88, Relevancy: 0.93
# Citation: Source: Policy document and additional dataset
#
# Question: What is included in the DriveSure policy?
# Expected: The DriveSure policy includes telematics insurance that captures driving data to understand your driving style and adjust your premium accordingly.
# Bot: If you have a DriveSure policy, it includes driver-monitoring technology that captures how, when, and where your car is driven. This information is used to understand your driving style and provide feedback. Additionally, the policy will have specific terms and conditions that you should carefully read and keep safe.
# Precision: 0.27, Recall: 0.61, Relevancy: 0.77
# Citation: Source: Policy document and additional dataset
#
# Question: Does the policy cover damage caused by misfuelling?
# Expected: Yes, the policy covers damage caused by misfuelling, but it does not cover the cost of draining, flushing, or replacing the fuel.
# Bot: Yes, the policy covers any damage to your car caused by misfuelling. However, it does not cover the cost of draining, flushing, or replacing the fuel if the wrong fuel is put in your car.
# Precision: 0.57, Recall: 0.85, Relevancy: 0.92
# Citation: Source: Policy document and additional dataset
#
# Question: What is the coverage for hotel expenses if you cannot drive your car after an accident?
# Expected: The policy covers up to Â£300 for hotel expenses if you cannot drive your car after an accident or loss covered under sections 2 or 4.
# Bot: The coverage for hotel expenses if you cannot drive your car after an accident is up to £250 with the Comp policy and up to £300 with the Comp+ policy.
# Precision: 0.62, Recall: 0.64, Relevancy: 0.83
# Citation: Source: Policy document and additional dataset
#
# Question: How long can you use the courtesy car if your car is being repaired?
# Expected: You can use the courtesy car for the duration of the repair if it is being repaired by an approved repairer.
# Bot: If your car is being repaired by an approved repairer, you can use the courtesy car for as long as your car is being repaired, subject to availability.
# Precision: 0.55, Recall: 0.63, Relevancy: 0.94
# Citation: Source: Policy document and additional dataset
#
# Question: What does the Guaranteed Hire Car Plus cover provide?
# Expected: Guaranteed Hire Car Plus provides a hire car of a similar size to your own if your car is damaged in an incident, written off, or stolen.
# Bot: The Guaranteed Hire Car Plus cover provides a hire car for a specified amount of time if your car is being repaired by an approved repairer. If the insurance company cannot provide you with a hire car for certain reasons, they will repay your travel costs. Additionally, this cover may be extended if you are unable to use your car.
# Precision: 0.29, Recall: 0.58, Relevancy: 0.82
# Citation: Source: Policy document and additional dataset
# Question: What impacts my premium?
# Expected: We can base your premium on the basis of your driving record. If you change your car insurance and thereÕs an extra premium to pay, you can pay this at thetime of the change, or add it to your monthly payments.
# Bot: Factors that can impact your premium include your driving record, the type of coverage you have (Essentials, Comprehensive, Comprehensive Plus), the type of car you drive, your age, where you live, and any additional coverages or benefits you choose to add to your policy. Additionally, your premium may be affected by driver-monitoring technology that assesses your driving style and behavior.
# Precision: 0.27, Recall: 0.38, Relevancy: 0.64
# Citation: Source: Policy document and additional dataset
#
# Question: When the premuim would not be refunded?
# Expected: We will not refund any car insurance premium if you have made a car insurance claim or if one has been made against you during the period of cover (regardless of whether you pay annually or by monthly instalments under a credit agreement). We wonÕt refund any premium if youÕve made a claim, or if youÕve had a claim against you if you have chosen to pay by lump-sum.
# Bot: The premium would not be refunded if you have made a claim, had a claim made against you, or if there are suspicions of fraud. Additionally, the premium may not be refunded if you no longer meet the criteria for providing motor insurance, or if you have used threatening or abusive behavior towards staff or suppliers.
# Precision: 0.35, Recall: 0.34, Relevancy: 0.79
# Citation: Source: Policy document and additional dataset
#
# Question: Can I Lend My Car to a Friend? Will My Insurance Cover Them?
# Expected: Your certificate of motor insurance will show who has cover to drive other cars.
# Generally, the insurance will only cover injury to third parties or damage caused to their property, not damage to the car being driven. If your friend is not listed on your insurance certificate or the policy does not explicitly allow it, then they would not be covered under your insurance.
# Bot: Yes, you can lend your car to a friend, and your insurance will cover them if they have the policyholder's permission to use the car. However, they must not be driving the car, but rather getting into or out of it. It's important to check the specific details of your policy to ensure coverage.
# Precision: 0.30, Recall: 0.28, Relevancy: 0.70
# Citation: Source: Policy document and additional dataset
#
# Question: What Does My Policy Cover If I Get into an Accident?
# Expected: Your car insurance policy covers liability for injuries and property damage to others, as well as accidental damage to your car. It also includes personal benefits such as medical expenses, personal accident coverage, and the replacement of child car seats and in-car entertainment equipment. Additionally, you can receive a courtesy car during repairs and have protections like the Uninsured Driver Promise and Vandalism Promise, which safeguard your No Claim Discount under certain conditions. For complete details, refer to sections on liability, accidental damage, and personal benefits in your policy booklet.
# Bot: Your policy covers up to £10,000 for personal accident under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car. Additionally, the policy covers damage to any belongings in your car that you’re legally responsible for and any other financial losses that happened as a direct result of the accident. To get the ball rolling after an accident, you should provide your personal details, policy number, car registration number, and a description of the loss or damage.
# Precision: 0.34, Recall: 0.30, Relevancy: 0.69
# Citation: Source: Policy document and additional dataset
#
# Question: What are the minimum liability coverage requirements?
# Expected: the minimum liability coverage requirements include:
# Injuries to Other People: Unlimited coverage for injuries or death caused to other people.
# Property Damage: Coverage up to £20,000,000 per accident, including all costs and expenses .
# Bot: The minimum liability coverage requirements for your car insurance policy are the minimum car insurance required by law for the countries listed in the 'Countries where you have minimum cover'. If you want to add additional coverage beyond the minimum, you will need to pay extra.
# Precision: 0.21, Recall: 0.23, Relevancy: 0.69
# Citation: Source: Policy document and additional dataset
#
# Question: what I am not covered for?
# Expected: Your policy does not cover: use by unauthorized drivers, unauthorized taking by family without reporting to police, loss of value due to wear and tear, mechanical or electrical failures, deliberate damage, indirect losses like travel costs, actions by government or authorities, cyber events, automated car use when unlawful, and incidents involving drink or drug driving.
# Bot: Losses we don’t cover include things like repair, replacement, or restoration of electronic data, cyber events, and driving on a racing track, airfield, or off-road event. It's important to keep to all the terms of the policy to ensure you receive the cover outlined in the policy.
# Precision: 0.21, Recall: 0.17, Relevancy: 0.54
# Citation: Source: Policy document and additional dataset
#
# Question: What are the conditions under which my No Claim Discount (NCD) is protected?
# Expected: Your NCD is protected if you make no more than 2 claims in 3 years. Protected NCD doesnât guarantee your premium wonât increase if a claim is made.
# Bot: Your No Claim Discount (NCD) can be protected if you make up to 2 claims in 3 years of insurance in a row. This means that making up to 2 claims within this time frame won't affect the NCD on your policy. However, if you make more than 2 claims in 3 years, your NCD may be affected. Additionally, protected NCD doesn't guarantee that your premium won't increase if a claim is made.
# Precision: 0.39, Recall: 0.80, Relevancy: 0.87
# Citation: Source: Policy document and additional dataset
#
# Question: What is the process if my car is written off and I have a lease or hire purchase agreement?
# Expected: If your car is written off, payments will be made to the lease or hire purchase company. Any remaining balance will be paid to you if you have the option to become the full owner at the end of the agreement.
# Bot: If your car is written off and you have a lease or hire purchase agreement, the insurance company will typically pay any claims to the lease company or the legal owners of the car, depending on the agreement. Once the claim is settled, your car will become the property of the insurance company, and you may need to send them the registration document. All cover will then end unless otherwise agreed.
# Precision: 0.36, Recall: 0.56, Relevancy: 0.62
# Citation: Source: Policy document and additional dataset
#
# Question: How does the policy handle repairs if I choose my own repairer instead of an approved one?
# Expected: Reasonable and necessary repairs can be carried out at a repairer of your choice, but these repairs will not be guaranteed by the insurer even if they pay for them directly.
# Bot: If you choose your own repairer instead of an approved one under the policy, the repairs will not be guaranteed by the insurance company, even if they pay for them directly. In this case, the repairs will not be treated as being carried out by an approved repairer. If there are any issues with the repair work, your first point of contact should be the repairer who conducted the original repairs. It's important to note that by choosing your own repairer, the repairs may not be guaranteed or covered under the policy.
# Precision: 0.30, Recall: 0.66, Relevancy: 0.79
# Citation: Source: Policy document and additional dataset
#
# Question: What are the exclusions related to driving another car under my policy?
# Expected: Your policy doesnât cover damage, fire, or theft of the car youâre driving, nor does it provide Motor Legal cover when driving another car.
# Bot: The exclusions related to driving another car under your policy include not covering damage caused by any driver insured on the policy to any property they own or are responsible for.
# Precision: 0.21, Recall: 0.26, Relevancy: 0.82
# Citation: Source: Policy document and additional dataset
# Question: Under what conditions will the Uninsured Driver Promise apply?
# Expected: The Uninsured Driver Promise applies if you are in an accident that isnât your fault, and the driver of the other vehicle is uninsured. You need to provide the registration number, make and model of the vehicle that hit you, the driverâs details, and any witness information.
# Bot: The Uninsured Driver Promise will apply if you are involved in a road traffic accident that isn't your fault, and the driver of the vehicle that hits your car is uninsured. In this case, your No Claim Discount on the policy will not be affected, and you will not need to pay an excess.
# Precision: 0.50, Recall: 0.58, Relevancy: 0.83
# Citation: Source: Policy document and additional dataset
#
# Question: What does the policy cover under Motor Legal Cover?
# Expected: Motor Legal Cover includes costs for pursuing or defending claims related to road traffic accidents, motor contract disputes, and motoring offences, provided there is a reasonable chance of success.
# Bot: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court.
# Precision: 0.39, Recall: 0.24, Relevancy: 0.90
# Citation: Source: Policy document and additional dataset
#
# Question: How does the Guaranteed Hire Car Plus work if my car is not driveable?
# Expected: If your car is not driveable and you use an approved repairer, you will be provided with a hire car until your car is repaired. If you use your own repairer, youâll get a hire car for up to 21 days.
# Bot: If your car is not driveable and you have Guaranteed Hire Car Plus cover, the insurance will extend this cover while you're unable to use your car. This means that if you cannot drive your car due to lost or damaged car keys, the insurance will provide you with a hire car for the duration of the repair. If the insurance cannot provide you with a hire car for any reason listed in the policy, they will repay your travel costs up to a certain limit per day. You can use this benefit within 21 days following your claim. You will need to pay the costs upfront and then submit your receipts to the insurance company.
# Precision: 0.23, Recall: 0.61, Relevancy: 0.61
# Citation: Source: Policy document and additional dataset
#
# Question: What are the exclusions for windscreen damage coverage?
# Expected: The policy doesnât cover other losses caused by the same incident that arenât related to windscreen damage, such as dents to the bodywork or damage caused by vandalism.
# Bot: The exclusions for windscreen damage coverage typically include damages that are not accidental, intentional damage, damages caused by wear and tear, damages caused by pre-existing conditions, damages caused by improper installation of the windscreen, and damages caused by using the vehicle in a reckless or illegal manner.
# Precision: 0.26, Recall: 0.38, Relevancy: 0.60
# Citation: Source: Policy document and additional dataset
#
# Question: What actions should I avoid to prevent increasing the amount claimed?
# Expected: You must not do or refrain from doing anything that would increase the amount of the claim without written permission, such as admitting liability or negotiating to settle any claim.
# Bot: You must not do, or refrain from doing, anything that would increase the amount of the claim without the insurance company's written permission. For example, admitting liability for, or negotiating to settle, any claim could increase the amount claimed.
# Precision: 0.66, Recall: 0.75, Relevancy: 0.83
# Citation: Source: Policy document and additional dataset
#
# Question: What are the conditions for replacing car keys if they are stolen or lost abroad?
# Expected: While driving abroad, car keys are covered if stolen when you have Comprehensive cover with a Foreign Use Extension or Comprehensive Plus cover. You must replace the keys and send receipts for reimbursement.
# Bot: To have your car keys replaced if they are stolen or lost abroad, you need to have Comprehensive cover and have added the Foreign Use Extension to your policy before traveling. If you have Comprehensive Plus cover, which includes 90 days of Foreign Use Extension, you are also covered. You must take reasonable steps to protect your car keys from theft, and if they are stolen, you will need to pay the theft excess, report the theft to the police, and provide the insurance company with the crime reference number. The policy covers up to £1,000 for the theft of car keys, including locksmith charges.
# Precision: 0.30, Recall: 0.68, Relevancy: 0.90
# Citation: Source: Policy document and additional dataset
#
# Question: Am I protected if I seriously injure someone in an accident?
# Expected: Yes, you are protected if you seriously injure someone in an accident. The liability coverage under your policy includes protection for injuries to other people caused by an accident involving your car. This includes unlimited coverage for injuries or death caused to other people.
# Bot: Yes, you are protected if you seriously injure someone in an accident. The policy provides coverage for accidents caused by your car that injure or kill someone, including coverage for personal accident if you or your partner are accidentally injured while traveling in or getting in or out of your car.
# Precision: 0.57, Recall: 0.62, Relevancy: 0.95
# Citation: Source: Policy document and additional dataset
#
# Question: What are the cancellation policy?
# Expected: Your Right to Cancel the Policy or Remove Any Optional Cover:
# Before Cover Starts: Full refund.
# During 14-Day Cooling-Off Period: Charge for the time you had cover, refund the rest.
# After the 14-Day Cooling-Off Period: Charge for the time you had cover plus an administration fee, refund any remaining premium.
# Bot: The cancellation policy states that if the cancellation or removal happens before your cover starts, a full refund will be given. If the cancellation happens during the 14-day cooling-off period, a full refund will be provided. If the cancellation occurs after the 14-day cooling-off period, you will be charged for the time you've had cover, and the rest of the premium paid will be refunded. The policy can be canceled at any time with at least 7 days' notice if there is a valid reason. If the policy is canceled, it is the policyholder's responsibility to inform anyone insured under the policy. If the policy is canceled, any money owed must be paid.
# Precision: 0.16, Recall: 0.30, Relevancy: 0.86
# Citation: Source: Policy document and additional dataset
#
# Question: What to do incase I met an accident?
# Expected: If you have an accident, ensure everyone's safety and call emergency services if needed. Exchange details with the other driver(s) and gather information about the accident, including witness details. Report the accident to the police if there are injuries or the other driver leaves the scene. Notify your insurer as soon as possible by calling the claims number
# Bot: If you are involved in an accident, you should provide your personal details, policy number, car registration number, and a description of the loss or damage. It's also important to take photos of the accident if it's safe to do so, including any vehicles involved, and ask the other party for their contact details. If any driver involved hasn’t stopped, you should call the police and emergency services.
# Precision: 0.35, Recall: 0.40, Relevancy: 0.75
# Citation: Source: Policy document and additional dataset
#
# Question: Give me the  locations i will be covered?
# Expected: our car insurance covers the following areas:
# Great Britain
# Northern Ireland
# The Channel Islands
# The Isle of Man
# Bot: The territorial limits for coverage include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# Precision: 0.41, Recall: 0.41, Relevancy: 0.70
# Citation: Source: Policy document and additional dataset
#
# Average Precision: 0.50
# Average Recall: 0.63
# Average Relevancy: 0.82

# %% [markdown]
# **RESULTS**
# - Average Precision: 0.50
# - Average Recall: 0.63
# - Average Relevancy: 0.82

# %% [markdown]
# ### Ragas Evaluation

# %%
# !pip -q install ragas
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 14.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.

# %%
# !pip show ragas
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Name: ragas
# Version: 0.1.9
# Summary:
# Home-page:
# Author:
# Author-email:
# License:
# Location: /Applications/anaconda3/lib/python3.11/site-packages
# Requires: appdirs, datasets, langchain, langchain-community, langchain-core, langchain-openai, nest-asyncio, numpy, openai, pysbd, tiktoken
# Required-by:

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.19.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.25.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.23.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (23.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.14.0)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (0.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.9.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.2

# %%
from ragas.metrics import answer_relevancy, faithfulness, context_recall, context_precision, answer_correctness
from ragas import evaluate
from datasets import Dataset

# %% [markdown]
# Sample run on the test dataset created.

# %%
# Load the dataset
dataset_path = "/content/sample_data/Cleaned_Testcase_Dataset_Cleaned.csv"  
df = pd.read_csv(dataset_path)

if isinstance(df['contexts'].iloc[0], str):
    df['contexts'] = df['contexts'].apply(lambda x: x.strip('[]').split(','))  

# Convert the DataFrame to a Dataset object
data_dict = {
    'question': df['question'].tolist(),
    'answer': df['answer'].tolist(),
    'contexts': df['contexts'].tolist()
}
dataset = Dataset.from_dict(data_dict)

# Evaluate the dataset using the specified metrics
score = evaluate(dataset, metrics=[faithfulness])

# Convert the score to a pandas DataFrame and display it
score_df = score.to_pandas()
print(score_df)
# Out:
# Evaluating:   0%|          | 0/50 [00:00<?, ?it/s]
# WARNING:ragas.metrics._faithfulness:No statements were generated from the answer.
# WARNING:ragas.metrics._faithfulness:No statements were generated from the answer.
# WARNING:ragas.metrics._faithfulness:No statements were generated from the answer.
#                                              question  \
# 0   What is the procedure to make a claim for wind...
# 1   Does the policy cover theft if the car is left...
# 2   Are electric car charging cables covered under...
# 3          What is the coverage for personal accident
# 4   What is DriveSure and how does it affect my pr...
# 5   How much will be covered for the theft of car ...
# 6                 What does Motor Legal Cover include
# 7   Are courtesy cars available for all types of c...
# 8        What are the territorial limits for coverage
# 9   What should you do if you are involved in an a...
# 10          What is covered under Section 1 Liability
# 11  What is the coverage for new car replacement u...
# 12   Are personal belongings covered under the policy
# 13  What is the maximum number of claims allowed u...
# 14     What should you do if you need to make a claim
# 15  Does the policy cover mechanical or electrical...
# 16      Can you use your car abroad under this policy
# 17            What happens if your car is written off
# 18              What does the Vandalism Promise cover
# 19               What is the Uninsured Driver Promise
# 20     What should you do if your car keys are stolen
# 21             Does the policy cover vandalism damage
# 22  What happens if someone drives your car withou...
# 23  How can you claim for personal belongings unde...
# 24  Are medical expenses covered if you are injure...
# 25           What is included in the DriveSure policy
# 26  Does the policy cover damage caused by misfuel...
# 27  What is the coverage for hotel expenses if you...
# 28  How long can you use the courtesy car if your ...
# 29  What does the Guaranteed Hire Car Plus cover p...
# 30                            What impacts my premium
# 31             When the premuim would not be refunded
# 32  Can I Lend My Car to a Friend Will My Insuranc...
# 33  What Does My Policy Cover If I Get into an Acc...
# 34  What are the minimum liability coverage requir...
# 35                          what I am not covered for
# 36  What are the conditions under which my No Clai...
# 37  What is the process if my car is written off a...
# 38  How does the policy handle repairs if I choose...
# 39  What are the exclusions related to driving ano...
# 40  Under what conditions will the Uninsured Drive...
# 41  What does the policy cover under Motor Legal C...
# 42  How does the Guaranteed Hire Car Plus work if ...
# 43  What are the exclusions for windscreen damage ...
# 44  What actions should I avoid to prevent increas...
# 45  What are the conditions for replacing car keys...
# 46  Am I protected if I seriously injure someone i...
# 47                   What are the cancellation policy
# 48                What to do incase I met an accident
# 49           Give me the  locations i will be covered
#
#                                                answer  \
# 0   To make a claim for windscreen damage you need...
# 1   No the policy does not cover theft or attempte...
# 2   Yes the home charger and charging cables are c...
# 3   The policy covers up to 10000 for personal acc...
# 4   DriveSure is a telematics insurance product de...
# 5   The policy covers up to 1000 for the theft of ...
# 6   Motor Legal Cover includes covering costs if y...
# 7   Courtesy cars are available if you have Essent...
# 8   The territorial limits include Great Britain N...
# 9   You should provide your personal details polic...
# 10  Section 1 Liability covers you if youre found ...
# 11  If your new car is stolen and not recovered or...
# 12  Yes personal belongings are covered if they ar...
# 13  The maximum number of claims allowed under Pro...
# 14  You should call the claims number provided 034...
# 15  No the policy does not cover mechanical or ele...
# 16  Yes you can use your car abroad but you may ne...
# 17  If your car is written off the insurance will ...
# 18  The Vandalism Promise covers damage to your ca...
# 19  The Uninsured Driver Promise ensures that if y...
# 20  You must report the theft to the police obtain...
# 21  Yes the policy covers vandalism damage and it ...
# 22  The policy does not cover any claims if the ca...
# 23  You can claim for personal belongings if they ...
# 24  Yes medical expenses are covered up to the spe...
# 25  The DriveSure policy includes telematics insur...
# 26  Yes the policy covers damage caused by misfuel...
# 27  The policy covers up to 300 for hotel expenses...
# 28  You can use the courtesy car for the duration ...
# 29  Guaranteed Hire Car Plus provides a hire car o...
# 30  We can base your premium on the basis of your ...
# 31  We will not refund any car insurance premium i...
# 32  Your certificate of motor insurance will show ...
# 33  Your car insurance policy covers liability for...
# 34  the minimum liability coverage requirements in...
# 35  Your policy does not cover use by unauthorized...
# 36  Your NCD is protected if you make no more than...
# 37  If your car is written off payments will be ma...
# 38  Reasonable and necessary repairs can be carrie...
# 39  Your policy doesnt cover damage fire or theft ...
# 40  The Uninsured Driver Promise applies if you ar...
# 41  Motor Legal Cover includes costs for pursuing ...
# 42  If your car is not driveable and you use an ap...
# 43  The policy doesnt cover other losses caused by...
# 44  You must not do or refrain from doing anything...
# 45  While driving abroad car keys are covered if s...
# 46  Yes you are protected if you seriously injure ...
# 47  Your Right to Cancel the Policy or Remove Any ...
# 48  If you have an accident ensure everyones safet...
# 49  our car insurance covers the following areas\n...
#
#                                              contexts  faithfulness
# 0   [Well pay to replace or repair accidentally br...      1.000000
# 1   [We wont pay a claim for theft or attempted th...      1.000000
# 2   [Your home charger and charging cables are con...      1.000000
# 3   [If you or your partner are accidentally injur...      0.500000
# 4   [DriveSure is our telematics insurance product...      1.000000
# 5   [Well replace your stolen car keys and the loc...      0.000000
# 6   [Well cover your Costs if you need to take leg...      1.000000
# 7   [If your car is being repaired by an approved ...      0.500000
# 8   [Territorial limits Great Britain Northern Ire...      1.000000
# 9   [To get the ball rolling well need to know thi...      1.000000
# 10  [Well provide cover if youre found to be legal...      1.000000
# 11  [If you have Comprehensive Plus cover your car...      1.000000
# 12  [Well pay for personal belongings if theyre lo...      0.500000
# 13  [Protected No Claim Discount NCD Maximum numbe...      1.000000
# 14  [To get the ball rolling well need to know thi...      0.666667
# 15  [We dont cover things like Mechanical or elect...      1.000000
# 16  [You may need a Green Card if youre travelling...      0.666667
# 17  [If your car is written off and we agree to se...      0.500000
# 18  [If you claim for damage to your car thats a r...      0.666667
# 19  [If you claim for an accident that isnt your f...      1.000000
# 20  [If your keys are stolen youll need to pay the...      0.666667
# 21  [If you claim for damage to your car thats a r...      0.500000
# 22  [We wont provide cover if your car is being us...           NaN
# 23  [Well pay for personal belongings if theyre lo...      1.000000
# 24  [If your car is in an accident and people are ...      1.000000
# 25  [DriveSure is our telematics insurance product...      0.666667
# 26  [Well cover any damage to your car caused by m...      1.000000
# 27  [If you cannot drive your car after an acciden...      1.000000
# 28  [If your car is being repaired by an approved ...      0.500000
# 29  [Guaranteed Hire Car Plus is designed to keep ...           NaN
# 30  [We can base your premium on the basis of your...      1.000000
# 31  [We will not refund any car insurance premium ...      1.000000
# 32  [Your certificate of motor insurance will show...      0.666667
# 33  [Section 1 Liability\nInjuries to Other People...      1.000000
# 34  [the minimum liability coverage requirements i...      1.000000
# 35  [Your policy does not cover use by unauthorize...      0.800000
# 36  [Protected NCD means that you can make up to 2...      0.500000
# 37  [If your car cant be repaired and youre leasin...      0.500000
# 38  [Where the repairs are carried out at a repair...      1.000000
# 39  [We dont cover any damage fire or theft to the...           NaN
# 40  [If you claim for an accident that isnt your f...      0.400000
# 41  [Well provide cover for the costs to defend yo...      0.250000
# 42  [If your car can be repaired and is not drivea...      0.000000
# 43  [We wont cover any other losses covered under ...      0.500000
# 44  [You must not do or refrain from doing anythin...      1.000000
# 45  [While driving your car abroad well cover your...      0.500000
# 46  [Section 1 Liability\nInjuries to Other People...      0.333333
# 47  [Your Right to Cancel the Policy or Remove Any...      1.000000
# 48  [Were here to support you when\naccidents happ...      0.833333
# 49  [The area your policy applies the territorial ...      1.000000

# %%
# Function to evaluate precision, recall, and relevancy using sentence-transformers
def evaluate_rag_system(conversation_chain, csv_path):
    df = pd.read_csv(csv_path)
    results = []

    for index, row in df.iterrows():
        question = row['Question']
        expected_answer = row['Answer']

        citation = "Source: Policy document and additional dataset"
        response = handle_userinput(conversation_chain, question, citation)
        bot_answer = response["chat_history"][-1].content  # Last message is the bot's response

        # Collect the result
        results.append({
            "Question": question,
            "Expected Answer": expected_answer,
            "Bot Answer": bot_answer,
            "Citation": response['citation']
        })

        print(f"Question: {question}")
        print(f"Expected: {expected_answer}")
        print(f"Bot: {bot_answer}")
        print(f"Citation: {response['citation']}\n")

    # Save the results to a new CSV file
    results_df = pd.DataFrame(results)
    results_df.to_csv("/content/sample_data/results.csv", index=False)
    print("Results saved to results.csv")

# Specify the path to your CSV file
csv_path = "/content/sample_data/Cleaned_Testcase_Dataset.csv"

# Run the evaluation
evaluate_rag_system(conversation_chain, csv_path)
# Out:
# Question: What is the procedure to make a claim for windscreen damage?
# Expected: To make a claim for windscreen damage, you need to contact the windscreen claims number provided, and the policy will cover the cost of replacing or repairing broken glass in the windscreen, sunroof, or windows.
# Bot: To make a claim for windscreen damage, you need to contact the windscreen claims number provided, and the policy will cover the cost of replacing or repairing broken glass in the windscreen, sunroof, or windows.
# Citation: Source: Policy document and additional dataset
#
# Question: Does the policy cover theft if the car is left unlocked?
# Expected: No, the policy does not cover theft or attempted theft if the car is left unlocked.
# Bot: No, the policy does not cover theft or attempted theft if the car is left unlocked.
# Citation: Source: Policy document and additional dataset
#
# Question: Are electric car charging cables covered under the policy?
# Expected: Yes, the home charger and charging cables are considered an accessory to the car and are covered under 'Section 2: Fire and theft' or 'Section 4: Accidental damage.'
# Bot: Yes, the home charger and charging cables are considered an accessory to the car and are covered under 'Section 2: Fire and theft' or 'Section 4: Accidental damage' of your policy.
# Citation: Source: Policy document and additional dataset
#
# Question: What is the coverage for personal accident?
# Expected: The policy covers up to Â£10,000 for personal accident under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car.
# Bot: The policy covers up to £10,000 for personal accident under Comprehensive Plus cover if you or your partner are accidentally injured or killed in a car accident involving your car.
# Citation: Source: Policy document and additional dataset
#
# Question: What is DriveSure and how does it affect my premium?
# Expected: DriveSure is a telematics insurance product designed to capture how, when, and where your car is driven, based on driver-monitoring technology. This information is used to understand your driving style and give feedback, which in turn bases your premium on your driving record.
# Bot: DriveSure is a telematics insurance product designed to capture how, when, and where your car is driven, based on driver-monitoring technology. This information is used to understand your driving style and give you feedback. Your premium may be affected based on your driving record and behavior as monitored by DriveSure.
# Citation: Source: Policy document and additional dataset
#
# Question: How much will be covered for the theft of car keys?
# Expected: The policy covers up to Â£1,000 for the theft of car keys.
# Bot: The policy covers up to £1,000 for the theft of car keys.
# Citation: Source: Policy document and additional dataset
#
# Question: What does Motor Legal Cover include?
# Expected: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court.
# Bot: Motor Legal Cover includes covering costs if you need to take legal action or defend yourself in court.
# Citation: Source: Policy document and additional dataset
#
# Question: Are courtesy cars available for all types of cover?
# Expected: Courtesy cars are available if you have Essentials or Comprehensive cover and your car is being repaired by an approved repairer.
# Bot: Courtesy cars are available if you have Essentials or Comprehensive cover and your car is being repaired by an approved repairer.
# Citation: Source: Policy document and additional dataset
#
# Question: What are the territorial limits for coverage?
# Expected: The territorial limits include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# Bot: The territorial limits for coverage include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# Citation: Source: Policy document and additional dataset
#
# Question: What should you do if you are involved in an accident?
# Expected: You should provide your personal details, policy number, car registration number, and a description of the loss or damage.
# Bot: If you are involved in an accident, you should first ensure safety by stopping at the scene and calling the police and emergency services if there are any injuries or if any driver involved hasn’t stopped. Then, you should take photos of the accident if it's safe to do so, including any vehicles involved. Additionally, you should exchange personal details, policy numbers, car registration numbers, and descriptions of the loss or damage with the other party involved.
# Citation: Source: Policy document and additional dataset
#
# Question: What is covered under Section 1: Liability?
# Expected: Section 1: Liability covers you if you're found to be legally responsible for an accident involving your car that injures or kills someone or damages their property.
# Bot: Under Section 1: Liability, your car insurance policy provides cover for liability to other people (third parties) within the territorial limits in the countries listed in the 'Countries where you have minimum cover'. This includes injury to anyone working with or for the driver of the car, except as set out in the Road Traffic Act. If your policy includes Green Flag, it may also cover liability for accidents caused by your automated car when it is lawfully driving. Additional details and any restrictions can be found under each section of the policy.
# Citation: Source: Policy document and additional dataset
#
# Question: What is the coverage for new car replacement under Comprehensive Plus?
# Expected: If your new car is stolen and not recovered, or written off, Comprehensive Plus will replace it with one of the same make and model if your car is less than 2 years old.
# Bot: If your new car is stolen and not recovered, or written off, Comprehensive Plus cover will replace it with one of the same make and model.
# Citation: Source: Policy document and additional dataset
#
# Question: Are personal belongings covered under the policy?
# Expected: Yes, personal belongings are covered if they are lost or damaged by fire, theft, attempted theft, or accident while theyâre in or on your car, up to Â£500 under Comprehensive Plus.
# Bot: Yes, personal belongings are covered under the policy if they are lost or damaged by fire, theft, attempted theft, or accident while they’re in or on your car.
# Citation: Source: Policy document and additional dataset
#
# Question: What is the maximum number of claims allowed under Protected No Claim Discount?
# Expected: The maximum number of claims allowed under Protected No Claim Discount is 2 claims in 3 years.
# Bot: The maximum number of claims allowed under Protected No Claim Discount is 2 claims in 3 years.
# Citation: Source: Policy document and additional dataset
#
# Question: What should you do if you need to make a claim?
# Expected: You should call the claims number provided 0345 878 6261
# Windscreen claims 0800 328 9150 , have your personal details, policy number, car registration number, and a description of the loss or damage ready.
# Bot: To make a claim, you should provide your personal details, policy number, car registration number, and a description of the loss or damage. Additionally, you should inform us and your appointed representative of any information, evidence, or documents you have related to the claim. It's important to keep us updated on any developments regarding the claim.
# Citation: Source: Policy document and additional dataset
#
# Question: Does the policy cover mechanical or electrical failure?
# Expected: No, the policy does not cover mechanical or electrical failure.
# Bot: No, the policy does not cover mechanical or electrical failure.
# Citation: Source: Policy document and additional dataset
#
# Question: Can you use your car abroad under this policy?
# Expected: Yes, you can use your car abroad, but you may need a Green Card and should take a European Accident Statement with you.
# Bot: Yes, you can use your car abroad under this policy if you have Comprehensive cover and you've added the Foreign Use Extension to your cover before you travel. This information will be shown on your car insurance details.
# Citation: Source: Policy document and additional dataset
#
# Question: What happens if your car is written off?
# Expected: If your car is written off, the insurance will pay the market value of the car, and the car will become the property of the insurance company.
# Bot: If your car is written off, the insurance company may choose to either repair the damage themselves or pay you the value of the car if it's more cost-effective than repairing it. Once the claim is settled, your car will become the property of the insurance company, and you may need to send them the registration document. All cover will then end unless otherwise agreed.
# Citation: Source: Policy document and additional dataset
#
# Question: What does the Vandalism Promise cover?
# Expected: The Vandalism Promise covers damage to your car that is a result of vandalism, and this wonât affect the No Claim Discount on your policy.
# Bot: The Vandalism Promise covers damage to your car that is a result of vandalism. If you claim for such damage, it won't affect the No Claim Discount on your policy. However, it's important to note that the Vandalism Promise doesn't cover damage caused by another vehicle.
# Citation: Source: Policy document and additional dataset
#
# Question: What is the Uninsured Driver Promise?
# Expected: The Uninsured Driver Promise ensures that if you are hit by an uninsured driver, your No Claim Discount will not be affected and you will not need to pay an excess.
# Bot: The Uninsured Driver Promise covers you if you are involved in an accident that isn't your fault, and the driver of the other vehicle is uninsured. It helps you claim your uninsured losses from the person who was to blame for the accident. This could include compensation for death or bodily injury.
# Citation: Source: Policy document and additional dataset
#
# Question: What should you do if your car keys are stolen?
# Expected: You must report the theft to the police, obtain a crime reference number, and pay the theft excess.
# Bot: If your car keys are stolen, you should report the theft to the police and obtain a crime reference number. After that, you should contact your insurance provider and follow their instructions for making a claim. They will provide cover to replace your stolen car keys and the locks they fit, including any locksmith charges.
# Citation: Source: Policy document and additional dataset
#
# Question: Does the policy cover vandalism damage?
# Expected: Yes, the policy covers vandalism damage, and it wonât affect your No Claim Discount if you have Comprehensive or Comprehensive Plus cover.
# Bot: Yes, the policy covers vandalism damage. If you claim for damage to your car that’s a result of vandalism, it won’t affect the No Claim Discount on this policy.
# Citation: Source: Policy document and additional dataset
#
# Question: What happens if someone drives your car without being insured?
# Expected: The policy does not cover any claims if the car is driven by someone who is not insured on the policy.
# Bot: If someone drives your car without being named or listed as an excluded driver on your insurance policy, and they are at fault for an accident, your insurance may not cover the damages or losses. In such a situation, you may need to claim your uninsured losses from the person who was driving your car.
# Citation: Source: Policy document and additional dataset
#
# Question: How can you claim for personal belongings under the policy?
# Expected: You can claim for personal belongings if they are lost or damaged by fire, theft, attempted theft, or accident while they are in or on your car, up to the specified amount.
# Bot: To claim personal belongings under your car insurance policy, you should ensure that they meet the criteria mentioned in your policy booklet. This includes having the belongings on or in your car, in your locked private garage, or plugged into your car. When making a claim, provide your personal details, policy number, car registration number, and a description of the loss or damage to enable the process to be completed efficiently.
# Citation: Source: Policy document and additional dataset
#
# Question: Are medical expenses covered if you are injured in a car accident?
# Expected: Yes, medical expenses are covered up to the specified amount if you are injured in a car accident.
# Bot: Yes, medical expenses are covered if you are injured in a car accident, as long as no other car insurance policy covers the cost. The policy will cover up to the amounts specified in 'What your cover includes' on page 8.
# Citation: Source: Policy document and additional dataset
#
# Question: What is included in the DriveSure policy?
# Expected: The DriveSure policy includes telematics insurance that captures driving data to understand your driving style and adjust your premium accordingly.
# Bot: If you have a DriveSure policy, it includes driver-monitoring technology that captures how, when, and where your car is driven. This information is used to understand your driving style and provide you with feedback. Additionally, the policy will have specific terms and conditions that you should carefully read and keep safe for reference.
# Citation: Source: Policy document and additional dataset
#
# Question: Does the policy cover damage caused by misfuelling?
# Expected: Yes, the policy covers damage caused by misfuelling, but it does not cover the cost of draining, flushing, or replacing the fuel.
# Bot: Yes, the policy covers any damage to your car caused by misfuelling. However, it does not cover the cost of draining, flushing, or replacing the fuel if the wrong fuel is put in your car.
# Citation: Source: Policy document and additional dataset
#
# Question: What is the coverage for hotel expenses if you cannot drive your car after an accident?
# Expected: The policy covers up to Â£300 for hotel expenses if you cannot drive your car after an accident or loss covered under sections 2 or 4.
# Bot: The coverage for hotel expenses if you cannot drive your car after an accident is up to £250 with the Comp policy and up to £300 with the Comp+ policy.
# Citation: Source: Policy document and additional dataset
#
# Question: How long can you use the courtesy car if your car is being repaired?
# Expected: You can use the courtesy car for the duration of the repair if it is being repaired by an approved repairer.
# Bot: If your car is being repaired by an approved repairer, you can use the courtesy car subject to availability. The duration of use may vary, but typically you can use the courtesy car until your car is repaired and ready for collection.
# Citation: Source: Policy document and additional dataset
#
# Question: What does the Guaranteed Hire Car Plus cover provide?
# Expected: Guaranteed Hire Car Plus provides a hire car of a similar size to your own if your car is damaged in an incident, written off, or stolen.
# Bot: The Guaranteed Hire Car Plus cover provides you with a hire car for a specified amount of time if your car is being repaired by an approved repairer. If the insurance company cannot provide you with a hire car for certain reasons, they will repay your travel costs.
# Citation: Source: Policy document and additional dataset
#
# Question: What impacts my premium?
# Expected: We can base your premium on the basis of your driving record. If you change your car insurance and thereÕs an extra premium to pay, you can pay this at thetime of the change, or add it to your monthly payments.
# Bot: Factors that can impact your premium include your driving record, the type of coverage you have (such as Comprehensive or Third Party, Fire and Theft), the type of car you drive, your age, where you live, and any additional coverages or benefits you choose to add to your policy. Additionally, factors like driver-monitoring technology and any claims you make can also affect your premium.
# Citation: Source: Policy document and additional dataset
#
# Question: When the premuim would not be refunded?
# Expected: We will not refund any car insurance premium if you have made a car insurance claim or if one has been made against you during the period of cover (regardless of whether you pay annually or by monthly instalments under a credit agreement). We wonÕt refund any premium if youÕve made a claim, or if youÕve had a claim against you if you have chosen to pay by lump-sum.
# Bot: The premium would not be refunded if you have made a claim, or if a claim has been made against you, or if there has been any fraudulent activity.
# Citation: Source: Policy document and additional dataset
#
# Question: Can I Lend My Car to a Friend? Will My Insurance Cover Them?
# Expected: Your certificate of motor insurance will show who has cover to drive other cars.
# Generally, the insurance will only cover injury to third parties or damage caused to their property, not damage to the car being driven. If your friend is not listed on your insurance certificate or the policy does not explicitly allow it, then they would not be covered under your insurance.
# Bot: Yes, your insurance will cover your friend if you lend them your car as long as they have your permission to use the car. However, it's important to check the specific details of your policy to ensure that your friend is covered under your insurance.
# Citation: Source: Policy document and additional dataset
#
# Question: What Does My Policy Cover If I Get into an Accident?
# Expected: Your car insurance policy covers liability for injuries and property damage to others, as well as accidental damage to your car. It also includes personal benefits such as medical expenses, personal accident coverage, and the replacement of child car seats and in-car entertainment equipment. Additionally, you can receive a courtesy car during repairs and have protections like the Uninsured Driver Promise and Vandalism Promise, which safeguard your No Claim Discount under certain conditions. For complete details, refer to sections on liability, accidental damage, and personal benefits in your policy booklet.
# Bot: Your policy covers personal accident up to the amounts shown in ‘What your cover includes’ on page 8. Additionally, you should provide your personal details, policy number, car registration number, and a description of the loss or damage if you are involved in an accident.
# Citation: Source: Policy document and additional dataset
#
# Question: What are the minimum liability coverage requirements?
# Expected: the minimum liability coverage requirements include:
# Injuries to Other People: Unlimited coverage for injuries or death caused to other people.
# Property Damage: Coverage up to £20,000,000 per accident, including all costs and expenses .
# Bot: The minimum liability coverage requirements for your car insurance policy include:
#
# - Injuries to other people: Unlimited coverage
# - Property damage: £20,000,000 per accident (includes all costs and expenses)
# - Road traffic accident: £100,000 if this cover is included
# - Motor contract dispute: £100,000 if this cover is included
# - Motoring prosecution defense: £100,000 if this cover is included
#
# These are the minimum liability coverage amounts provided by your policy.
# Citation: Source: Policy document and additional dataset
#
# Question: what I am not covered for?
# Expected: Your policy does not cover: use by unauthorized drivers, unauthorized taking by family without reporting to police, loss of value due to wear and tear, mechanical or electrical failures, deliberate damage, indirect losses like travel costs, actions by government or authorities, cyber events, automated car use when unlawful, and incidents involving drink or drug driving.
# Bot: I don't have specific information on the exclusions or limitations of your coverage. It would be best to refer to your car insurance policy booklet or contact your insurance provider for detailed information on the exclusions and limitations of your coverage.
# Citation: Source: Policy document and additional dataset
#
# Question: What are the conditions under which my No Claim Discount (NCD) is protected?
# Expected: Your NCD is protected if you make no more than 2 claims in 3 years. Protected NCD doesnât guarantee your premium wonât increase if a claim is made.
# Bot: Your No Claim Discount (NCD) can be protected if you make up to 2 claims in 3 years of insurance in a row. This means that making up to 2 claims within this time frame won't affect the NCD on your policy. However, it's important to note that protected NCD doesn’t guarantee your premium – it may still increase if a claim is made. You may also have the option to protect your NCD by paying an additional premium.
# Citation: Source: Policy document and additional dataset
#
# Question: What is the process if my car is written off and I have a lease or hire purchase agreement?
# Expected: If your car is written off, payments will be made to the lease or hire purchase company. Any remaining balance will be paid to you if you have the option to become the full owner at the end of the agreement.
# Bot: If your car is written off and you have a lease or hire purchase agreement, the insurance company will typically pay any claims directly to the lease company or the legal owners of the car. This is because they are the legal owners of the vehicle. You may need to provide documentation or information about the lease or hire purchase agreement to facilitate this process.
# Citation: Source: Policy document and additional dataset
#
# Question: How does the policy handle repairs if I choose my own repairer instead of an approved one?
# Expected: Reasonable and necessary repairs can be carried out at a repairer of your choice, but these repairs will not be guaranteed by the insurer even if they pay for them directly.
# Bot: If you choose your own repairer instead of an approved one under the policy, the repairs will not be guaranteed by the insurance company, even if they pay for them directly. In this case, the repairs will not be treated as being carried out by the approved repairer. If there is a problem with any aspect of the repair, your first point of contact should be the repairer who did the original work.
# Citation: Source: Policy document and additional dataset
#
# Question: What are the exclusions related to driving another car under my policy?
# Expected: Your policy doesnât cover damage, fire, or theft of the car youâre driving, nor does it provide Motor Legal cover when driving another car.
# Bot: Under your policy, the exclusions related to driving another car include not covering damage caused by any driver insured on the policy to any property they own or are responsible for. Additionally, liability for loss of, or accidental damage is not covered.
# Citation: Source: Policy document and additional dataset
#
# Question: Under what conditions will the Uninsured Driver Promise apply?
# Expected: The Uninsured Driver Promise applies if you are in an accident that isnât your fault, and the driver of the other vehicle is uninsured. You need to provide the registration number, make and model of the vehicle that hit you, the driverâs details, and any witness information.
# Bot: The Uninsured Driver Promise will apply if you are involved in a road traffic accident that isn't your fault, and the driver of the vehicle that hits your car is uninsured. In this case, the Uninsured Driver Promise will help you claim your uninsured losses from the person who was to blame for the accident.
# Citation: Source: Policy document and additional dataset
#
# Question: What does the policy cover under Motor Legal Cover?
# Expected: Motor Legal Cover includes costs for pursuing or defending claims related to road traffic accidents, motor contract disputes, and motoring offences, provided there is a reasonable chance of success.
# Bot: The policy under Motor Legal Cover covers costs if you need to take legal action or defend yourself in court.
# Citation: Source: Policy document and additional dataset
#
# Question: How does the Guaranteed Hire Car Plus work if my car is not driveable?
# Expected: If your car is not driveable and you use an approved repairer, you will be provided with a hire car until your car is repaired. If you use your own repairer, youâll get a hire car for up to 21 days.
# Bot: If your car is not driveable and you have the Guaranteed Hire Car Plus cover, the insurance will extend this cover while you're unable to use your car. This means that if you can't drive your car due to lost or damaged car keys, the insurance will provide you with a hire car for the duration of the repair. If the insurance cannot provide you with a hire car for certain reasons outlined in the policy, they will repay your travel costs up to a certain limit per day. You can use this benefit within 21 days following your claim.
# Citation: Source: Policy document and additional dataset
#
# Question: What are the exclusions for windscreen damage coverage?
# Expected: The policy doesnât cover other losses caused by the same incident that arenât related to windscreen damage, such as dents to the bodywork or damage caused by vandalism.
# Bot: Exclusions for windscreen damage coverage include damage caused by vandalism (which may be covered under Section 4: Accidental Damage) and loss of use or earnings.
# Citation: Source: Policy document and additional dataset
#
# Question: What actions should I avoid to prevent increasing the amount claimed?
# Expected: You must not do or refrain from doing anything that would increase the amount of the claim without written permission, such as admitting liability or negotiating to settle any claim.
# Bot: You must not do, or refrain from doing, anything that would increase the amount of the claim without the insurance company's written permission. For example, admitting liability for, or negotiating to settle, any claim could potentially increase the amount claimed.
# Citation: Source: Policy document and additional dataset
#
# Question: What are the conditions for replacing car keys if they are stolen or lost abroad?
# Expected: While driving abroad, car keys are covered if stolen when you have Comprehensive cover with a Foreign Use Extension or Comprehensive Plus cover. You must replace the keys and send receipts for reimbursement.
# Bot: The conditions for replacing car keys if they are stolen abroad are:
# - You must have Comprehensive cover and have added Foreign Use Extension to your policy before traveling.
# - For Comprehensive Plus cover, 90 days of Foreign Use Extension is included.
# - The policy covers up to £1,000 for the theft of car keys.
# - You must take all reasonable steps to protect your car keys from theft.
# - You will need to report the theft to the police and provide a crime reference number.
# Citation: Source: Policy document and additional dataset
#
# Question: Am I protected if I seriously injure someone in an accident?
# Expected: Yes, you are protected if you seriously injure someone in an accident. The liability coverage under your policy includes protection for injuries to other people caused by an accident involving your car. This includes unlimited coverage for injuries or death caused to other people.
# Bot: Yes, you are protected if you seriously injure someone in an accident. The policy provides coverage for injuries or deaths caused to someone else as a result of an accident involving your car.
# Citation: Source: Policy document and additional dataset
#
# Question: What are the cancellation policy?
# Expected: Your Right to Cancel the Policy or Remove Any Optional Cover:
# Before Cover Starts: Full refund.
# During 14-Day Cooling-Off Period: Charge for the time you had cover, refund the rest.
# After the 14-Day Cooling-Off Period: Charge for the time you had cover plus an administration fee, refund any remaining premium.
# Bot: If you decide to cancel your policy before it starts, you will receive a full refund. If you cancel during the 14-day cooling-off period, you will be charged for the time you had cover and refunded the rest of the premium paid. If you cancel after the cooling-off period, you will be charged for the time you had cover, an administration fee, and refunded any remaining premium paid. The policy can also be canceled by the insurance company if there are valid reasons, and they will provide at least 7 days' notice.
# Citation: Source: Policy document and additional dataset
#
# Question: What to do incase I met an accident?
# Expected: If you have an accident, ensure everyone's safety and call emergency services if needed. Exchange details with the other driver(s) and gather information about the accident, including witness details. Report the accident to the police if there are injuries or the other driver leaves the scene. Notify your insurer as soon as possible by calling the claims number
# Bot: If you are involved in an accident, you should first stop at the scene of the accident and ensure safety. If there are any injuries or if any driver involved hasn’t stopped, call the police and emergency services. Take photos of the accident if it’s safe to do so, including any vehicles involved. Exchange personal details, policy numbers, car registration numbers, and a description of the loss or damage with the other party.
# Citation: Source: Policy document and additional dataset
#
# Question: Give me the  locations i will be covered?
# Expected: our car insurance covers the following areas:
# Great Britain
# Northern Ireland
# The Channel Islands
# The Isle of Man
# Bot: The territorial limits for coverage under the policy include Great Britain, Northern Ireland, the Channel Islands, and the Isle of Man.
# Citation: Source: Policy document and additional dataset
#
# Results saved to results.csv

# %%
# Load the dataset
dataset_path = "/content/sample_data/results 2.csv"  
df = pd.read_csv(dataset_path)


if isinstance(df['contexts'].iloc[0], str):
    df['contexts'] = df['contexts'].apply(lambda x: x.strip('[]').split(',')) 

# Convert the DataFrame to a Dataset object
data_dict = {
    'question': df['question'].tolist(),
    'answer': df['answer'].tolist(),
    'contexts': df['contexts'].tolist()
}
dataset = Dataset.from_dict(data_dict)

# Evaluate the dataset using multiple metrics
metrics = [faithfulness, answer_relevancy]
score = evaluate(dataset, metrics=metrics)

# Convert the score to a pandas DataFrame and display it
score_df = score.to_pandas()

print(score_df)
# Out:
# Evaluating:   0%|          | 0/100 [00:00<?, ?it/s]
#                                              question  \
# 0   What is the procedure to make a claim for wind...
# 1   Does the policy cover theft if the car is left...
# 2   Are electric car charging cables covered under...
# 3         What is the coverage for personal accident?
# 4   What is DriveSure and how does it affect my pr...
# 5   How much will be covered for the theft of car ...
# 6                What does Motor Legal Cover include?
# 7   Are courtesy cars available for all types of c...
# 8       What are the territorial limits for coverage?
# 9   What should you do if you are involved in an a...
# 10        What is covered under Section 1: Liability?
# 11  What is the coverage for new car replacement u...
# 12  Are personal belongings covered under the policy?
# 13  What is the maximum number of claims allowed u...
# 14    What should you do if you need to make a claim?
# 15  Does the policy cover mechanical or electrical...
# 16     Can you use your car abroad under this policy?
# 17           What happens if your car is written off?
# 18             What does the Vandalism Promise cover?
# 19              What is the Uninsured Driver Promise?
# 20    What should you do if your car keys are stolen?
# 21            Does the policy cover vandalism damage?
# 22  What happens if someone drives your car withou...
# 23  How can you claim for personal belongings unde...
# 24  Are medical expenses covered if you are injure...
# 25          What is included in the DriveSure policy?
# 26  Does the policy cover damage caused by misfuel...
# 27  What is the coverage for hotel expenses if you...
# 28  How long can you use the courtesy car if your ...
# 29  What does the Guaranteed Hire Car Plus cover p...
# 30                           What impacts my premium?
# 31            When the premuim would not be refunded?
# 32  Can I Lend My Car to a Friend? Will My Insuran...
# 33  What Does My Policy Cover If I Get into an Acc...
# 34  What are the minimum liability coverage requir...
# 35                         what I am not covered for?
# 36  What are the conditions under which my No Clai...
# 37  What is the process if my car is written off a...
# 38  How does the policy handle repairs if I choose...
# 39  What are the exclusions related to driving ano...
# 40  Under what conditions will the Uninsured Drive...
# 41  What does the policy cover under Motor Legal C...
# 42  How does the Guaranteed Hire Car Plus work if ...
# 43  What are the exclusions for windscreen damage ...
# 44  What actions should I avoid to prevent increas...
# 45  What are the conditions for replacing car keys...
# 46  Am I protected if I seriously injure someone i...
# 47                  What are the cancellation policy?
# 48               What to do incase I met an accident?
# 49          Give me the  locations i will be covered?
#
#                                                answer  \
# 0   To make a claim for windscreen damage, you nee...
# 1   No, the policy does not cover theft or attempt...
# 2   Yes, the home charger and charging cables are ...
# 3   The policy covers up to £10,000 for personal a...
# 4   DriveSure is a telematics insurance product de...
# 5   The policy covers up to £1,000 for the theft o...
# 6   Motor Legal Cover includes covering costs if y...
# 7   Courtesy cars are available if you have Essent...
# 8   The territorial limits for coverage include Gr...
# 9   If you are involved in an accident, you should...
# 10  Under Section 1: Liability, your car insurance...
# 11  If your new car is stolen and not recovered, o...
# 12  Yes, personal belongings are covered under the...
# 13  The maximum number of claims allowed under Pro...
# 14  To make a claim, you should provide your perso...
# 15  No, the policy does not cover mechanical or el...
# 16  Yes, you can use your car abroad under this po...
# 17  If your car is written off, the insurance comp...
# 18  The Vandalism Promise covers damage to your ca...
# 19  The Uninsured Driver Promise covers you if you...
# 20  If your car keys are stolen, you should report...
# 21  Yes, the policy covers vandalism damage. If yo...
# 22  If someone drives your car without being named...
# 23  To claim personal belongings under your car in...
# 24  Yes, medical expenses are covered if you are i...
# 25  If you have a DriveSure policy, it includes dr...
# 26  Yes, the policy covers any damage to your car ...
# 27  The coverage for hotel expenses if you cannot ...
# 28  If your car is being repaired by an approved r...
# 29  The Guaranteed Hire Car Plus cover provides yo...
# 30  Factors that can impact your premium include y...
# 31  The premium would not be refunded if you have ...
# 32  Yes, your insurance will cover your friend if ...
# 33  Your policy covers personal accident up to the...
# 34  The minimum liability coverage requirements fo...
# 35  I don't have specific information on the exclu...
# 36  Your No Claim Discount (NCD) can be protected ...
# 37  If your car is written off and you have a leas...
# 38  If you choose your own repairer instead of an ...
# 39  Under your policy, the exclusions related to d...
# 40  The Uninsured Driver Promise will apply if you...
# 41  The policy under Motor Legal Cover covers cost...
# 42  If your car is not driveable and you have the ...
# 43  Exclusions for windscreen damage coverage incl...
# 44  You must not do, or refrain from doing, anythi...
# 45  The conditions for replacing car keys if they ...
# 46  Yes, you are protected if you seriously injure...
# 47  If you decide to cancel your policy before it ...
# 48  If you are involved in an accident, you should...
# 49  The territorial limits for coverage under the ...
#
#                                              contexts  faithfulness  \
# 0   [To make a claim for windscreen damage,  you n...      1.000000
# 1   [No,  the policy does not cover theft or attem...      1.000000
# 2   [Yes,  the home charger and charging cables ar...      1.000000
# 3   [The policy covers up to Â£10, 000 for persona...      1.000000
# 4   [DriveSure is a telematics insurance product d...      1.000000
# 5   [The policy covers up to Â£1, 000 for the thef...      1.000000
# 6   [Motor Legal Cover includes covering costs if ...      1.000000
# 7   [Courtesy cars are available if you have Essen...      0.666667
# 8   [The territorial limits include Great Britain,...      1.000000
# 9   [You should provide your personal details,  po...      1.000000
# 10  [Section 1: Liability covers you if you're fou...      0.500000
# 11  [If your new car is stolen and not recovered, ...      1.000000
# 12  [Yes,  personal belongings are covered if they...      1.000000
# 13  [The maximum number of claims allowed under Pr...      1.000000
# 14  [You should call the claims number provided 03...      0.333333
# 15  [No,  the policy does not cover mechanical or ...      1.000000
# 16  [Yes,  you can use your car abroad,  but you m...      0.000000
# 17  [If your car is written off,  the insurance wi...      0.400000
# 18  [The Vandalism Promise covers damage to your c...      0.750000
# 19  [The Uninsured Driver Promise ensures that if ...      0.200000
# 20  [You must report the theft to the police,  obt...      0.285714
# 21  [Yes,  the policy covers vandalism damage,  an...      1.000000
# 22  [The policy does not cover any claims if the c...      0.500000
# 23  [You can claim for personal belongings if they...      1.000000
# 24  [Yes,  medical expenses are covered up to the ...      0.333333
# 25  [The DriveSure policy includes telematics insu...      0.166667
# 26  [Yes,  the policy covers damage caused by misf...      1.000000
# 27  [The policy covers up to Â£300 for hotel expen...      0.500000
# 28  [You can use the courtesy car for the duration...      0.250000
# 29  [Guaranteed Hire Car Plus provides a hire car ...      0.000000
# 30  [We can base your premium on the basis of your...      0.375000
# 31  [We will not refund any car insurance premium ...      0.666667
# 32  [Your certificate of motor insurance will show...      0.500000
# 33  [Your car insurance policy covers liability fo...      0.400000
# 34  [the minimum liability coverage requirements i...      0.000000
# 35  [Your policy does not cover: use by unauthoriz...      0.666667
# 36  [Your NCD is protected if you make no more tha...      0.400000
# 37  [If your car is written off,  payments will be...      0.500000
# 38  [Reasonable and necessary repairs can be carri...      1.000000
# 39  [Your policy doesnât cover damage,  fire,  o...      0.666667
# 40  [The Uninsured Driver Promise applies if you a...      0.400000
# 41  [Motor Legal Cover includes costs for pursuing...      1.000000
# 42  [If your car is not driveable and you use an a...      0.250000
# 43  [The policy doesnât cover other losses cause...      0.250000
# 44  [You must not do or refrain from doing anythin...      0.750000
# 45  [While driving abroad,  car keys are covered i...      0.142857
# 46  [Yes,  you are protected if you seriously inju...      1.000000
# 47  [Your Right to Cancel the Policy or Remove Any...      0.750000
# 48  [If you have an accident,  ensure everyone's s...      0.555556
# 49  [our car insurance covers the following areas:...      1.000000
#
#     answer_relevancy
# 0           0.987232
# 1           0.989924
# 2           0.939649
# 3           0.925386
# 4           0.914833
# 5           0.982769
# 6           1.000000
# 7           0.929427
# 8           0.999999
# 9           0.993597
# 10          0.935934
# 11          0.917182
# 12          0.933213
# 13          1.000000
# 14          0.930332
# 15          1.000000
# 16          0.993204
# 17          0.982083
# 18          0.941248
# 19          0.954742
# 20          1.000000
# 21          0.953881
# 22          0.929993
# 23          0.921357
# 24          1.000000
# 25          0.988170
# 26          0.912049
# 27          0.961222
# 28          0.935977
# 29          0.968088
# 30          0.916607
# 31          0.912841
# 32          0.948602
# 33          0.909428
# 34          0.968537
# 35          0.000000
# 36          0.893686
# 37          0.925847
# 38          0.955108
# 39          0.966850
# 40          0.967148
# 41          0.971922
# 42          0.951017
# 43          1.000000
# 44          0.903666
# 45          0.994231
# 46          0.987892
# 47          0.883442
# 48          0.937085
# 49          0.846790

# %%
# Save the results to a new CSV file
results_path = "evaluation_results.csv"
score_df.to_csv(results_path, index=False)

# %%
# Calculate aggregate score for faithfulness
aggregate_faithfulness = score_df['faithfulness'].mean()
answer_relevancy = score_df['answer_relevancy'].mean()
# Display the scores

print(f"Aggregate Faithfulness Score: {aggregate_faithfulness:.2f}")
print(f"Aggregate Relevency: {answer_relevancy:.2f}")
# Out:
# Aggregate Faithfulness Score: 0.64
# Aggregate Relevency: 0.93

# %%
# Load the dataset
dataset_path = "/content/sample_data/results 3.csv" 
df = pd.read_csv(dataset_path)


if isinstance(df['ground_truth'].iloc[0], str):
    df['contexts'] = df['contexts'].apply(lambda x: x.strip('[]').split(','))  

# Convert the DataFrame to a Dataset object
data_dict = {
    'question': df['question'].tolist(),
    'answer': df['answer'].tolist(),
    'contexts': df['contexts'].tolist(),
    'ground_truth': df['ground_truth'].tolist()
}
dataset = Dataset.from_dict(data_dict)

# Evaluate the dataset using multiple metrics
metrics = [context_recall]
score = evaluate(dataset, metrics=metrics)

# Convert the score to a pandas DataFrame and display it
score_df2 = score.to_pandas()

print(score_df2)
# Out:
# Evaluating:   0%|          | 0/50 [00:00<?, ?it/s]
#                                              question  \
# 0   What is the procedure to make a claim for wind...
# 1   Does the policy cover theft if the car is left...
# 2   Are electric car charging cables covered under...
# 3         What is the coverage for personal accident?
# 4   What is DriveSure and how does it affect my pr...
# 5   How much will be covered for the theft of car ...
# 6                What does Motor Legal Cover include?
# 7   Are courtesy cars available for all types of c...
# 8       What are the territorial limits for coverage?
# 9   What should you do if you are involved in an a...
# 10        What is covered under Section 1: Liability?
# 11  What is the coverage for new car replacement u...
# 12  Are personal belongings covered under the policy?
# 13  What is the maximum number of claims allowed u...
# 14    What should you do if you need to make a claim?
# 15  Does the policy cover mechanical or electrical...
# 16     Can you use your car abroad under this policy?
# 17           What happens if your car is written off?
# 18             What does the Vandalism Promise cover?
# 19              What is the Uninsured Driver Promise?
# 20    What should you do if your car keys are stolen?
# 21            Does the policy cover vandalism damage?
# 22  What happens if someone drives your car withou...
# 23  How can you claim for personal belongings unde...
# 24  Are medical expenses covered if you are injure...
# 25          What is included in the DriveSure policy?
# 26  Does the policy cover damage caused by misfuel...
# 27  What is the coverage for hotel expenses if you...
# 28  How long can you use the courtesy car if your ...
# 29  What does the Guaranteed Hire Car Plus cover p...
# 30                           What impacts my premium?
# 31            When the premuim would not be refunded?
# 32  Can I Lend My Car to a Friend? Will My Insuran...
# 33  What Does My Policy Cover If I Get into an Acc...
# 34  What are the minimum liability coverage requir...
# 35                         what I am not covered for?
# 36  What are the conditions under which my No Clai...
# 37  What is the process if my car is written off a...
# 38  How does the policy handle repairs if I choose...
# 39  What are the exclusions related to driving ano...
# 40  Under what conditions will the Uninsured Drive...
# 41  What does the policy cover under Motor Legal C...
# 42  How does the Guaranteed Hire Car Plus work if ...
# 43  What are the exclusions for windscreen damage ...
# 44  What actions should I avoid to prevent increas...
# 45  What are the conditions for replacing car keys...
# 46  Am I protected if I seriously injure someone i...
# 47                  What are the cancellation policy?
# 48               What to do incase I met an accident?
# 49          Give me the  locations i will be covered?
#
#                                                answer  \
# 0   To make a claim for windscreen damage, you nee...
# 1   No, the policy does not cover theft or attempt...
# 2   Yes, the home charger and charging cables are ...
# 3   The policy covers up to £10,000 for personal a...
# 4   DriveSure is a telematics insurance product de...
# 5   The policy covers up to £1,000 for the theft o...
# 6   Motor Legal Cover includes covering costs if y...
# 7   Courtesy cars are available if you have Essent...
# 8   The territorial limits for coverage include Gr...
# 9   If you are involved in an accident, you should...
# 10  Under Section 1: Liability, your car insurance...
# 11  If your new car is stolen and not recovered, o...
# 12  Yes, personal belongings are covered under the...
# 13  The maximum number of claims allowed under Pro...
# 14  To make a claim, you should provide your perso...
# 15  No, the policy does not cover mechanical or el...
# 16  Yes, you can use your car abroad under this po...
# 17  If your car is written off, the insurance comp...
# 18  The Vandalism Promise covers damage to your ca...
# 19  The Uninsured Driver Promise covers you if you...
# 20  If your car keys are stolen, you should report...
# 21  Yes, the policy covers vandalism damage. If yo...
# 22  If someone drives your car without being named...
# 23  To claim personal belongings under your car in...
# 24  Yes, medical expenses are covered if you are i...
# 25  If you have a DriveSure policy, it includes dr...
# 26  Yes, the policy covers any damage to your car ...
# 27  The coverage for hotel expenses if you cannot ...
# 28  If your car is being repaired by an approved r...
# 29  The Guaranteed Hire Car Plus cover provides yo...
# 30  Factors that can impact your premium include y...
# 31  The premium would not be refunded if you have ...
# 32  Yes, your insurance will cover your friend if ...
# 33  Your policy covers personal accident up to the...
# 34  The minimum liability coverage requirements fo...
# 35  I don't have specific information on the exclu...
# 36  Your No Claim Discount (NCD) can be protected ...
# 37  If your car is written off and you have a leas...
# 38  If you choose your own repairer instead of an ...
# 39  Under your policy, the exclusions related to d...
# 40  The Uninsured Driver Promise will apply if you...
# 41  The policy under Motor Legal Cover covers cost...
# 42  If your car is not driveable and you have the ...
# 43  Exclusions for windscreen damage coverage incl...
# 44  You must not do, or refrain from doing, anythi...
# 45  The conditions for replacing car keys if they ...
# 46  Yes, you are protected if you seriously injure...
# 47  If you decide to cancel your policy before it ...
# 48  If you are involved in an accident, you should...
# 49  The territorial limits for coverage under the ...
#
#                                              contexts  \
# 0   [To make a claim for windscreen damage,  you n...
# 1   [No,  the policy does not cover theft or attem...
# 2   [Yes,  the home charger and charging cables ar...
# 3   [The policy covers up to Â£10, 000 for persona...
# 4   [DriveSure is a telematics insurance product d...
# 5   [The policy covers up to Â£1, 000 for the thef...
# 6   [Motor Legal Cover includes covering costs if ...
# 7   [Courtesy cars are available if you have Essen...
# 8   [The territorial limits include Great Britain,...
# 9   [You should provide your personal details,  po...
# 10  [Section 1: Liability covers you if you're fou...
# 11  [If your new car is stolen and not recovered, ...
# 12  [Yes,  personal belongings are covered if they...
# 13  [The maximum number of claims allowed under Pr...
# 14  [You should call the claims number provided 03...
# 15  [No,  the policy does not cover mechanical or ...
# 16  [Yes,  you can use your car abroad,  but you m...
# 17  [If your car is written off,  the insurance wi...
# 18  [The Vandalism Promise covers damage to your c...
# 19  [The Uninsured Driver Promise ensures that if ...
# 20  [You must report the theft to the police,  obt...
# 21  [Yes,  the policy covers vandalism damage,  an...
# 22  [The policy does not cover any claims if the c...
# 23  [You can claim for personal belongings if they...
# 24  [Yes,  medical expenses are covered up to the ...
# 25  [The DriveSure policy includes telematics insu...
# 26  [Yes,  the policy covers damage caused by misf...
# 27  [The policy covers up to Â£300 for hotel expen...
# 28  [You can use the courtesy car for the duration...
# 29  [Guaranteed Hire Car Plus provides a hire car ...
# 30  [We can base your premium on the basis of your...
# 31  [We will not refund any car insurance premium ...
# 32  [Your certificate of motor insurance will show...
# 33  [Your car insurance policy covers liability fo...
# 34  [the minimum liability coverage requirements i...
# 35  [Your policy does not cover: use by unauthoriz...
# 36  [Your NCD is protected if you make no more tha...
# 37  [If your car is written off,  payments will be...
# 38  [Reasonable and necessary repairs can be carri...
# 39  [Your policy doesnât cover damage,  fire,  o...
# 40  [The Uninsured Driver Promise applies if you a...
# 41  [Motor Legal Cover includes costs for pursuing...
# 42  [If your car is not driveable and you use an a...
# 43  [The policy doesnât cover other losses cause...
# 44  [You must not do or refrain from doing anythin...
# 45  [While driving abroad,  car keys are covered i...
# 46  [Yes,  you are protected if you seriously inju...
# 47  [Your Right to Cancel the Policy or Remove Any...
# 48  [If you have an accident,  ensure everyone's s...
# 49  [our car insurance covers the following areas:...
#
#                                          ground_truth  context_recall
# 0   Weâll pay to replace or repair accidentally ...        1.000000
# 1   We wonât pay a claim for theft or attempted ...        1.000000
# 2   Your home charger and charging cables are cons...        1.000000
# 3   If you or your partner are accidentally injure...        0.500000
# 4   DriveSure is our telematics insurance product....        1.000000
# 5   Weâll replace your stolen car keys and the l...        0.500000
# 6   Weâll cover your Costs if you need to take l...        1.000000
# 7   If your car is being repaired by an approved r...        1.000000
# 8   Territorial limits: Great Britain, Northern Ir...        1.000000
# 9   To get the ball rolling, weâll need to know ...        1.000000
# 10  Weâll provide cover if youâre found to be ...        1.000000
# 11  If you have Comprehensive Plus cover, your car...        1.000000
# 12  Weâll pay for personal belongings if theyâ...        0.500000
# 13  Protected No Claim Discount (NCD) Maximum numb...        1.000000
# 14  To get the ball rolling, weâll need to know ...        1.000000
# 15  We donât cover things like: Mechanical or el...        1.000000
# 16  You may need a Green Card if youâre travelli...        0.666667
# 17  If your car is written off and we agree to set...        1.000000
# 18  If you claim for damage to your car thatâs a...        1.000000
# 19  If you claim for an accident that isnât your...        1.000000
# 20  If your keys are stolen, youâll need to pay ...        0.500000
# 21  If you claim for damage to your car thatâs a...        0.500000
# 22  We wonât provide cover if your car is being ...        1.000000
# 23  Weâll pay for personal belongings if theyâ...        1.000000
# 24  If your car is in an accident and people are i...        1.000000
# 25  DriveSure is our telematics insurance product....        1.000000
# 26  Weâll cover any damage to your car caused by...        0.500000
# 27  If you cannot drive your car after an accident...        0.500000
# 28  If your car is being repaired by an approved r...        0.500000
# 29  Guaranteed Hire Car Plus is designed to keep y...        1.000000
# 30  We can base your premium on the basis of your ...        1.000000
# 31  We will not refund any car insurance premium i...        1.000000
# 32  Your certificate of motor insurance will show\...        1.000000
# 33  Section 1: Liability\nInjuries to Other People...        0.714286
# 34  the minimum liability coverage requirements in...        1.000000
# 35  Your policy does not cover: use by unauthorize...        1.000000
# 36  Protected NCD means that you can make up to 2 ...        1.000000
# 37  If your car canât be repaired and youâre l...        1.000000
# 38  Where the repairs are carried out at a repaire...        1.000000
# 39  We donât cover any damage, fire, or theft to...        1.000000
# 40  If you claim for an accident that isnât your...        0.666667
# 41  Weâll provide cover for the costs to defend ...        0.500000
# 42  If your car can be repaired, and is not drivea...        0.000000
# 43  We wonât cover any other losses covered unde...        1.000000
# 44  You must not do, or refrain from doing, anythi...        1.000000
# 45  While driving your car abroad, weâll cover y...        1.000000
# 46  Section 1: Liability\nInjuries to Other People...        1.000000
# 47  Your Right to Cancel the Policy or Remove Any ...        1.000000
# 48  WeÕre here to support you when\naccidents happ...        0.400000
# 49  "The area your policy applies (the territorial...        1.000000

# %%
# Calculate aggregate score for faithfulness
context_recall = score_df2['context_recall'].mean()

print(f"Aggregate context_recall: {context_recall:.2f}")
# Out:
# Aggregate context_recall: 0.86

# %%
# Load the dataset
dataset_path = "/content/sample_data/results 3.csv" 
df = pd.read_csv(dataset_path)


if isinstance(df['ground_truth'].iloc[0], str):
    df['contexts'] = df['contexts'].apply(lambda x: x.strip('[]').split(','))  # Adjust delimiter as needed

# Convert the DataFrame to a Dataset object
data_dict = {
    'question': df['question'].tolist(),
    'answer': df['answer'].tolist(),
    'contexts': df['contexts'].tolist(),
    'ground_truth': df['ground_truth'].tolist()
}
dataset = Dataset.from_dict(data_dict)

# Evaluate the dataset using multiple metrics
metrics = [answer_correctness]
score = evaluate(dataset, metrics=metrics)

# Convert the score to a pandas DataFrame and display it
score_df3 = score.to_pandas()

print(score_df3)
# Out:
# Evaluating:   0%|          | 0/50 [00:00<?, ?it/s]
#                                              question  \
# 0   What is the procedure to make a claim for wind...
# 1   Does the policy cover theft if the car is left...
# 2   Are electric car charging cables covered under...
# 3         What is the coverage for personal accident?
# 4   What is DriveSure and how does it affect my pr...
# 5   How much will be covered for the theft of car ...
# 6                What does Motor Legal Cover include?
# 7   Are courtesy cars available for all types of c...
# 8       What are the territorial limits for coverage?
# 9   What should you do if you are involved in an a...
# 10        What is covered under Section 1: Liability?
# 11  What is the coverage for new car replacement u...
# 12  Are personal belongings covered under the policy?
# 13  What is the maximum number of claims allowed u...
# 14    What should you do if you need to make a claim?
# 15  Does the policy cover mechanical or electrical...
# 16     Can you use your car abroad under this policy?
# 17           What happens if your car is written off?
# 18             What does the Vandalism Promise cover?
# 19              What is the Uninsured Driver Promise?
# 20    What should you do if your car keys are stolen?
# 21            Does the policy cover vandalism damage?
# 22  What happens if someone drives your car withou...
# 23  How can you claim for personal belongings unde...
# 24  Are medical expenses covered if you are injure...
# 25          What is included in the DriveSure policy?
# 26  Does the policy cover damage caused by misfuel...
# 27  What is the coverage for hotel expenses if you...
# 28  How long can you use the courtesy car if your ...
# 29  What does the Guaranteed Hire Car Plus cover p...
# 30                           What impacts my premium?
# 31            When the premuim would not be refunded?
# 32  Can I Lend My Car to a Friend? Will My Insuran...
# 33  What Does My Policy Cover If I Get into an Acc...
# 34  What are the minimum liability coverage requir...
# 35                         what I am not covered for?
# 36  What are the conditions under which my No Clai...
# 37  What is the process if my car is written off a...
# 38  How does the policy handle repairs if I choose...
# 39  What are the exclusions related to driving ano...
# 40  Under what conditions will the Uninsured Drive...
# 41  What does the policy cover under Motor Legal C...
# 42  How does the Guaranteed Hire Car Plus work if ...
# 43  What are the exclusions for windscreen damage ...
# 44  What actions should I avoid to prevent increas...
# 45  What are the conditions for replacing car keys...
# 46  Am I protected if I seriously injure someone i...
# 47                  What are the cancellation policy?
# 48               What to do incase I met an accident?
# 49          Give me the  locations i will be covered?
#
#                                                answer  \
# 0   To make a claim for windscreen damage, you nee...
# 1   No, the policy does not cover theft or attempt...
# 2   Yes, the home charger and charging cables are ...
# 3   The policy covers up to £10,000 for personal a...
# 4   DriveSure is a telematics insurance product de...
# 5   The policy covers up to £1,000 for the theft o...
# 6   Motor Legal Cover includes covering costs if y...
# 7   Courtesy cars are available if you have Essent...
# 8   The territorial limits for coverage include Gr...
# 9   If you are involved in an accident, you should...
# 10  Under Section 1: Liability, your car insurance...
# 11  If your new car is stolen and not recovered, o...
# 12  Yes, personal belongings are covered under the...
# 13  The maximum number of claims allowed under Pro...
# 14  To make a claim, you should provide your perso...
# 15  No, the policy does not cover mechanical or el...
# 16  Yes, you can use your car abroad under this po...
# 17  If your car is written off, the insurance comp...
# 18  The Vandalism Promise covers damage to your ca...
# 19  The Uninsured Driver Promise covers you if you...
# 20  If your car keys are stolen, you should report...
# 21  Yes, the policy covers vandalism damage. If yo...
# 22  If someone drives your car without being named...
# 23  To claim personal belongings under your car in...
# 24  Yes, medical expenses are covered if you are i...
# 25  If you have a DriveSure policy, it includes dr...
# 26  Yes, the policy covers any damage to your car ...
# 27  The coverage for hotel expenses if you cannot ...
# 28  If your car is being repaired by an approved r...
# 29  The Guaranteed Hire Car Plus cover provides yo...
# 30  Factors that can impact your premium include y...
# 31  The premium would not be refunded if you have ...
# 32  Yes, your insurance will cover your friend if ...
# 33  Your policy covers personal accident up to the...
# 34  The minimum liability coverage requirements fo...
# 35  I don't have specific information on the exclu...
# 36  Your No Claim Discount (NCD) can be protected ...
# 37  If your car is written off and you have a leas...
# 38  If you choose your own repairer instead of an ...
# 39  Under your policy, the exclusions related to d...
# 40  The Uninsured Driver Promise will apply if you...
# 41  The policy under Motor Legal Cover covers cost...
# 42  If your car is not driveable and you have the ...
# 43  Exclusions for windscreen damage coverage incl...
# 44  You must not do, or refrain from doing, anythi...
# 45  The conditions for replacing car keys if they ...
# 46  Yes, you are protected if you seriously injure...
# 47  If you decide to cancel your policy before it ...
# 48  If you are involved in an accident, you should...
# 49  The territorial limits for coverage under the ...
#
#                                              contexts  \
# 0   [To make a claim for windscreen damage,  you n...
# 1   [No,  the policy does not cover theft or attem...
# 2   [Yes,  the home charger and charging cables ar...
# 3   [The policy covers up to Â£10, 000 for persona...
# 4   [DriveSure is a telematics insurance product d...
# 5   [The policy covers up to Â£1, 000 for the thef...
# 6   [Motor Legal Cover includes covering costs if ...
# 7   [Courtesy cars are available if you have Essen...
# 8   [The territorial limits include Great Britain,...
# 9   [You should provide your personal details,  po...
# 10  [Section 1: Liability covers you if you're fou...
# 11  [If your new car is stolen and not recovered, ...
# 12  [Yes,  personal belongings are covered if they...
# 13  [The maximum number of claims allowed under Pr...
# 14  [You should call the claims number provided 03...
# 15  [No,  the policy does not cover mechanical or ...
# 16  [Yes,  you can use your car abroad,  but you m...
# 17  [If your car is written off,  the insurance wi...
# 18  [The Vandalism Promise covers damage to your c...
# 19  [The Uninsured Driver Promise ensures that if ...
# 20  [You must report the theft to the police,  obt...
# 21  [Yes,  the policy covers vandalism damage,  an...
# 22  [The policy does not cover any claims if the c...
# 23  [You can claim for personal belongings if they...
# 24  [Yes,  medical expenses are covered up to the ...
# 25  [The DriveSure policy includes telematics insu...
# 26  [Yes,  the policy covers damage caused by misf...
# 27  [The policy covers up to Â£300 for hotel expen...
# 28  [You can use the courtesy car for the duration...
# 29  [Guaranteed Hire Car Plus provides a hire car ...
# 30  [We can base your premium on the basis of your...
# 31  [We will not refund any car insurance premium ...
# 32  [Your certificate of motor insurance will show...
# 33  [Your car insurance policy covers liability fo...
# 34  [the minimum liability coverage requirements i...
# 35  [Your policy does not cover: use by unauthoriz...
# 36  [Your NCD is protected if you make no more tha...
# 37  [If your car is written off,  payments will be...
# 38  [Reasonable and necessary repairs can be carri...
# 39  [Your policy doesnât cover damage,  fire,  o...
# 40  [The Uninsured Driver Promise applies if you a...
# 41  [Motor Legal Cover includes costs for pursuing...
# 42  [If your car is not driveable and you use an a...
# 43  [The policy doesnât cover other losses cause...
# 44  [You must not do or refrain from doing anythin...
# 45  [While driving abroad,  car keys are covered i...
# 46  [Yes,  you are protected if you seriously inju...
# 47  [Your Right to Cancel the Policy or Remove Any...
# 48  [If you have an accident,  ensure everyone's s...
# 49  [our car insurance covers the following areas:...
#
#                                          ground_truth  answer_correctness
# 0   Weâll pay to replace or repair accidentally ...            0.823789
# 1   We wonât pay a claim for theft or attempted ...            0.730945
# 2   Your home charger and charging cables are cons...            0.886853
# 3   If you or your partner are accidentally injure...            0.525268
# 4   DriveSure is our telematics insurance product....            0.744819
# 5   Weâll replace your stolen car keys and the l...            0.212994
# 6   Weâll cover your Costs if you need to take l...            0.826376
# 7   If your car is being repaired by an approved r...            0.792211
# 8   Territorial limits: Great Britain, Northern Ir...            0.987762
# 9   To get the ball rolling, weâll need to know ...            0.216002
# 10  Weâll provide cover if youâre found to be ...            0.435528
# 11  If you have Comprehensive Plus cover, your car...            0.652996
# 12  Weâll pay for personal belongings if theyâ...            0.832726
# 13  Protected No Claim Discount (NCD) Maximum numb...            0.985349
# 14  To get the ball rolling, weâll need to know ...            0.695090
# 15  We donât cover things like: Mechanical or el...            0.229496
# 16  You may need a Green Card if youâre travelli...            0.582391
# 17  If your car is written off and we agree to set...            0.535435
# 18  If you claim for damage to your car thatâs a...            0.607293
# 19  If you claim for an accident that isnât your...            0.673379
# 20  If your keys are stolen, youâll need to pay ...            0.687742
# 21  If you claim for damage to your car thatâs a...            0.741282
# 22  We wonât provide cover if your car is being ...            0.515340
# 23  Weâll pay for personal belongings if theyâ...            0.750612
# 24  If your car is in an accident and people are i...            0.733830
# 25  DriveSure is our telematics insurance product....            0.662103
# 26  Weâll cover any damage to your car caused by...            0.613572
# 27  If you cannot drive your car after an accident...            0.648228
# 28  If your car is being repaired by an approved r...            0.533812
# 29  Guaranteed Hire Car Plus is designed to keep y...            0.731825
# 30  We can base your premium on the basis of your ...            0.840955
# 31  We will not refund any car insurance premium i...            0.225639
# 32  Your certificate of motor insurance will show\...            0.208796
# 33  Section 1: Liability\nInjuries to Other People...            0.533936
# 34  the minimum liability coverage requirements in...            0.240690
# 35  Your policy does not cover: use by unauthorize...            0.212827
# 36  Protected NCD means that you can make up to 2 ...            0.663285
# 37  If your car canât be repaired and youâre l...            0.603314
# 38  Where the repairs are carried out at a repaire...            0.830161
# 39  We donât cover any damage, fire, or theft to...            0.223661
# 40  If you claim for an accident that isnât your...            0.390803
# 41  Weâll provide cover for the costs to defend ...            0.602188
# 42  If your car can be repaired, and is not drivea...            0.437715
# 43  We wonât cover any other losses covered unde...            0.213375
# 44  You must not do, or refrain from doing, anythi...            0.607594
# 45  While driving your car abroad, weâll cover y...            0.504936
# 46  Section 1: Liability\nInjuries to Other People...            0.521504
# 47  Your Right to Cancel the Policy or Remove Any ...            0.689236
# 48  WeÕre here to support you when\naccidents happ...            0.685331
# 49  "The area your policy applies (the territorial...            0.981543

# %%
# Calculate aggregate score for faithfulness
answer_correctness = score_df3['answer_correctness'].mean()

print(f"Aggregate answer_correctness: {answer_correctness:.2f}")
# Out:
# Aggregate answer_correctness: 0.60

# %%
# Load the dataset
dataset_path = "/content/sample_data/results 3.csv" 
df = pd.read_csv(dataset_path)


if isinstance(df['ground_truth'].iloc[0], str):
    df['contexts'] = df['contexts'].apply(lambda x: x.strip('[]').split(','))  # Adjust delimiter as needed

# Convert the DataFrame to a Dataset object
data_dict = {
    'question': df['question'].tolist(),
    'answer': df['answer'].tolist(),
    'contexts': df['contexts'].tolist(),
    'ground_truth': df['ground_truth'].tolist()
}
dataset = Dataset.from_dict(data_dict)

# Evaluate the dataset using multiple metrics
metrics = [context_precision]
score = evaluate(dataset, metrics=metrics)

# Convert the score to a pandas DataFrame and display it
score_df4 = score.to_pandas()

print(score_df4)
# Out:
# Evaluating:   0%|          | 0/50 [00:00<?, ?it/s]
#                                              question  \
# 0   What is the procedure to make a claim for wind...
# 1   Does the policy cover theft if the car is left...
# 2   Are electric car charging cables covered under...
# 3         What is the coverage for personal accident?
# 4   What is DriveSure and how does it affect my pr...
# 5   How much will be covered for the theft of car ...
# 6                What does Motor Legal Cover include?
# 7   Are courtesy cars available for all types of c...
# 8       What are the territorial limits for coverage?
# 9   What should you do if you are involved in an a...
# 10        What is covered under Section 1: Liability?
# 11  What is the coverage for new car replacement u...
# 12  Are personal belongings covered under the policy?
# 13  What is the maximum number of claims allowed u...
# 14    What should you do if you need to make a claim?
# 15  Does the policy cover mechanical or electrical...
# 16     Can you use your car abroad under this policy?
# 17           What happens if your car is written off?
# 18             What does the Vandalism Promise cover?
# 19              What is the Uninsured Driver Promise?
# 20    What should you do if your car keys are stolen?
# 21            Does the policy cover vandalism damage?
# 22  What happens if someone drives your car withou...
# 23  How can you claim for personal belongings unde...
# 24  Are medical expenses covered if you are injure...
# 25          What is included in the DriveSure policy?
# 26  Does the policy cover damage caused by misfuel...
# 27  What is the coverage for hotel expenses if you...
# 28  How long can you use the courtesy car if your ...
# 29  What does the Guaranteed Hire Car Plus cover p...
# 30                           What impacts my premium?
# 31            When the premuim would not be refunded?
# 32  Can I Lend My Car to a Friend? Will My Insuran...
# 33  What Does My Policy Cover If I Get into an Acc...
# 34  What are the minimum liability coverage requir...
# 35                         what I am not covered for?
# 36  What are the conditions under which my No Clai...
# 37  What is the process if my car is written off a...
# 38  How does the policy handle repairs if I choose...
# 39  What are the exclusions related to driving ano...
# 40  Under what conditions will the Uninsured Drive...
# 41  What does the policy cover under Motor Legal C...
# 42  How does the Guaranteed Hire Car Plus work if ...
# 43  What are the exclusions for windscreen damage ...
# 44  What actions should I avoid to prevent increas...
# 45  What are the conditions for replacing car keys...
# 46  Am I protected if I seriously injure someone i...
# 47                  What are the cancellation policy?
# 48               What to do incase I met an accident?
# 49          Give me the  locations i will be covered?
#
#                                                answer  \
# 0   To make a claim for windscreen damage, you nee...
# 1   No, the policy does not cover theft or attempt...
# 2   Yes, the home charger and charging cables are ...
# 3   The policy covers up to £10,000 for personal a...
# 4   DriveSure is a telematics insurance product de...
# 5   The policy covers up to £1,000 for the theft o...
# 6   Motor Legal Cover includes covering costs if y...
# 7   Courtesy cars are available if you have Essent...
# 8   The territorial limits for coverage include Gr...
# 9   If you are involved in an accident, you should...
# 10  Under Section 1: Liability, your car insurance...
# 11  If your new car is stolen and not recovered, o...
# 12  Yes, personal belongings are covered under the...
# 13  The maximum number of claims allowed under Pro...
# 14  To make a claim, you should provide your perso...
# 15  No, the policy does not cover mechanical or el...
# 16  Yes, you can use your car abroad under this po...
# 17  If your car is written off, the insurance comp...
# 18  The Vandalism Promise covers damage to your ca...
# 19  The Uninsured Driver Promise covers you if you...
# 20  If your car keys are stolen, you should report...
# 21  Yes, the policy covers vandalism damage. If yo...
# 22  If someone drives your car without being named...
# 23  To claim personal belongings under your car in...
# 24  Yes, medical expenses are covered if you are i...
# 25  If you have a DriveSure policy, it includes dr...
# 26  Yes, the policy covers any damage to your car ...
# 27  The coverage for hotel expenses if you cannot ...
# 28  If your car is being repaired by an approved r...
# 29  The Guaranteed Hire Car Plus cover provides yo...
# 30  Factors that can impact your premium include y...
# 31  The premium would not be refunded if you have ...
# 32  Yes, your insurance will cover your friend if ...
# 33  Your policy covers personal accident up to the...
# 34  The minimum liability coverage requirements fo...
# 35  I don't have specific information on the exclu...
# 36  Your No Claim Discount (NCD) can be protected ...
# 37  If your car is written off and you have a leas...
# 38  If you choose your own repairer instead of an ...
# 39  Under your policy, the exclusions related to d...
# 40  The Uninsured Driver Promise will apply if you...
# 41  The policy under Motor Legal Cover covers cost...
# 42  If your car is not driveable and you have the ...
# 43  Exclusions for windscreen damage coverage incl...
# 44  You must not do, or refrain from doing, anythi...
# 45  The conditions for replacing car keys if they ...
# 46  Yes, you are protected if you seriously injure...
# 47  If you decide to cancel your policy before it ...
# 48  If you are involved in an accident, you should...
# 49  The territorial limits for coverage under the ...
#
#                                              contexts  \
# 0   [To make a claim for windscreen damage,  you n...
# 1   [No,  the policy does not cover theft or attem...
# 2   [Yes,  the home charger and charging cables ar...
# 3   [The policy covers up to Â£10, 000 for persona...
# 4   [DriveSure is a telematics insurance product d...
# 5   [The policy covers up to Â£1, 000 for the thef...
# 6   [Motor Legal Cover includes covering costs if ...
# 7   [Courtesy cars are available if you have Essen...
# 8   [The territorial limits include Great Britain,...
# 9   [You should provide your personal details,  po...
# 10  [Section 1: Liability covers you if you're fou...
# 11  [If your new car is stolen and not recovered, ...
# 12  [Yes,  personal belongings are covered if they...
# 13  [The maximum number of claims allowed under Pr...
# 14  [You should call the claims number provided 03...
# 15  [No,  the policy does not cover mechanical or ...
# 16  [Yes,  you can use your car abroad,  but you m...
# 17  [If your car is written off,  the insurance wi...
# 18  [The Vandalism Promise covers damage to your c...
# 19  [The Uninsured Driver Promise ensures that if ...
# 20  [You must report the theft to the police,  obt...
# 21  [Yes,  the policy covers vandalism damage,  an...
# 22  [The policy does not cover any claims if the c...
# 23  [You can claim for personal belongings if they...
# 24  [Yes,  medical expenses are covered up to the ...
# 25  [The DriveSure policy includes telematics insu...
# 26  [Yes,  the policy covers damage caused by misf...
# 27  [The policy covers up to Â£300 for hotel expen...
# 28  [You can use the courtesy car for the duration...
# 29  [Guaranteed Hire Car Plus provides a hire car ...
# 30  [We can base your premium on the basis of your...
# 31  [We will not refund any car insurance premium ...
# 32  [Your certificate of motor insurance will show...
# 33  [Your car insurance policy covers liability fo...
# 34  [the minimum liability coverage requirements i...
# 35  [Your policy does not cover: use by unauthoriz...
# 36  [Your NCD is protected if you make no more tha...
# 37  [If your car is written off,  payments will be...
# 38  [Reasonable and necessary repairs can be carri...
# 39  [Your policy doesnât cover damage,  fire,  o...
# 40  [The Uninsured Driver Promise applies if you a...
# 41  [Motor Legal Cover includes costs for pursuing...
# 42  [If your car is not driveable and you use an a...
# 43  [The policy doesnât cover other losses cause...
# 44  [You must not do or refrain from doing anythin...
# 45  [While driving abroad,  car keys are covered i...
# 46  [Yes,  you are protected if you seriously inju...
# 47  [Your Right to Cancel the Policy or Remove Any...
# 48  [If you have an accident,  ensure everyone's s...
# 49  [our car insurance covers the following areas:...
#
#                                          ground_truth  context_precision
# 0   Weâll pay to replace or repair accidentally ...           1.000000
# 1   We wonât pay a claim for theft or attempted ...           1.000000
# 2   Your home charger and charging cables are cons...           1.000000
# 3   If you or your partner are accidentally injure...           0.500000
# 4   DriveSure is our telematics insurance product....           1.000000
# 5   Weâll replace your stolen car keys and the l...           1.000000
# 6   Weâll cover your Costs if you need to take l...           1.000000
# 7   If your car is being repaired by an approved r...           1.000000
# 8   Territorial limits: Great Britain, Northern Ir...           0.805556
# 9   To get the ball rolling, weâll need to know ...           0.000000
# 10  Weâll provide cover if youâre found to be ...           1.000000
# 11  If you have Comprehensive Plus cover, your car...           0.833333
# 12  Weâll pay for personal belongings if theyâ...           1.000000
# 13  Protected No Claim Discount (NCD) Maximum numb...           1.000000
# 14  To get the ball rolling, weâll need to know ...           1.000000
# 15  We donât cover things like: Mechanical or el...           0.500000
# 16  You may need a Green Card if youâre travelli...           0.833333
# 17  If your car is written off and we agree to set...           1.000000
# 18  If you claim for damage to your car thatâs a...           1.000000
# 19  If you claim for an accident that isnât your...           1.000000
# 20  If your keys are stolen, youâll need to pay ...           1.000000
# 21  If you claim for damage to your car thatâs a...           0.583333
# 22  We wonât provide cover if your car is being ...           1.000000
# 23  Weâll pay for personal belongings if theyâ...           0.588889
# 24  If your car is in an accident and people are i...           1.000000
# 25  DriveSure is our telematics insurance product....           1.000000
# 26  Weâll cover any damage to your car caused by...           1.000000
# 27  If you cannot drive your car after an accident...           1.000000
# 28  If your car is being repaired by an approved r...           1.000000
# 29  Guaranteed Hire Car Plus is designed to keep y...           1.000000
# 30  We can base your premium on the basis of your ...           1.000000
# 31  We will not refund any car insurance premium i...           1.000000
# 32  Your certificate of motor insurance will show\...           1.000000
# 33  Section 1: Liability\nInjuries to Other People...           0.833879
# 34  the minimum liability coverage requirements in...           0.750000
# 35  Your policy does not cover: use by unauthorize...           1.000000
# 36  Protected NCD means that you can make up to 2 ...           1.000000
# 37  If your car canât be repaired and youâre l...           1.000000
# 38  Where the repairs are carried out at a repaire...           1.000000
# 39  We donât cover any damage, fire, or theft to...           0.750000
# 40  If you claim for an accident that isnât your...           1.000000
# 41  Weâll provide cover for the costs to defend ...           0.750000
# 42  If your car can be repaired, and is not drivea...           1.000000
# 43  We wonât cover any other losses covered unde...           1.000000
# 44  You must not do, or refrain from doing, anythi...           1.000000
# 45  While driving your car abroad, weâll cover y...           1.000000
# 46  Section 1: Liability\nInjuries to Other People...           1.000000
# 47  Your Right to Cancel the Policy or Remove Any ...           0.833333
# 48  WeÕre here to support you when\naccidents happ...           1.000000
# 49  "The area your policy applies (the territorial...           1.000000

# %%
# Calculate aggregate score for faithfulness
context_precision = score_df4['context_precision'].mean()

print(f"Aggregate context_precision: {context_precision:.2f}")
# Out:
# Aggregate context_precision: 0.91

# %% [markdown]
# **RAGAS Evaluation Results:**
#
# - Aggregate Faithfulness Score: 0.64
# - Aggregate Relevency: 0.93
# - Aggregate context_recall: 0.86
# - Aggregate answer_correctness: 0.60
# - Aggregate context_precision: 0.91
